# %% [markdown]
# # PFM: Data Collection - REE OpenWeather

# %% [markdown]
# The objective of this session is to understand how data can be retrieved from specific sources as REE API.
#
# To do so, we will use `requests` library and `json` libraries for Python. These libraries are considered as wrappers.
#
# Later on, we will use specific libraries for plotting as `matplotlib` and `datetime`.

# %%
# import requests library
import requests 
import json
# import plotting library
import matplotlib
import matplotlib.pyplot as plt 
import datetime
import pandas as pd #importamos Pandas!
import numpy as np

# %% [markdown]
# As we have seen before, when we work with APIs, we have to write the url we want to access.
#
# Most of the times, we need to add some headers to our requests that are required to get the information. The most important one is the **API Key**, which corresponds to our ID to access that API.

# %% [markdown]
# ### Current and forecast weather data
#
# Minute forecast for 1 hour, Hourly forecast por 48 hours, Daily forecast for 7 days

# %%
request=requests.get('https://api.openweathermap.org/data/2.5/onecall?lat=33.441792&lon=-94.037689&appid=de359429e61129a9779f33cd9e7b2611&units=metric&lang=es')
request.json()
# Out:
# {'lat': 33.44,
#  'lon': -94.04,
#  'timezone': 'America/Chicago',
#  'timezone_offset': -18000,
#  'current': {'dt': 1601549945,
#   'sunrise': 1601554243,
#   'sunset': 1601596822,
#   'temp': 14.34,
#   'feels_like': 13.2,
#   'pressure': 1019,
#   'humidity': 87,
#   'dew_point': 12.21,
#   'uvi': 6.87,
#   'clouds': 1,
#   'visibility': 10000,
#   'wind_speed': 2.6,
#   'wind_deg': 20,
#   'weather': [{'id': 800,
#     'main': 'Clear',
#     'description': 'cielo claro',
#     'icon': '01n'}]},
#  'minutely': [{'dt': 1601550000, 'precipitation': 0},
#   {'dt': 1601550060, 'precipitation': 0},
#   {'dt': 1601550120, 'precipitation': 0},
#   {'dt': 1601550180, 'precipitation': 0},
#   {'dt': 1601550240, 'precipitation': 0},
#   {'dt': 1601550300, 'precipitation': 0},
#   {'dt': 1601550360, 'precipitation': 0},
#   {'dt': 1601550420, 'precipitation': 0},
#   {'dt': 1601550480, 'precipitation': 0},
#   {'dt': 1601550540, 'precipitation': 0},
#   {'dt': 1601550600, 'precipitation': 0},
#   {'dt': 1601550660, 'precipitation': 0},
#   {'dt': 1601550720, 'precipitation': 0},
#   {'dt': 1601550780, 'precipitation': 0},
#   {'dt': 1601550840, 'precipitation': 0},
#   {'dt': 1601550900, 'precipitation': 0},
#   {'dt': 1601550960, 'precipitation': 0},
#   {'dt': 1601551020, 'precipitation': 0},
#   {'dt': 1601551080, 'precipitation': 0},
#   {'dt': 1601551140, 'precipitation': 0},
#   {'dt': 1601551200, 'precipitation': 0},
#   {'dt': 1601551260, 'precipitation': 0},
#   {'dt': 1601551320, 'precipitation': 0},
#   {'dt': 1601551380, 'precipitation': 0},
#   {'dt': 1601551440, 'precipitation': 0},
#   {'dt': 1601551500, 'precipitation': 0},
#   {'dt': 1601551560, 'precipitation': 0},
#   {'dt': 1601551620, 'precipitation': 0},
#   {'dt': 1601551680, 'precipitation': 0},
#   {'dt': 1601551740, 'precipitation': 0},
#   {'dt': 1601551800, 'precipitation': 0},
#   {'dt': 1601551860, 'precipitation': 0},
#   {'dt': 1601551920, 'precipitation': 0},
#   {'dt': 1601551980, 'precipitation': 0},
#   {'dt': 1601552040, 'precipitation': 0},
#   {'dt': 1601552100, 'precipitation': 0},
#   {'dt': 1601552160, 'precipitation': 0},
#   {'dt': 1601552220, 'precipitation': 0},
#   {'dt': 1601552280, 'precipitation': 0},
#   {'dt': 1601552340, 'precipitation': 0},
#   {'dt': 1601552400, 'precipitation': 0},
#   {'dt': 1601552460, 'precipitation': 0},
#   {'dt': 1601552520, 'precipitation': 0},
#   {'dt': 1601552580, 'precipitation': 0},
#   {'dt': 1601552640, 'precipitation': 0},
#   {'dt': 1601552700, 'precipitation': 0},
#   {'dt': 1601552760, 'precipitation': 0},
#   {'dt': 1601552820, 'precipitation': 0},
#   {'dt': 1601552880, 'precipitation': 0},
#   {'dt': 1601552940, 'precipitation': 0},
#   {'dt': 1601553000, 'precipitation': 0},
#   {'dt': 1601553060, 'precipitation': 0},
#   {'dt': 1601553120, 'precipitation': 0},
#   {'dt': 1601553180, 'precipitation': 0},
#   {'dt': 1601553240, 'precipitation': 0},
#   {'dt': 1601553300, 'precipitation': 0},
#   {'dt': 1601553360, 'precipitation': 0},
#   {'dt': 1601553420, 'precipitation': 0},
#   {'dt': 1601553480, 'precipitation': 0},
#   {'dt': 1601553540, 'precipitation': 0},
#   {'dt': 1601553600, 'precipitation': 0}],
#  'hourly': [{'dt': 1601546400,
#    'temp': 14.34,
#    'feels_like': 12.85,
#    'pressure': 1019,
#    'humidity': 87,
#    'dew_point': 12.21,
#    'clouds': 1,
#    'visibility': 10000,
#    'wind_speed': 3.11,
#    'wind_deg': 4,
#    'weather': [{'id': 800,
#      'main': 'Clear',
#      'description': 'cielo claro',
#      'icon': '01n'}],
#    'pop': 0},
#   {'dt': 1601550000,
#    'temp': 15.01,
#    'feels_like': 13.24,
#    'pressure': 1019,
#    'humidity': 84,
#    'dew_point': 12.33,
#    'clouds': 1,
#    'visibility': 10000,
#    'wind_speed': 3.56,
#    'wind_deg': 31,
#    'weather': [{'id': 800,
#      'main': 'Clear',
#      'description': 'cielo claro',
#      'icon': '01n'}],
#    'pop': 0},
#   {'dt': 1601553600,
#    'temp': 15.22,
#    'feels_like': 13.5,
#    'pressure': 1020,
#    'humidity': 82,
#    'dew_point': 12.17,
#    'clouds': 0,
#    'visibility': 10000,
#    'wind_speed': 3.42,
#    'wind_deg': 40,
#    'weather': [{'id': 800,
#      'main': 'Clear',
#      'description': 'cielo claro',
#      'icon': '01n'}],
#    'pop': 0},
#   {'dt': 1601557200,
#    'temp': 15.55,
#    'feels_like': 14.04,
#    'pressure': 1021,
#    'humidity': 80,
#    'dew_point': 12.12,
#    'clouds': 0,
#    'visibility': 10000,
#    'wind_speed': 3.09,
#    'wind_deg': 48,
#    'weather': [{'id': 800,
#      'main': 'Clear',
#      'description': 'cielo claro',
#      'icon': '01d'}],
#    'pop': 0},
#   {'dt': 1601560800,
#    'temp': 18.06,
#    'feels_like': 16.01,
#    'pressure': 1022,
#    'humidity': 67,
#    'dew_point': 11.85,
#    'clouds': 0,
#    'visibility': 10000,
#    'wind_speed': 3.74,
#    'wind_deg': 57,
#    'weather': [{'id': 800,
#      'main': 'Clear',
#      'description': 'cielo claro',
#      'icon': '01d'}],
#    'pop': 0},
#   {'dt': 1601564400,
#    'temp': 20.15,
#    'feels_like': 18.05,
#    'pressure': 1022,
#    'humidity': 57,
#    'dew_point': 11.58,
#    'clouds': 0,
#    'visibility': 10000,
#    'wind_speed': 3.61,
#    'wind_deg': 54,
#    'weather': [{'id': 800,
#      'main': 'Clear',
#      'description': 'cielo claro',
#      'icon': '01d'}],
#    'pop': 0},
#   {'dt': 1601568000,
#    'temp': 21.98,
#    'feels_like': 19.89,
#    'pressure': 1022,
#    'humidity': 49,
#    'dew_point': 11,
#    'clouds': 0,
#    'visibility': 10000,
#    'wind_speed': 3.36,
#    'wind_deg': 52,
#    'weather': [{'id': 800,
#      'main': 'Clear',
#      'description': 'cielo claro',
#      'icon': '01d'}],
#    'pop': 0},
#   {'dt': 1601571600,
#    'temp': 23.44,
#    'feels_like': 21.18,
#    'pressure': 1022,
#    'humidity': 43,
#    'dew_point': 10.35,
#    'clouds': 0,
#    'visibility': 10000,
#    'wind_speed': 3.34,
#    'wind_deg': 37,
#    'weather': [{'id': 800,
#      'main': 'Clear',
#      'description': 'cielo claro',
#      'icon': '01d'}],
#    'pop': 0},
#   {'dt': 1601575200,
#    'temp': 24.44,
#    'feels_like': 22.09,
#    'pressure': 1022,
#    'humidity': 40,
#    'dew_point': 10.03,
#    'clouds': 0,
#    'visibility': 10000,
#    'wind_speed': 3.4,
#    'wind_deg': 28,
#    'weather': [{'id': 800,
#      'main': 'Clear',
#      'description': 'cielo claro',
#      'icon': '01d'}],
#    'pop': 0},
#   {'dt': 1601578800,
#    'temp': 25.19,
#    'feels_like': 22.96,
#    'pressure': 1022,
#    'humidity': 38,
#    'dew_point': 10.06,
#    'clouds': 0,
#    'visibility': 10000,
#    'wind_speed': 3.2,
#    'wind_deg': 20,
#    'weather': [{'id': 800,
#      'main': 'Clear',
#      'description': 'cielo claro',
#      'icon': '01d'}],
#    'pop': 0},
#   {'dt': 1601582400,
#    'temp': 25.59,
#    'feels_like': 23.38,
#    'pressure': 1021,
#    'humidity': 36,
#    'dew_point': 9.66,
#    'clouds': 0,
#    'visibility': 10000,
#    'wind_speed': 3,
#    'wind_deg': 16,
#    'weather': [{'id': 800,
#      'main': 'Clear',
#      'description': 'cielo claro',
#      'icon': '01d'}],
#    'pop': 0},
#   {'dt': 1601586000,
#    'temp': 25.6,
#    'feels_like': 23.14,
#    'pressure': 1020,
#    'humidity': 36,
#    'dew_point': 9.81,
#    'clouds': 0,
#    'visibility': 10000,
#    'wind_speed': 3.35,
#    'wind_deg': 9,
#    'weather': [{'id': 800,
#      'main': 'Clear',
#      'description': 'cielo claro',
#      'icon': '01d'}],
#    'pop': 0},
#   {'dt': 1601589600,
#    'temp': 24.92,
#    'feels_like': 23.41,
#    'pressure': 1020,
#    'humidity': 44,
#    'dew_point': 11.89,
#    'clouds': 0,
#    'visibility': 10000,
#    'wind_speed': 2.96,
#    'wind_deg': 6,
#    'weather': [{'id': 800,
#      'main': 'Clear',
#      'description': 'cielo claro',
#      'icon': '01d'}],
#    'pop': 0},
#   {'dt': 1601593200,
#    'temp': 22.22,
#    'feels_like': 20.49,
#    'pressure': 1020,
#    'humidity': 50,
#    'dew_point': 11.5,
#    'clouds': 0,
#    'visibility': 10000,
#    'wind_speed': 3.06,
#    'wind_deg': 0,
#    'weather': [{'id': 800,
#      'main': 'Clear',
#      'description': 'cielo claro',
#      'icon': '01d'}],
#    'pop': 0},
#   {'dt': 1601596800,
#    'temp': 18.78,
#    'feels_like': 16.24,
#    'pressure': 1021,
#    'humidity': 53,
#    'dew_point': 9.16,
#    'clouds': 0,
#    'visibility': 10000,
#    'wind_speed': 3.31,
#    'wind_deg': 350,
#    'weather': [{'id': 800,
#      'main': 'Clear',
#      'description': 'cielo claro',
#      'icon': '01d'}],
#    'pop': 0},
#   {'dt': 1601600400,
#    'temp': 17.36,
#    'feels_like': 14.25,
#    'pressure': 1022,
#    'humidity': 52,
#    'dew_point': 7.63,
#    'clouds': 0,
#    'visibility': 10000,
#    'wind_speed': 3.58,
#    'wind_deg': 350,
#    'weather': [{'id': 800,
#      'main': 'Clear',
#      'description': 'cielo claro',
#      'icon': '01n'}],
#    'pop': 0},
#   {'dt': 1601604000,
#    'temp': 16.51,
#    'feels_like': 13.07,
#    'pressure': 1023,
#    'humidity': 51,
#    'dew_point': 6.61,
#    'clouds': 0,
#    'visibility': 10000,
#    'wind_speed': 3.7,
#    'wind_deg': 354,
#    'weather': [{'id': 800,
#      'main': 'Clear',
#      'description': 'cielo claro',
#      'icon': '01n'}],
#    'pop': 0},
#   {'dt': 1601607600,
#    'temp': 15.77,
#    'feels_like': 12.09,
#    'pressure': 1023,
#    'humidity': 51,
#    'dew_point': 5.78,
#    'clouds': 0,
#    'visibility': 10000,
#    'wind_speed': 3.84,
#    'wind_deg': 358,
#    'weather': [{'id': 800,
#      'main': 'Clear',
#      'description': 'cielo claro',
#      'icon': '01n'}],
#    'pop': 0},
#   {'dt': 1601611200,
#    'temp': 14.71,
#    'feels_like': 10.92,
#    'pressure': 1023,
#    'humidity': 52,
#    'dew_point': 5.2,
#    'clouds': 0,
#    'visibility': 10000,
#    'wind_speed': 3.79,
#    'wind_deg': 358,
#    'weather': [{'id': 800,
#      'main': 'Clear',
#      'description': 'cielo claro',
#      'icon': '01n'}],
#    'pop': 0},
#   {'dt': 1601614800,
#    'temp': 13.69,
#    'feels_like': 10.07,
#    'pressure': 1024,
#    'humidity': 56,
#    'dew_point': 5.2,
#    'clouds': 0,
#    'visibility': 10000,
#    'wind_speed': 3.58,
#    'wind_deg': 359,
#    'weather': [{'id': 800,
#      'main': 'Clear',
#      'description': 'cielo claro',
#      'icon': '01n'}],
#    'pop': 0},
#   {'dt': 1601618400,
#    'temp': 12.88,
#    'feels_like': 9.29,
#    'pressure': 1024,
#    'humidity': 59,
#    'dew_point': 5.1,
#    'clouds': 0,
#    'visibility': 10000,
#    'wind_speed': 3.54,
#    'wind_deg': 5,
#    'weather': [{'id': 800,
#      'main': 'Clear',
#      'description': 'cielo claro',
#      'icon': '01n'}],
#    'pop': 0},
#   {'dt': 1601622000,
#    'temp': 12.21,
#    'feels_like': 8.75,
#    'pressure': 1025,
#    'humidity': 60,
#    'dew_point': 4.86,
#    'clouds': 0,
#    'visibility': 10000,
#    'wind_speed': 3.25,
#    'wind_deg': 12,
#    'weather': [{'id': 800,
#      'main': 'Clear',
#      'description': 'cielo claro',
#      'icon': '01n'}],
#    'pop': 0},
#   {'dt': 1601625600,
#    'temp': 11.58,
#    'feels_like': 8.23,
#    'pressure': 1024,
#    'humidity': 62,
#    'dew_point': 4.64,
#    'clouds': 0,
#    'visibility': 10000,
#    'wind_speed': 3.05,
#    'wind_deg': 20,
#    'weather': [{'id': 800,
#      'main': 'Clear',
#      'description': 'cielo claro',
#      'icon': '01n'}],
#    'pop': 0},
#   {'dt': 1601629200,
#    'temp': 10.97,
#    'feels_like': 7.76,
#    'pressure': 1024,
#    'humidity': 64,
#    'dew_point': 4.55,
#    'clouds': 0,
#    'visibility': 10000,
#    'wind_speed': 2.82,
#    'wind_deg': 30,
#    'weather': [{'id': 800,
#      'main': 'Clear',
#      'description': 'cielo claro',
#      'icon': '01n'}],
#    'pop': 0},
#   {'dt': 1601632800,
#    'temp': 10.42,
#    'feels_like': 7.49,
#    'pressure': 1024,
#    'humidity': 66,
#    'dew_point': 4.37,
#    'clouds': 0,
#    'visibility': 10000,
#    'wind_speed': 2.4,
#    'wind_deg': 38,
#    'weather': [{'id': 800,
#      'main': 'Clear',
#      'description': 'cielo claro',
#      'icon': '01n'}],
#    'pop': 0},
#   {'dt': 1601636400,
#    'temp': 9.86,
#    'feels_like': 6.91,
#    'pressure': 1024,
#    'humidity': 67,
#    'dew_point': 4.09,
#    'clouds': 0,
#    'visibility': 10000,
#    'wind_speed': 2.33,
#    'wind_deg': 29,
#    'weather': [{'id': 800,
#      'main': 'Clear',
#      'description': 'cielo claro',
#      'icon': '01n'}],
#    'pop': 0},
#   {'dt': 1601640000,
#    'temp': 9.28,
#    'feels_like': 6.27,
#    'pressure': 1025,
#    'humidity': 68,
#    'dew_point': 3.84,
#    'clouds': 0,
#    'visibility': 10000,
#    'wind_speed': 2.33,
#    'wind_deg': 24,
#    'weather': [{'id': 800,
#      'main': 'Clear',
#      'description': 'cielo claro',
#      'icon': '01n'}],
#    'pop': 0},
#   {'dt': 1601643600,
#    'temp': 9.75,
#    'feels_like': 6.87,
#    'pressure': 1025,
#    'humidity': 71,
#    'dew_point': 4.9,
#    'clouds': 0,
#    'visibility': 10000,
#    'wind_speed': 2.43,
#    'wind_deg': 21,
#    'weather': [{'id': 800,
#      'main': 'Clear',
#      'description': 'cielo claro',
#      'icon': '01d'}],
#    'pop': 0},
#   {'dt': 1601647200,
#    'temp': 12.28,
#    'feels_like': 9.38,
#    'pressure': 1026,
#    'humidity': 64,
#    'dew_point': 5.79,
#    'clouds': 0,
#    'visibility': 10000,
#    'wind_speed': 2.73,
#    'wind_deg': 38,
#    'weather': [{'id': 800,
#      'main': 'Clear',
#      'description': 'cielo claro',
#      'icon': '01d'}],
#    'pop': 0},
#   {'dt': 1601650800,
#    'temp': 14.78,
#    'feels_like': 11.99,
#    'pressure': 1025,
#    'humidity': 57,
#    'dew_point': 6.48,
#    'clouds': 0,
#    'visibility': 10000,
#    'wind_speed': 2.78,
#    'wind_deg': 53,
#    'weather': [{'id': 800,
#      'main': 'Clear',
#      'description': 'cielo claro',
#      'icon': '01d'}],
#    'pop': 0},
#   {'dt': 1601654400,
#    'temp': 16.65,
#    'feels_like': 13.73,
#    'pressure': 1025,
#    'humidity': 51,
#    'dew_point': 6.53,
#    'clouds': 5,
#    'visibility': 10000,
#    'wind_speed': 3.01,
#    'wind_deg': 60,
#    'weather': [{'id': 800,
#      'main': 'Clear',
#      'description': 'cielo claro',
#      'icon': '01d'}],
#    'pop': 0},
#   {'dt': 1601658000,
#    'temp': 18.01,
#    'feels_like': 15.12,
#    'pressure': 1025,
#    'humidity': 45,
#    'dew_point': 6,
#    'clouds': 4,
#    'visibility': 10000,
#    'wind_speed': 2.79,
#    'wind_deg': 60,
#    'weather': [{'id': 800,
#      'main': 'Clear',
#      'description': 'cielo claro',
#      'icon': '01d'}],
#    'pop': 0},
#   {'dt': 1601661600,
#    'temp': 19.07,
#    'feels_like': 16.32,
#    'pressure': 1024,
#    'humidity': 41,
#    'dew_point': 5.61,
#    'clouds': 3,
#    'visibility': 10000,
#    'wind_speed': 2.47,
#    'wind_deg': 53,
#    'weather': [{'id': 800,
#      'main': 'Clear',
#      'description': 'cielo claro',
#      'icon': '01d'}],
#    'pop': 0},
#   {'dt': 1601665200,
#    'temp': 19.91,
#    'feels_like': 17.31,
#    'pressure': 1023,
#    'humidity': 39,
#    'dew_point': 5.63,
#    'clouds': 17,
#    'visibility': 10000,
#    'wind_speed': 2.26,
#    'wind_deg': 49,
#    'weather': [{'id': 801,
#      'main': 'Clouds',
#      'description': 'algo de nubes',
#      'icon': '02d'}],
#    'pop': 0},
#   {'dt': 1601668800,
#    'temp': 20.26,
#    'feels_like': 17.73,
#    'pressure': 1022,
#    'humidity': 38,
#    'dew_point': 5.7,
#    'clouds': 45,
#    'visibility': 10000,
#    'wind_speed': 2.14,
#    'wind_deg': 55,
#    'weather': [{'id': 802,
#      'main': 'Clouds',
#      'description': 'nubes dispersas',
#      'icon': '03d'}],
#    'pop': 0},
#   {'dt': 1601672400,
#    'temp': 20.33,
#    'feels_like': 18.16,
#    'pressure': 1021,
#    'humidity': 38,
#    'dew_point': 5.78,
#    'clouds': 62,
#    'visibility': 10000,
#    'wind_speed': 1.65,
#    'wind_deg': 61,
#    'weather': [{'id': 803,
#      'main': 'Clouds',
#      'description': 'nubes rotas',
#      'icon': '04d'}],
#    'pop': 0},
#   {'dt': 1601676000,
#    'temp': 20.32,
#    'feels_like': 18.5,
#    'pressure': 1020,
#    'humidity': 39,
#    'dew_point': 6.13,
#    'clouds': 47,
#    'visibility': 10000,
#    'wind_speed': 1.26,
#    'wind_deg': 77,
#    'weather': [{'id': 802,
#      'main': 'Clouds',
#      'description': 'nubes dispersas',
#      'icon': '03d'}],
#    'pop': 0},
#   {'dt': 1601679600,
#    'temp': 19.32,
#    'feels_like': 18.3,
#    'pressure': 1020,
#    'humidity': 50,
#    'dew_point': 8.93,
#    'clouds': 37,
#    'visibility': 10000,
#    'wind_speed': 1.02,
#    'wind_deg': 125,
#    'weather': [{'id': 802,
#      'main': 'Clouds',
#      'description': 'nubes dispersas',
#      'icon': '03d'}],
#    'pop': 0},
#   {'dt': 1601683200,
#    'temp': 15.59,
#    'feels_like': 13.62,
#    'pressure': 1020,
#    'humidity': 50,
#    'dew_point': 5.34,
#    'clouds': 36,
#    'visibility': 10000,
#    'wind_speed': 1.27,
#    'wind_deg': 135,
#    'weather': [{'id': 802,
#      'main': 'Clouds',
#      'description': 'nubes dispersas',
#      'icon': '03n'}],
#    'pop': 0},
#   {'dt': 1601686800,
#    'temp': 15,
#    'feels_like': 12.35,
#    'pressure': 1021,
#    'humidity': 51,
#    'dew_point': 4.97,
#    'clouds': 77,
#    'visibility': 10000,
#    'wind_speed': 2.17,
#    'wind_deg': 118,
#    'weather': [{'id': 803,
#      'main': 'Clouds',
#      'description': 'nubes rotas',
#      'icon': '04n'}],
#    'pop': 0},
#   {'dt': 1601690400,
#    'temp': 14.22,
#    'feels_like': 11.57,
#    'pressure': 1021,
#    'humidity': 53,
#    'dew_point': 4.96,
#    'clouds': 87,
#    'visibility': 10000,
#    'wind_speed': 2.11,
#    'wind_deg': 120,
#    'weather': [{'id': 804,
#      'main': 'Clouds',
#      'description': 'nubes',
#      'icon': '04n'}],
#    'pop': 0},
#   {'dt': 1601694000,
#    'temp': 13.32,
#    'feels_like': 10.46,
#    'pressure': 1021,
#    'humidity': 56,
#    'dew_point': 4.93,
#    'clouds': 61,
#    'visibility': 10000,
#    'wind_speed': 2.4,
#    'wind_deg': 124,
#    'weather': [{'id': 803,
#      'main': 'Clouds',
#      'description': 'nubes rotas',
#      'icon': '04n'}],
#    'pop': 0},
#   {'dt': 1601697600,
#    'temp': 13.14,
#    'feels_like': 10.13,
#    'pressure': 1021,
#    'humidity': 56,
#    'dew_point': 4.81,
#    'clouds': 69,
#    'visibility': 10000,
#    'wind_speed': 2.57,
#    'wind_deg': 132,
#    'weather': [{'id': 803,
#      'main': 'Clouds',
#      'description': 'nubes rotas',
#      'icon': '04n'}],
#    'pop': 0},
#   {'dt': 1601701200,
#    'temp': 12.61,
#    'feels_like': 9.29,
#    'pressure': 1021,
#    'humidity': 58,
#    'dew_point': 4.6,
#    'clouds': 73,
#    'visibility': 10000,
#    'wind_speed': 3.02,
#    'wind_deg': 127,
#    'weather': [{'id': 803,
#      'main': 'Clouds',
#      'description': 'nubes rotas',
#      'icon': '04n'}],
#    'pop': 0},
#   {'dt': 1601704800,
#    'temp': 11.66,
#    'feels_like': 8.23,
#    'pressure': 1021,
#    'humidity': 62,
#    'dew_point': 4.82,
#    'clouds': 60,
#    'visibility': 10000,
#    'wind_speed': 3.18,
#    'wind_deg': 130,
#    'weather': [{'id': 803,
#      'main': 'Clouds',
#      'description': 'nubes rotas',
#      'icon': '04n'}],
#    'pop': 0},
#   {'dt': 1601708400,
#    'temp': 11.02,
#    'feels_like': 8.27,
#    'pressure': 1021,
#    'humidity': 68,
#    'dew_point': 5.39,
#    'clouds': 66,
#    'visibility': 10000,
#    'wind_speed': 2.42,
#    'wind_deg': 148,
#    'weather': [{'id': 803,
#      'main': 'Clouds',
#      'description': 'nubes rotas',
#      'icon': '04n'}],
#    'pop': 0},
#   {'dt': 1601712000,
#    'temp': 10.68,
#    'feels_like': 7.73,
#    'pressure': 1021,
#    'humidity': 71,
#    'dew_point': 5.8,
#    'clouds': 46,
#    'visibility': 10000,
#    'wind_speed': 2.79,
#    'wind_deg': 151,
#    'weather': [{'id': 802,
#      'main': 'Clouds',
#      'description': 'nubes dispersas',
#      'icon': '03n'}],
#    'pop': 0},
#   {'dt': 1601715600,
#    'temp': 10.57,
#    'feels_like': 7.6,
#    'pressure': 1020,
#    'humidity': 73,
#    'dew_point': 6.05,
#    'clouds': 64,
#    'visibility': 10000,
#    'wind_speed': 2.91,
#    'wind_deg': 147,
#    'weather': [{'id': 803,
#      'main': 'Clouds',
#      'description': 'nubes rotas',
#      'icon': '04n'}],
#    'pop': 0}],
#  'daily': [{'dt': 1601575200,
#    'sunrise': 1601554243,
#    'sunset': 1601596822,
#    'temp': {'day': 23.79,
#     'min': 14.34,
#     'max': 25.51,
#     'night': 15.77,
#     'eve': 18.78,
#     'morn': 14.89},
#    'feels_like': {'day': 21.58, 'night': 12.09, 'eve': 16.24, 'morn': 13.18},
#    'pressure': 1022,
#    'humidity': 43,
#    'dew_point': 10.47,
#    'wind_speed': 3.4,
#    'wind_deg': 28,
#    'weather': [{'id': 800,
#      'main': 'Clear',
#      'description': 'cielo claro',
#      'icon': '01d'}],
#    'clouds': 0,
#    'pop': 0,
#    'uvi': 6.87},
#   {'dt': 1601661600,
#    'sunrise': 1601640685,
#    'sunset': 1601683141,
#    'temp': {'day': 19.07,
#     'min': 9.28,
#     'max': 20.33,
#     'night': 13.32,
#     'eve': 15.59,
#     'morn': 9.28},
#    'feels_like': {'day': 16.32, 'night': 10.46, 'eve': 13.62, 'morn': 6.27},
#    'pressure': 1024,
#    'humidity': 41,
#    'dew_point': 5.61,
#    'wind_speed': 2.47,
#    'wind_deg': 53,
#    'weather': [{'id': 800,
#      'main': 'Clear',
#      'description': 'cielo claro',
#      'icon': '01d'}],
#    'clouds': 3,
#    'pop': 0,
#    'uvi': 6.28},
#   {'dt': 1601748000,
#    'sunrise': 1601727127,
#    'sunset': 1601769460,
#    'temp': {'day': 21.46,
#     'min': 9.51,
#     'max': 23.61,
#     'night': 15.58,
#     'eve': 18.21,
#     'morn': 9.51},
#    'feels_like': {'day': 18.81, 'night': 13.78, 'eve': 16.45, 'morn': 6.76},
#    'pressure': 1019,
#    'humidity': 48,
#    'dew_point': 10.09,
#    'wind_speed': 3.85,
#    'wind_deg': 157,
#    'weather': [{'id': 801,
#      'main': 'Clouds',
#      'description': 'algo de nubes',
#      'icon': '02d'}],
#    'clouds': 18,
#    'pop': 0,
#    'uvi': 6.4},
#   {'dt': 1601834400,
#    'sunrise': 1601813569,
#    'sunset': 1601855780,
#    'temp': {'day': 19.87,
#     'min': 13.66,
#     'max': 23.56,
#     'night': 16.79,
#     'eve': 19.22,
#     'morn': 13.86},
#    'feels_like': {'day': 19.61, 'night': 17.43, 'eve': 20.16, 'morn': 12.92},
#    'pressure': 1019,
#    'humidity': 66,
#    'dew_point': 13.56,
#    'wind_speed': 1.85,
#    'wind_deg': 249,
#    'weather': [{'id': 804,
#      'main': 'Clouds',
#      'description': 'nubes',
#      'icon': '04d'}],
#    'clouds': 95,
#    'pop': 0.12,
#    'uvi': 6.41},
#   {'dt': 1601920800,
#    'sunrise': 1601900012,
#    'sunset': 1601942100,
#    'temp': {'day': 24.16,
#     'min': 13.23,
#     'max': 24.98,
#     'night': 16.67,
#     'eve': 19.46,
#     'morn': 13.23},
#    'feels_like': {'day': 23.19, 'night': 15.03, 'eve': 18.71, 'morn': 12.68},
#    'pressure': 1020,
#    'humidity': 51,
#    'dew_point': 13.63,
#    'wind_speed': 2.9,
#    'wind_deg': 120,
#    'weather': [{'id': 800,
#      'main': 'Clear',
#      'description': 'cielo claro',
#      'icon': '01d'}],
#    'clouds': 0,
#    'pop': 0,
#    'uvi': 6.46},
#   {'dt': 1602007200,
#    'sunrise': 1601986455,
#    'sunset': 1602028421,
#    'temp': {'day': 25.29,
#     'min': 12.78,
#     'max': 27.11,
#     'night': 19.4,
#     'eve': 21.34,
#     'morn': 12.78},
#    'feels_like': {'day': 24.96, 'night': 18.76, 'eve': 21.32, 'morn': 11.39},
#    'pressure': 1016,
#    'humidity': 49,
#    'dew_point': 14.06,
#    'wind_speed': 2.18,
#    'wind_deg': 154,
#    'weather': [{'id': 800,
#      'main': 'Clear',
#      'description': 'cielo claro',
#      'icon': '01d'}],
#    'clouds': 0,
#    'pop': 0,
#    'uvi': 6.31},
#   {'dt': 1602093600,
#    'sunrise': 1602072899,
#    'sunset': 1602114742,
#    'temp': {'day': 28.72,
#     'min': 15.81,
#     'max': 29.43,
#     'night': 21.49,
#     'eve': 23.5,
#     'morn': 15.81},
#    'feels_like': {'day': 30.2, 'night': 22.14, 'eve': 24.36, 'morn': 15.32},
#    'pressure': 1017,
#    'humidity': 47,
#    'dew_point': 16.6,
#    'wind_speed': 0.87,
#    'wind_deg': 148,
#    'weather': [{'id': 800,
#      'main': 'Clear',
#      'description': 'cielo claro',
#      'icon': '01d'}],
#    'clouds': 0,
#    'pop': 0,
#    'uvi': 6.38},
#   {'dt': 1602180000,
#    'sunrise': 1602159343,
#    'sunset': 1602201064,
#    'temp': {'day': 28.45,
#     'min': 17.62,
#     'max': 29.22,
#     'night': 23.59,
#     'eve': 23.59,
#     'morn': 17.62},
#    'feels_like': {'day': 29.37, 'night': 25.12, 'eve': 25.12, 'morn': 18.43},
#    'pressure': 1018,
#    'humidity': 50,
#    'dew_point': 17.23,
#    'wind_speed': 2.09,
#    'wind_deg': 129,
#    'weather': [{'id': 800,
#      'main': 'Clear',
#      'description': 'cielo claro',
#      'icon': '01d'}],
#    'clouds': 0,
#    'pop': 0,
#    'uvi': 6.31}]}

# %% [markdown]
# ### Historical weather data
#
# Para uno de los 5 días previos a la solicitud de los datos. Histórico horario

# %%
request=requests.get('http://api.openweathermap.org/data/2.5/onecall/timemachine?lat=60.99&lon=30.9&dt=1601251200&appid=de359429e61129a9779f33cd9e7b2611&units=metric&lang=es')
request.json()
# Out:
# {'lat': 60.99,
#  'lon': 30.9,
#  'timezone': 'Europe/Moscow',
#  'timezone_offset': 10800,
#  'current': {'dt': 1601251200,
#   'sunrise': 1601265341,
#   'sunset': 1601307489,
#   'temp': 10.56,
#   'feels_like': 5.56,
#   'pressure': 1016,
#   'humidity': 80,
#   'dew_point': 7.26,
#   'uvi': 1.56,
#   'clouds': 30,
#   'wind_speed': 6.23,
#   'wind_deg': 146,
#   'weather': [{'id': 802,
#     'main': 'Clouds',
#     'description': 'nubes dispersas',
#     'icon': '03n'}]},
#  'hourly': [{'dt': 1601251200,
#    'temp': 10.56,
#    'feels_like': 5.56,
#    'pressure': 1016,
#    'humidity': 80,
#    'dew_point': 7.26,
#    'clouds': 30,
#    'wind_speed': 6.23,
#    'wind_deg': 146,
#    'weather': [{'id': 802,
#      'main': 'Clouds',
#      'description': 'nubes dispersas',
#      'icon': '03n'}]},
#   {'dt': 1601254800,
#    'temp': 10.56,
#    'feels_like': 5.59,
#    'pressure': 1016,
#    'humidity': 80,
#    'dew_point': 7.26,
#    'clouds': 0,
#    'wind_speed': 6.19,
#    'wind_deg': 139,
#    'weather': [{'id': 800,
#      'main': 'Clear',
#      'description': 'cielo claro',
#      'icon': '01n'}]},
#   {'dt': 1601258400,
#    'temp': 10,
#    'feels_like': 4.7,
#    'pressure': 1016,
#    'humidity': 80,
#    'dew_point': 6.71,
#    'clouds': 0,
#    'wind_speed': 6.48,
#    'wind_deg': 136,
#    'weather': [{'id': 800,
#      'main': 'Clear',
#      'description': 'cielo claro',
#      'icon': '01n'}]},
#   {'dt': 1601262000,
#    'temp': 10,
#    'feels_like': 4.69,
#    'pressure': 1015,
#    'humidity': 81,
#    'dew_point': 6.89,
#    'clouds': 0,
#    'wind_speed': 6.56,
#    'wind_deg': 130,
#    'weather': [{'id': 800,
#      'main': 'Clear',
#      'description': 'cielo claro',
#      'icon': '01n'}]},
#   {'dt': 1601265600,
#    'temp': 10,
#    'feels_like': 4.06,
#    'pressure': 1016,
#    'humidity': 82,
#    'dew_point': 7.07,
#    'clouds': 0,
#    'wind_speed': 7.51,
#    'wind_deg': 134,
#    'weather': [{'id': 800,
#      'main': 'Clear',
#      'description': 'cielo claro',
#      'icon': '01d'}]},
#   {'dt': 1601269200,
#    'temp': 10,
#    'feels_like': 4.23,
#    'pressure': 1016,
#    'humidity': 82,
#    'dew_point': 7.07,
#    'clouds': 0,
#    'wind_speed': 7.27,
#    'wind_deg': 135,
#    'weather': [{'id': 800,
#      'main': 'Clear',
#      'description': 'cielo claro',
#      'icon': '01d'}]},
#   {'dt': 1601272800,
#    'temp': 11.11,
#    'feels_like': 5.6,
#    'pressure': 1016,
#    'humidity': 82,
#    'dew_point': 8.16,
#    'clouds': 0,
#    'wind_speed': 7.26,
#    'wind_deg': 131,
#    'weather': [{'id': 800,
#      'main': 'Clear',
#      'description': 'cielo claro',
#      'icon': '01d'}]},
#   {'dt': 1601276400,
#    'temp': 12.78,
#    'feels_like': 7.77,
#    'pressure': 1016,
#    'humidity': 82,
#    'dew_point': 9.79,
#    'clouds': 0,
#    'wind_speed': 7.14,
#    'wind_deg': 129,
#    'weather': [{'id': 800,
#      'main': 'Clear',
#      'description': 'cielo claro',
#      'icon': '01d'}]},
#   {'dt': 1601280000,
#    'temp': 12.78,
#    'feels_like': 7.78,
#    'pressure': 1016,
#    'humidity': 82,
#    'dew_point': 9.79,
#    'clouds': 0,
#    'wind_speed': 7.13,
#    'wind_deg': 125,
#    'weather': [{'id': 800,
#      'main': 'Clear',
#      'description': 'cielo claro',
#      'icon': '01d'}]},
#   {'dt': 1601283600,
#    'temp': 13.33,
#    'feels_like': 8.56,
#    'pressure': 1016,
#    'humidity': 82,
#    'dew_point': 10.33,
#    'clouds': 0,
#    'wind_speed': 7.01,
#    'wind_deg': 128,
#    'weather': [{'id': 800,
#      'main': 'Clear',
#      'description': 'cielo claro',
#      'icon': '01d'}]},
#   {'dt': 1601287200,
#    'temp': 12.78,
#    'feels_like': 8.09,
#    'pressure': 1016,
#    'humidity': 82,
#    'dew_point': 9.79,
#    'clouds': 0,
#    'wind_speed': 6.68,
#    'wind_deg': 125,
#    'weather': [{'id': 800,
#      'main': 'Clear',
#      'description': 'cielo claro',
#      'icon': '01d'}]},
#   {'dt': 1601290800,
#    'temp': 12.22,
#    'feels_like': 7.65,
#    'pressure': 1016,
#    'humidity': 81,
#    'dew_point': 9.06,
#    'clouds': 0,
#    'wind_speed': 6.24,
#    'wind_deg': 120,
#    'weather': [{'id': 800,
#      'main': 'Clear',
#      'description': 'cielo claro',
#      'icon': '01d'}]},
#   {'dt': 1601294400,
#    'temp': 12.22,
#    'feels_like': 7.67,
#    'pressure': 1016,
#    'humidity': 80,
#    'dew_point': 8.88,
#    'clouds': 0,
#    'wind_speed': 6.14,
#    'wind_deg': 117,
#    'weather': [{'id': 800,
#      'main': 'Clear',
#      'description': 'cielo claro',
#      'icon': '01d'}]},
#   {'dt': 1601298000,
#    'temp': 11.67,
#    'feels_like': 7.16,
#    'pressure': 1015,
#    'humidity': 77,
#    'dew_point': 7.78,
#    'clouds': 0,
#    'wind_speed': 5.7,
#    'wind_deg': 118,
#    'weather': [{'id': 800,
#      'main': 'Clear',
#      'description': 'cielo claro',
#      'icon': '01d'}]},
#   {'dt': 1601301600,
#    'temp': 11.11,
#    'feels_like': 6.38,
#    'pressure': 1015,
#    'humidity': 75,
#    'dew_point': 6.85,
#    'clouds': 0,
#    'wind_speed': 5.71,
#    'wind_deg': 120,
#    'weather': [{'id': 800,
#      'main': 'Clear',
#      'description': 'cielo claro',
#      'icon': '01d'}]},
#   {'dt': 1601305200,
#    'temp': 11.11,
#    'feels_like': 6.27,
#    'pressure': 1015,
#    'humidity': 74,
#    'dew_point': 6.66,
#    'clouds': 0,
#    'wind_speed': 5.8,
#    'wind_deg': 122,
#    'weather': [{'id': 800,
#      'main': 'Clear',
#      'description': 'cielo claro',
#      'icon': '01d'}]},
#   {'dt': 1601308800,
#    'temp': 10.56,
#    'feels_like': 5.23,
#    'pressure': 1015,
#    'humidity': 74,
#    'dew_point': 6.13,
#    'clouds': 0,
#    'wind_speed': 6.34,
#    'wind_deg': 127,
#    'weather': [{'id': 800,
#      'main': 'Clear',
#      'description': 'cielo claro',
#      'icon': '01n'}]},
#   {'dt': 1601312400,
#    'temp': 10,
#    'feels_like': 4.39,
#    'pressure': 1015,
#    'humidity': 76,
#    'dew_point': 5.97,
#    'clouds': 0,
#    'wind_speed': 6.69,
#    'wind_deg': 136,
#    'weather': [{'id': 800,
#      'main': 'Clear',
#      'description': 'cielo claro',
#      'icon': '01n'}]},
#   {'dt': 1601316000,
#    'temp': 10,
#    'feels_like': 4.51,
#    'pressure': 1015,
#    'humidity': 75,
#    'dew_point': 5.78,
#    'clouds': 0,
#    'wind_speed': 6.47,
#    'wind_deg': 133,
#    'weather': [{'id': 800,
#      'main': 'Clear',
#      'description': 'cielo claro',
#      'icon': '01n'}]},
#   {'dt': 1601319600,
#    'temp': 10,
#    'feels_like': 4.44,
#    'pressure': 1015,
#    'humidity': 78,
#    'dew_point': 6.35,
#    'clouds': 0,
#    'wind_speed': 6.73,
#    'wind_deg': 137,
#    'weather': [{'id': 800,
#      'main': 'Clear',
#      'description': 'cielo claro',
#      'icon': '01n'}]},
#   {'dt': 1601323200,
#    'temp': 9.44,
#    'feels_like': 4.24,
#    'pressure': 1015,
#    'humidity': 80,
#    'dew_point': 6.17,
#    'clouds': 0,
#    'wind_speed': 6.17,
#    'wind_deg': 147,
#    'weather': [{'id': 800,
#      'main': 'Clear',
#      'description': 'cielo claro',
#      'icon': '01n'}]},
#   {'dt': 1601326800,
#    'temp': 9.44,
#    'feels_like': 4.53,
#    'pressure': 1014,
#    'humidity': 80,
#    'dew_point': 6.17,
#    'clouds': 0,
#    'wind_speed': 5.75,
#    'wind_deg': 150,
#    'weather': [{'id': 800,
#      'main': 'Clear',
#      'description': 'cielo claro',
#      'icon': '01n'}]},
#   {'dt': 1601330400,
#    'temp': 8.89,
#    'feels_like': 3.73,
#    'pressure': 1014,
#    'humidity': 83,
#    'dew_point': 6.16,
#    'clouds': 0,
#    'wind_speed': 6.11,
#    'wind_deg': 152,
#    'weather': [{'id': 800,
#      'main': 'Clear',
#      'description': 'cielo claro',
#      'icon': '01n'}]},
#   {'dt': 1601334000,
#    'temp': 8.33,
#    'feels_like': 3.78,
#    'pressure': 1014,
#    'humidity': 84,
#    'dew_point': 5.79,
#    'clouds': 0,
#    'wind_speed': 5.12,
#    'wind_deg': 154,
#    'weather': [{'id': 800,
#      'main': 'Clear',
#      'description': 'cielo claro',
#      'icon': '01n'}]}]}

# %% [markdown]
# ![image.png](attachment:image.png)
