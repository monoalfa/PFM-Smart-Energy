# %% [markdown]
# # PFM: Requests - API Meteostat

# %% [markdown]
# The objective of this session is to understand how data can be retrieved from specific sources as REE API.
#
# To do so, we will use `requests` library and `json` libraries for Python. These libraries are considered as wrappers.
#
# Later on, we will use specific libraries for plotting as `matplotlib` and `datetime`.

# %%
# import requests library
import requests 
import json
# import plotting library
import matplotlib
import matplotlib.pyplot as plt 
from datetime import datetime, timedelta
# importamos Pandas y numpy!
import pandas as pd 
import numpy as np
# importamos time
import time

# %% [markdown]
# As we have seen before, when we work with APIs, we have to write the url we want to access.
#
# Most of the times, we need to add some headers to our requests that are required to get the information. The most important one is the **API Key**, which corresponds to our ID to access that API.

# %%
endpoint = 'https://api.meteostat.net'
get_stations = '/v2/stations/nearby?lat=28.1661&lon=-16.5013&limit=3'
headers = {'x-api-key':'erwezi3EUbckJZTIyEykn16bDspMbFg5'}

request = requests.get(endpoint+get_stations, headers=headers)
request.json()
# Out:
# {'meta': {'exec_time': 0.022, 'generated': '2020-10-07 15:10:07'},
#  'data': [{'id': '60025',
#    'name': {'en': 'Tenerife Sur'},
#    'active': True,
#    'distance': 14.4},
#   {'id': '60010', 'name': {'en': 'Izana'}, 'active': True, 'distance': 14.9},
#   {'id': '60015',
#    'name': {'en': 'Tenerife / Los Rodeos'},
#    'active': True,
#    'distance': 38}]}

# %% [markdown]
# After checking the stations nearby Arico - Santa cruz de tenerize, we found 3 different locations distributed along the island of Tenerife.

# %% [markdown]
# ### Historical weather data
#
# Historical hourly observations can be request for a particular weather station. Hourly data can be queried for a maximum of 10 days per request.

# %%
date_start = "2019-01-01"                # start date
date_end = "2019-01-10"                  # end date
indicator = str(60015)                   # INDICADOR

#id:60025 Tenerife Sur (Aeropuerto sur)
#id:60010 Izaña
#id:60015 Tenerife/Los Rodeos (Aeropuerto norte)

#Parámetros meteorológicos históricos observados por las estaciones en cuestión.

website = 'https://api.meteostat.net/v2/stations/hourly?station='+indicator+'&start='+date_start+'&end='+date_end
     
     
print('Checking dates: ' , date_start , "to" , date_end) # printing the date 

URL = website # host website
HEADERS = {'x-api-key':'erwezi3EUbckJZTIyEykn16bDspMbFg5'}
#PARAMS = {'date':date}

# Runs the request to get the total URL with access token
response = requests.get(url = URL, headers = HEADERS)#, params = PARAMS)
response.json()
# Out:
# Checking dates:  2019-01-01 to 2019-01-10
# {'meta': {'source': 'National Oceanic and Atmospheric Administration, Deutscher Wetterdienst',
#   'exec_time': 0.101,
#   'generated': '2020-10-07 15:26:36'},
#  'data': [{'time': '2019-01-01 00:00:00',
#    'temp': 11.7,
#    'dwpt': 4.2,
#    'rhum': 60,
#    'prcp': None,
#    'snow': None,
#    'wdir': 130,
#    'wspd': 13,
#    'wpgt': None,
#    'pres': 1023.5,
#    'tsun': None,
#    'coco': None},
#   {'time': '2019-01-01 01:00:00',
#    'temp': 12.6,
#    'dwpt': -1.4,
#    'rhum': 38,
#    'prcp': None,
#    'snow': None,
#    'wdir': 140,
#    'wspd': 14.8,
#    'wpgt': None,
#    'pres': 1023.3,
#    'tsun': None,
#    'coco': None},
#   {'time': '2019-01-01 02:00:00',
#    'temp': 12.1,
#    'dwpt': -2.2,
#    'rhum': 37,
#    'prcp': None,
#    'snow': None,
#    'wdir': 160,
#    'wspd': 13,
#    'wpgt': None,
#    'pres': 1023.8,
#    'tsun': None,
#    'coco': None},
#   {'time': '2019-01-01 03:00:00',
#    'temp': 13.2,
#    'dwpt': -3.2,
#    'rhum': 32,
#    'prcp': None,
#    'snow': None,
#    'wdir': 170,
#    'wspd': 14.8,
#    'wpgt': None,
#    'pres': 1023.5,
#    'tsun': None,
#    'coco': None},
#   {'time': '2019-01-01 04:00:00',
#    'temp': 12,
#    'dwpt': -2.6,
#    'rhum': 36,
#    'prcp': None,
#    'snow': None,
#    'wdir': 160,
#    'wspd': 9.4,
#    'wpgt': None,
#    'pres': 1023.8,
#    'tsun': None,
#    'coco': None},
#   {'time': '2019-01-01 05:00:00',
#    'temp': 11.1,
#    'dwpt': -1.3,
#    'rhum': 42,
#    'prcp': None,
#    'snow': None,
#    'wdir': 150,
#    'wspd': 9.4,
#    'wpgt': None,
#    'pres': 1023.9,
#    'tsun': None,
#    'coco': None},
#   {'time': '2019-01-01 06:00:00',
#    'temp': 10.7,
#    'dwpt': 1,
#    'rhum': 51,
#    'prcp': None,
#    'snow': None,
#    'wdir': 150,
#    'wspd': 11.2,
#    'wpgt': None,
#    'pres': 1024.2,
#    'tsun': None,
#    'coco': None},
#   {'time': '2019-01-01 07:00:00',
#    'temp': 11.1,
#    'dwpt': 4.1,
#    'rhum': 62,
#    'prcp': None,
#    'snow': None,
#    'wdir': 150,
#    'wspd': 11.2,
#    'wpgt': None,
#    'pres': 1024.8,
#    'tsun': None,
#    'coco': None},
#   {'time': '2019-01-01 08:00:00',
#    'temp': 10.5,
#    'dwpt': 7.4,
#    'rhum': 81,
#    'prcp': None,
#    'snow': None,
#    'wdir': 160,
#    'wspd': 9.4,
#    'wpgt': None,
#    'pres': 1025.9,
#    'tsun': None,
#    'coco': None},
#   {'time': '2019-01-01 09:00:00',
#    'temp': 16,
#    'dwpt': -1.6,
#    'rhum': 30,
#    'prcp': None,
#    'snow': None,
#    'wdir': 150,
#    'wspd': 16.6,
#    'wpgt': None,
#    'pres': 1025.7,
#    'tsun': None,
#    'coco': None},
#   {'time': '2019-01-01 10:00:00',
#    'temp': 16.2,
#    'dwpt': 7.1,
#    'rhum': 55,
#    'prcp': None,
#    'snow': None,
#    'wdir': 140,
#    'wspd': 18.4,
#    'wpgt': None,
#    'pres': 1026.3,
#    'tsun': None,
#    'coco': None},
#   {'time': '2019-01-01 11:00:00',
#    'temp': 16.6,
#    'dwpt': 9.3,
#    'rhum': 62,
#    'prcp': None,
#    'snow': None,
#    'wdir': 150,
#    'wspd': 25.9,
#    'wpgt': None,
#    'pres': 1026.5,
#    'tsun': None,
#    'coco': None},
#   {'time': '2019-01-01 12:00:00',
#    'temp': 17.5,
#    'dwpt': 9.1,
#    'rhum': 58,
#    'prcp': None,
#    'snow': None,
#    'wdir': 140,
#    'wspd': 24.1,
#    'wpgt': None,
#    'pres': 1025.6,
#    'tsun': None,
#    'coco': None},
#   {'time': '2019-01-01 13:00:00',
#    'temp': 17.1,
#    'dwpt': 7.4,
#    'rhum': 53,
#    'prcp': None,
#    'snow': None,
#    'wdir': 140,
#    'wspd': 22.3,
#    'wpgt': None,
#    'pres': 1025.1,
#    'tsun': None,
#    'coco': None},
#   {'time': '2019-01-01 14:00:00',
#    'temp': 17.2,
#    'dwpt': 7.5,
#    'rhum': 53,
#    'prcp': None,
#    'snow': None,
#    'wdir': 150,
#    'wspd': 18.4,
#    'wpgt': None,
#    'pres': 1024.9,
#    'tsun': None,
#    'coco': None},
#   {'time': '2019-01-01 15:00:00',
#    'temp': 18.7,
#    'dwpt': 5.2,
#    'rhum': 41,
#    'prcp': None,
#    'snow': None,
#    'wdir': 140,
#    'wspd': 18.4,
#    'wpgt': None,
#    'pres': 1024.3,
#    'tsun': None,
#    'coco': None},
#   {'time': '2019-01-01 16:00:00',
#    'temp': 18.6,
#    'dwpt': 4.4,
#    'rhum': 39,
#    'prcp': None,
#    'snow': None,
#    'wdir': 140,
#    'wspd': 14.8,
#    'wpgt': None,
#    'pres': 1024.4,
#    'tsun': None,
#    'coco': None},
#   {'time': '2019-01-01 17:00:00',
#    'temp': 18.1,
#    'dwpt': 4.3,
#    'rhum': 40,
#    'prcp': None,
#    'snow': None,
#    'wdir': 140,
#    'wspd': 13,
#    'wpgt': None,
#    'pres': 1024.8,
#    'tsun': None,
#    'coco': None},
#   {'time': '2019-01-01 18:00:00',
#    'temp': 15.5,
#    'dwpt': 5.7,
#    'rhum': 52,
#    'prcp': None,
#    'snow': None,
#    'wdir': 160,
#    'wspd': 9.4,
#    'wpgt': None,
#    'pres': 1026.2,
#    'tsun': None,
#    'coco': None},
#   {'time': '2019-01-01 19:00:00',
#    'temp': 15,
#    'dwpt': 0.8,
#    'rhum': 38,
#    'prcp': None,
#    'snow': None,
#    'wdir': 180,
#    'wspd': 7.6,
#    'wpgt': None,
#    'pres': 1026.9,
#    'tsun': None,
#    'coco': None},
#   {'time': '2019-01-01 20:00:00',
#    'temp': 13.2,
#    'dwpt': 2.4,
#    'rhum': 48,
#    'prcp': None,
#    'snow': None,
#    'wdir': 150,
#    'wspd': 3.6,
#    'wpgt': None,
#    'pres': 1028.1,
#    'tsun': None,
#    'coco': None},
#   {'time': '2019-01-01 21:00:00',
#    'temp': 13,
#    'dwpt': 3.1,
#    'rhum': 51,
#    'prcp': None,
#    'snow': None,
#    'wdir': 150,
#    'wspd': 11.2,
#    'wpgt': None,
#    'pres': 1028.6,
#    'tsun': None,
#    'coco': None},
#   {'time': '2019-01-01 22:00:00',
#    'temp': 14.6,
#    'dwpt': 1.5,
#    'rhum': 41,
#    'prcp': None,
#    'snow': None,
#    'wdir': 140,
#    'wspd': 13,
#    'wpgt': None,
#    'pres': 1028.1,
#    'tsun': None,
#    'coco': None},
#   {'time': '2019-01-01 23:00:00',
#    'temp': 14,
#    'dwpt': 1.9,
#    'rhum': 44,
#    'prcp': None,
#    'snow': None,
#    'wdir': 140,
#    'wspd': 13,
#    'wpgt': None,
#    'pres': 1028.5,
#    'tsun': None,
#    'coco': None},
#   {'time': '2019-01-02 00:00:00',
#    'temp': 14.1,
#    'dwpt': 2.3,
#    'rhum': 45,
#    'prcp': None,
#    'snow': None,
#    'wdir': 140,
#    'wspd': 13,
#    'wpgt': None,
#    'pres': 1028.5,
#    'tsun': None,
#    'coco': None},
#   {'time': '2019-01-02 01:00:00',
#    'temp': 14.5,
#    'dwpt': 0,
#    'rhum': 37,
#    'prcp': None,
#    'snow': None,
#    'wdir': 130,
#    'wspd': 13,
#    'wpgt': None,
#    'pres': 1028.5,
#    'tsun': None,
#    'coco': None},
#   {'time': '2019-01-02 02:00:00',
#    'temp': 13.7,
#    'dwpt': 0,
#    'rhum': 39,
#    'prcp': None,
#    'snow': None,
#    'wdir': 150,
#    'wspd': 13,
#    'wpgt': None,
#    'pres': 1028.4,
#    'tsun': None,
#    'coco': None},
#   {'time': '2019-01-02 03:00:00',
#    'temp': 13.5,
#    'dwpt': -0.6,
#    'rhum': 38,
#    'prcp': None,
#    'snow': None,
#    'wdir': 150,
#    'wspd': 13,
#    'wpgt': None,
#    'pres': 1028.5,
#    'tsun': None,
#    'coco': None},
#   {'time': '2019-01-02 04:00:00',
#    'temp': 13.2,
#    'dwpt': 0.6,
#    'rhum': 42,
#    'prcp': None,
#    'snow': None,
#    'wdir': 150,
#    'wspd': 13,
#    'wpgt': None,
#    'pres': 1028.3,
#    'tsun': None,
#    'coco': None},
#   {'time': '2019-01-02 05:00:00',
#    'temp': 12.2,
#    'dwpt': 1.2,
#    'rhum': 47,
#    'prcp': None,
#    'snow': None,
#    'wdir': 140,
#    'wspd': 9.4,
#    'wpgt': None,
#    'pres': 1028.4,
#    'tsun': None,
#    'coco': None},
#   {'time': '2019-01-02 06:00:00',
#    'temp': 11.6,
#    'dwpt': 6.3,
#    'rhum': 70,
#    'prcp': None,
#    'snow': None,
#    'wdir': 140,
#    'wspd': 9.4,
#    'wpgt': None,
#    'pres': 1028.5,
#    'tsun': None,
#    'coco': None},
#   {'time': '2019-01-02 07:00:00',
#    'temp': 11.5,
#    'dwpt': 9.2,
#    'rhum': 86,
#    'prcp': None,
#    'snow': None,
#    'wdir': 150,
#    'wspd': 11.2,
#    'wpgt': None,
#    'pres': 1028.6,
#    'tsun': None,
#    'coco': None},
#   {'time': '2019-01-02 08:00:00',
#    'temp': 12.2,
#    'dwpt': 10.9,
#    'rhum': 92,
#    'prcp': None,
#    'snow': None,
#    'wdir': 140,
#    'wspd': 11.2,
#    'wpgt': None,
#    'pres': 1028.9,
#    'tsun': None,
#    'coco': None},
#   {'time': '2019-01-02 09:00:00',
#    'temp': 13.6,
#    'dwpt': 11.8,
#    'rhum': 89,
#    'prcp': None,
#    'snow': None,
#    'wdir': 130,
#    'wspd': 11.2,
#    'wpgt': None,
#    'pres': 1028.8,
#    'tsun': None,
#    'coco': None},
#   {'time': '2019-01-02 10:00:00',
#    'temp': 14.7,
#    'dwpt': 12.4,
#    'rhum': 86,
#    'prcp': None,
#    'snow': None,
#    'wdir': 100,
#    'wspd': 14.8,
#    'wpgt': None,
#    'pres': 1029,
#    'tsun': None,
#    'coco': None},
#   {'time': '2019-01-02 11:00:00',
#    'temp': 16.5,
#    'dwpt': 10.8,
#    'rhum': 69,
#    'prcp': None,
#    'snow': None,
#    'wdir': 110,
#    'wspd': 11.2,
#    'wpgt': None,
#    'pres': 1028.9,
#    'tsun': None,
#    'coco': None},
#   {'time': '2019-01-02 12:00:00',
#    'temp': 17.7,
#    'dwpt': 8.3,
#    'rhum': 54,
#    'prcp': None,
#    'snow': None,
#    'wdir': 90,
#    'wspd': 9.4,
#    'wpgt': None,
#    'pres': 1027.7,
#    'tsun': None,
#    'coco': None},
#   {'time': '2019-01-02 13:00:00',
#    'temp': 17.7,
#    'dwpt': 10.3,
#    'rhum': 62,
#    'prcp': None,
#    'snow': None,
#    'wdir': 110,
#    'wspd': 11.2,
#    'wpgt': None,
#    'pres': 1026.7,
#    'tsun': None,
#    'coco': None},
#   {'time': '2019-01-02 14:00:00',
#    'temp': 17.5,
#    'dwpt': 9.9,
#    'rhum': 61,
#    'prcp': None,
#    'snow': None,
#    'wdir': 110,
#    'wspd': 14.8,
#    'wpgt': None,
#    'pres': 1026.2,
#    'tsun': None,
#    'coco': None},
#   {'time': '2019-01-02 15:00:00',
#    'temp': 17.2,
#    'dwpt': 8.3,
#    'rhum': 56,
#    'prcp': None,
#    'snow': None,
#    'wdir': 110,
#    'wspd': 16.6,
#    'wpgt': None,
#    'pres': 1026,
#    'tsun': None,
#    'coco': None},
#   {'time': '2019-01-02 16:00:00',
#    'temp': 16.5,
#    'dwpt': 6.6,
#    'rhum': 52,
#    'prcp': None,
#    'snow': None,
#    'wdir': 100,
#    'wspd': 16.6,
#    'wpgt': None,
#    'pres': 1026.4,
#    'tsun': None,
#    'coco': None},
#   {'time': '2019-01-02 17:00:00',
#    'temp': 15.7,
#    'dwpt': 5,
#    'rhum': 49,
#    'prcp': None,
#    'snow': None,
#    'wdir': 120,
#    'wspd': 11.2,
#    'wpgt': None,
#    'pres': 1026.6,
#    'tsun': None,
#    'coco': None},
#   {'time': '2019-01-02 18:00:00',
#    'temp': 14.2,
#    'dwpt': 5.8,
#    'rhum': 57,
#    'prcp': None,
#    'snow': None,
#    'wdir': 120,
#    'wspd': 9.4,
#    'wpgt': None,
#    'pres': 1026.9,
#    'tsun': None,
#    'coco': None},
#   {'time': '2019-01-02 19:00:00',
#    'temp': 12,
#    'dwpt': 6.1,
#    'rhum': 67,
#    'prcp': None,
#    'snow': None,
#    'wdir': 160,
#    'wspd': 7.6,
#    'wpgt': None,
#    'pres': 1027.8,
#    'tsun': None,
#    'coco': None},
#   {'time': '2019-01-02 20:00:00',
#    'temp': 12.2,
#    'dwpt': 1.8,
#    'rhum': 49,
#    'prcp': None,
#    'snow': None,
#    'wdir': 140,
#    'wspd': 7.6,
#    'wpgt': None,
#    'pres': 1027.9,
#    'tsun': None,
#    'coco': None},
#   {'time': '2019-01-02 21:00:00',
#    'temp': 11.7,
#    'dwpt': 0.2,
#    'rhum': 45,
#    'prcp': None,
#    'snow': None,
#    'wdir': 130,
#    'wspd': 7.6,
#    'wpgt': None,
#    'pres': 1028.1,
#    'tsun': None,
#    'coco': None},
#   {'time': '2019-01-02 22:00:00',
#    'temp': 11.5,
#    'dwpt': -0.3,
#    'rhum': 44,
#    'prcp': None,
#    'snow': None,
#    'wdir': 150,
#    'wspd': 9.4,
#    'wpgt': None,
#    'pres': 1028.2,
#    'tsun': None,
#    'coco': None},
#   {'time': '2019-01-02 23:00:00',
#    'temp': 11,
#    'dwpt': 1.2,
#    'rhum': 51,
#    'prcp': None,
#    'snow': None,
#    'wdir': 150,
#    'wspd': 11.2,
#    'wpgt': None,
#    'pres': 1027.9,
#    'tsun': None,
#    'coco': None},
#   {'time': '2019-01-03 00:00:00',
#    'temp': 11.7,
#    'dwpt': 7.4,
#    'rhum': 75,
#    'prcp': None,
#    'snow': None,
#    'wdir': 150,
#    'wspd': 13,
#    'wpgt': None,
#    'pres': 1026.9,
#    'tsun': None,
#    'coco': None},
#   {'time': '2019-01-03 01:00:00',
#    'temp': 11.2,
#    'dwpt': 9.5,
#    'rhum': 89,
#    'prcp': None,
#    'snow': None,
#    'wdir': 150,
#    'wspd': 13,
#    'wpgt': None,
#    'pres': 1026.8,
#    'tsun': None,
#    'coco': None},
#   {'time': '2019-01-03 02:00:00',
#    'temp': 11.6,
#    'dwpt': 10.3,
#    'rhum': 92,
#    'prcp': None,
#    'snow': None,
#    'wdir': 140,
#    'wspd': 13,
#    'wpgt': None,
#    'pres': 1026.4,
#    'tsun': None,
#    'coco': None},
#   {'time': '2019-01-03 03:00:00',
#    'temp': 11.7,
#    'dwpt': 10.6,
#    'rhum': 93,
#    'prcp': None,
#    'snow': None,
#    'wdir': 150,
#    'wspd': 16.6,
#    'wpgt': None,
#    'pres': 1026.1,
#    'tsun': None,
#    'coco': None},
#   {'time': '2019-01-03 04:00:00',
#    'temp': 11.5,
#    'dwpt': 10.1,
#    'rhum': 91,
#    'prcp': None,
#    'snow': None,
#    'wdir': 150,
#    'wspd': 16.6,
#    'wpgt': None,
#    'pres': 1026.1,
#    'tsun': None,
#    'coco': None},
#   {'time': '2019-01-03 05:00:00',
#    'temp': 11.5,
#    'dwpt': 9.9,
#    'rhum': 90,
#    'prcp': None,
#    'snow': None,
#    'wdir': 140,
#    'wspd': 14.8,
#    'wpgt': None,
#    'pres': 1025.2,
#    'tsun': None,
#    'coco': None},
#   {'time': '2019-01-03 06:00:00',
#    'temp': 11.2,
#    'dwpt': 9.8,
#    'rhum': 91,
#    'prcp': None,
#    'snow': None,
#    'wdir': 140,
#    'wspd': 14.8,
#    'wpgt': None,
#    'pres': 1025.3,
#    'tsun': None,
#    'coco': None},
#   {'time': '2019-01-03 07:00:00',
#    'temp': 11.5,
#    'dwpt': 9.7,
#    'rhum': 89,
#    'prcp': None,
#    'snow': None,
#    'wdir': 140,
#    'wspd': 14.8,
#    'wpgt': None,
#    'pres': 1025.4,
#    'tsun': None,
#    'coco': None},
#   {'time': '2019-01-03 08:00:00',
#    'temp': 11.7,
#    'dwpt': 9.9,
#    'rhum': 89,
#    'prcp': None,
#    'snow': None,
#    'wdir': 130,
#    'wspd': 14.8,
#    'wpgt': None,
#    'pres': 1025.9,
#    'tsun': None,
#    'coco': None},
#   {'time': '2019-01-03 09:00:00',
#    'temp': 12.1,
#    'dwpt': 10.7,
#    'rhum': 91,
#    'prcp': None,
#    'snow': None,
#    'wdir': 130,
#    'wspd': 9.4,
#    'wpgt': None,
#    'pres': 1026.2,
#    'tsun': None,
#    'coco': None},
#   {'time': '2019-01-03 10:00:00',
#    'temp': 13.7,
#    'dwpt': 10.7,
#    'rhum': 82,
#    'prcp': None,
#    'snow': None,
#    'wdir': 110,
#    'wspd': 14.8,
#    'wpgt': None,
#    'pres': 1026.2,
#    'tsun': None,
#    'coco': None},
#   {'time': '2019-01-03 11:00:00',
#    'temp': 14.5,
#    'dwpt': 10.5,
#    'rhum': 77,
#    'prcp': None,
#    'snow': None,
#    'wdir': 100,
#    'wspd': 18.4,
#    'wpgt': None,
#    'pres': 1025.9,
#    'tsun': None,
#    'coco': None},
#   {'time': '2019-01-03 12:00:00',
#    'temp': 15.2,
#    'dwpt': 10.6,
#    'rhum': 74,
#    'prcp': None,
#    'snow': None,
#    'wdir': 100,
#    'wspd': 20.5,
#    'wpgt': None,
#    'pres': 1025,
#    'tsun': None,
#    'coco': None},
#   {'time': '2019-01-03 13:00:00',
#    'temp': 15.5,
#    'dwpt': 10.9,
#    'rhum': 74,
#    'prcp': None,
#    'snow': None,
#    'wdir': 100,
#    'wspd': 18.4,
#    'wpgt': None,
#    'pres': 1023.9,
#    'tsun': None,
#    'coco': None},
#   {'time': '2019-01-03 14:00:00',
#    'temp': 15.2,
#    'dwpt': 10.2,
#    'rhum': 72,
#    'prcp': None,
#    'snow': None,
#    'wdir': 120,
#    'wspd': 11.2,
#    'wpgt': None,
#    'pres': 1023.5,
#    'tsun': None,
#    'coco': None},
#   {'time': '2019-01-03 15:00:00',
#    'temp': 15.2,
#    'dwpt': 10.4,
#    'rhum': 73,
#    'prcp': None,
#    'snow': None,
#    'wdir': 110,
#    'wspd': 13,
#    'wpgt': None,
#    'pres': 1023.5,
#    'tsun': None,
#    'coco': None},
#   {'time': '2019-01-03 16:00:00',
#    'temp': 14.7,
#    'dwpt': 10.7,
#    'rhum': 77,
#    'prcp': None,
#    'snow': None,
#    'wdir': 110,
#    'wspd': 14.8,
#    'wpgt': None,
#    'pres': 1023.1,
#    'tsun': None,
#    'coco': None},
#   {'time': '2019-01-03 17:00:00',
#    'temp': 13.7,
#    'dwpt': 10.7,
#    'rhum': 82,
#    'prcp': None,
#    'snow': None,
#    'wdir': 110,
#    'wspd': 13,
#    'wpgt': None,
#    'pres': 1023.9,
#    'tsun': None,
#    'coco': None},
#   {'time': '2019-01-03 18:00:00',
#    'temp': 13,
#    'dwpt': 10.5,
#    'rhum': 85,
#    'prcp': None,
#    'snow': None,
#    'wdir': 130,
#    'wspd': 11.2,
#    'wpgt': None,
#    'pres': 1024.2,
#    'tsun': None,
#    'coco': None},
#   {'time': '2019-01-03 19:00:00',
#    'temp': 12.2,
#    'dwpt': 9.9,
#    'rhum': 86,
#    'prcp': None,
#    'snow': None,
#    'wdir': 130,
#    'wspd': 9.4,
#    'wpgt': None,
#    'pres': 1024.6,
#    'tsun': None,
#    'coco': None},
#   {'time': '2019-01-03 20:00:00',
#    'temp': 12,
#    'dwpt': 9.7,
#    'rhum': 86,
#    'prcp': None,
#    'snow': None,
#    'wdir': 120,
#    'wspd': 9.4,
#    'wpgt': None,
#    'pres': 1024.8,
#    'tsun': None,
#    'coco': None},
#   {'time': '2019-01-03 21:00:00',
#    'temp': 11.7,
#    'dwpt': 9.4,
#    'rhum': 86,
#    'prcp': None,
#    'snow': None,
#    'wdir': 130,
#    'wspd': 11.2,
#    'wpgt': None,
#    'pres': 1025.1,
#    'tsun': None,
#    'coco': None},
#   {'time': '2019-01-03 22:00:00',
#    'temp': 12.1,
#    'dwpt': 9.5,
#    'rhum': 84,
#    'prcp': None,
#    'snow': None,
#    'wdir': 110,
#    'wspd': 11.2,
#    'wpgt': None,
#    'pres': 1025.5,
#    'tsun': None,
#    'coco': None},
#   {'time': '2019-01-03 23:00:00',
#    'temp': 12,
#    'dwpt': 9.4,
#    'rhum': 84,
#    'prcp': None,
#    'snow': None,
#    'wdir': 100,
#    'wspd': 3.6,
#    'wpgt': None,
#    'pres': 1025.6,
#    'tsun': None,
#    'coco': None},
#   {'time': '2019-01-04 00:00:00',
#    'temp': 11.7,
#    'dwpt': 9.3,
#    'rhum': 85,
#    'prcp': None,
#    'snow': None,
#    'wdir': 130,
#    'wspd': 7.6,
#    'wpgt': None,
#    'pres': 1025.3,
#    'tsun': None,
#    'coco': None},
#   {'time': '2019-01-04 01:00:00',
#    'temp': 11.6,
#    'dwpt': 9,
#    'rhum': 84,
#    'prcp': None,
#    'snow': None,
#    'wdir': 120,
#    'wspd': 9.4,
#    'wpgt': None,
#    'pres': 1024.8,
#    'tsun': None,
#    'coco': None},
#   {'time': '2019-01-04 02:00:00',
#    'temp': 11.7,
#    'dwpt': 9.1,
#    'rhum': 84,
#    'prcp': None,
#    'snow': None,
#    'wdir': 120,
#    'wspd': 11.2,
#    'wpgt': None,
#    'pres': 1024.5,
#    'tsun': None,
#    'coco': None},
#   {'time': '2019-01-04 03:00:00',
#    'temp': 12,
#    'dwpt': 8.7,
#    'rhum': 80,
#    'prcp': None,
#    'snow': None,
#    'wdir': 120,
#    'wspd': 13,
#    'wpgt': None,
#    'pres': 1024.5,
#    'tsun': None,
#    'coco': None},
#   {'time': '2019-01-04 04:00:00',
#    'temp': 12,
#    'dwpt': 8.7,
#    'rhum': 80,
#    'prcp': None,
#    'snow': None,
#    'wdir': 120,
#    'wspd': 13,
#    'wpgt': None,
#    'pres': 1024.3,
#    'tsun': None,
#    'coco': None},
#   {'time': '2019-01-04 05:00:00',
#    'temp': 11.7,
#    'dwpt': 8.5,
#    'rhum': 81,
#    'prcp': None,
#    'snow': None,
#    'wdir': 120,
#    'wspd': 14.8,
#    'wpgt': None,
#    'pres': 1023.7,
#    'tsun': None,
#    'coco': None},
#   {'time': '2019-01-04 06:00:00',
#    'temp': 12,
#    'dwpt': 9.2,
#    'rhum': 83,
#    'prcp': None,
#    'snow': None,
#    'wdir': 120,
#    'wspd': 13,
#    'wpgt': None,
#    'pres': 1023.4,
#    'tsun': None,
#    'coco': None},
#   {'time': '2019-01-04 07:00:00',
#    'temp': 11.7,
#    'dwpt': 8.5,
#    'rhum': 81,
#    'prcp': None,
#    'snow': None,
#    'wdir': 120,
#    'wspd': 16.6,
#    'wpgt': None,
#    'pres': 1023.9,
#    'tsun': None,
#    'coco': None},
#   {'time': '2019-01-04 08:00:00',
#    'temp': 11.2,
#    'dwpt': 8.4,
#    'rhum': 83,
#    'prcp': None,
#    'snow': None,
#    'wdir': 130,
#    'wspd': 13,
#    'wpgt': None,
#    'pres': 1024.5,
#    'tsun': None,
#    'coco': None},
#   {'time': '2019-01-04 09:00:00',
#    'temp': 12.1,
#    'dwpt': 9.1,
#    'rhum': 82,
#    'prcp': None,
#    'snow': None,
#    'wdir': 140,
#    'wspd': 13,
#    'wpgt': None,
#    'pres': 1024.8,
#    'tsun': None,
#    'coco': None},
#   {'time': '2019-01-04 10:00:00',
#    'temp': 12.7,
#    'dwpt': 9,
#    'rhum': 78,
#    'prcp': None,
#    'snow': None,
#    'wdir': 110,
#    'wspd': 18.4,
#    'wpgt': None,
#    'pres': 1025.4,
#    'tsun': None,
#    'coco': None},
#   {'time': '2019-01-04 11:00:00',
#    'temp': 13.2,
#    'dwpt': 9.6,
#    'rhum': 79,
#    'prcp': None,
#    'snow': None,
#    'wdir': 120,
#    'wspd': 18.4,
#    'wpgt': None,
#    'pres': 1025.5,
#    'tsun': None,
#    'coco': None},
#   {'time': '2019-01-04 12:00:00',
#    'temp': 15,
#    'dwpt': 10.6,
#    'rhum': 75,
#    'prcp': None,
#    'snow': None,
#    'wdir': 110,
#    'wspd': 18.4,
#    'wpgt': None,
#    'pres': 1024.4,
#    'tsun': None,
#    'coco': None},
#   {'time': '2019-01-04 13:00:00',
#    'temp': 14.7,
#    'dwpt': 10.1,
#    'rhum': 74,
#    'prcp': None,
#    'snow': None,
#    'wdir': 90,
#    'wspd': 13,
#    'wpgt': None,
#    'pres': 1024,
#    'tsun': None,
#    'coco': None},
#   {'time': '2019-01-04 14:00:00',
#    'temp': 15.2,
#    'dwpt': 10.2,
#    'rhum': 72,
#    'prcp': None,
#    'snow': None,
#    'wdir': 80,
#    'wspd': 9.4,
#    'wpgt': None,
#    'pres': 1023.2,
#    'tsun': None,
#    'coco': None},
#   {'time': '2019-01-04 15:00:00',
#    'temp': 15,
#    'dwpt': 10.8,
#    'rhum': 76,
#    'prcp': None,
#    'snow': None,
#    'wdir': 110,
#    'wspd': 13,
#    'wpgt': None,
#    'pres': 1023,
#    'tsun': None,
#    'coco': None},
#   {'time': '2019-01-04 16:00:00',
#    'temp': 14.1,
#    'dwpt': 11.1,
#    'rhum': 82,
#    'prcp': None,
#    'snow': None,
#    'wdir': 90,
#    'wspd': 9.4,
#    'wpgt': None,
#    'pres': 1023.6,
#    'tsun': None,
#    'coco': None},
#   {'time': '2019-01-04 17:00:00',
#    'temp': 14.2,
#    'dwpt': 11,
#    'rhum': 81,
#    'prcp': None,
#    'snow': None,
#    'wdir': 30,
#    'wspd': 7.6,
#    'wpgt': None,
#    'pres': 1023.7,
#    'tsun': None,
#    'coco': None},
#   {'time': '2019-01-04 18:00:00',
#    'temp': 13,
#    'dwpt': 10.9,
#    'rhum': 87,
#    'prcp': None,
#    'snow': None,
#    'wdir': 110,
#    'wspd': 7.6,
#    'wpgt': None,
#    'pres': 1024.4,
#    'tsun': None,
#    'coco': None},
#   {'time': '2019-01-04 19:00:00',
#    'temp': 12.5,
#    'dwpt': 10.6,
#    'rhum': 88,
#    'prcp': None,
#    'snow': None,
#    'wdir': 120,
#    'wspd': 7.6,
#    'wpgt': None,
#    'pres': 1025.4,
#    'tsun': None,
#    'coco': None},
#   {'time': '2019-01-04 20:00:00',
#    'temp': 11.5,
#    'dwpt': 9.7,
#    'rhum': 89,
#    'prcp': None,
#    'snow': None,
#    'wdir': 140,
#    'wspd': 3.6,
#    'wpgt': None,
#    'pres': 1026.2,
#    'tsun': None,
#    'coco': None},
#   {'time': '2019-01-04 21:00:00',
#    'temp': 11,
#    'dwpt': 9.7,
#    'rhum': 92,
#    'prcp': None,
#    'snow': None,
#    'wdir': 140,
#    'wspd': 3.6,
#    'wpgt': None,
#    'pres': 1027.1,
#    'tsun': None,
#    'coco': None},
#   {'time': '2019-01-04 22:00:00',
#    'temp': 10.5,
#    'dwpt': 9.4,
#    'rhum': 93,
#    'prcp': None,
#    'snow': None,
#    'wdir': 280,
#    'wspd': 1.8,
#    'wpgt': None,
#    'pres': 1027.6,
#    'tsun': None,
#    'coco': None},
#   {'time': '2019-01-04 23:00:00',
#    'temp': 10,
#    'dwpt': 9.1,
#    'rhum': 94,
#    'prcp': None,
#    'snow': None,
#    'wdir': 150,
#    'wspd': 7.6,
#    'wpgt': None,
#    'pres': 1027.8,
#    'tsun': None,
#    'coco': None},
#   {'time': '2019-01-05 00:00:00',
#    'temp': 11.1,
#    'dwpt': 10.5,
#    'rhum': 96,
#    'prcp': None,
#    'snow': None,
#    'wdir': 150,
#    'wspd': 7.6,
#    'wpgt': None,
#    'pres': 1026.9,
#    'tsun': None,
#    'coco': None},
#   {'time': '2019-01-05 01:00:00',
#    'temp': 11.5,
#    'dwpt': 10.6,
#    'rhum': 94,
#    'prcp': None,
#    'snow': None,
#    'wdir': 140,
#    'wspd': 9.4,
#    'wpgt': None,
#    'pres': 1026.2,
#    'tsun': None,
#    'coco': None},
#   {'time': '2019-01-05 02:00:00',
#    'temp': 11.5,
#    'dwpt': 10.6,
#    'rhum': 94,
#    'prcp': None,
#    'snow': None,
#    'wdir': 120,
#    'wspd': 11.2,
#    'wpgt': None,
#    'pres': 1026.3,
#    'tsun': None,
#    'coco': None},
#   {'time': '2019-01-05 03:00:00',
#    'temp': 11.5,
#    'dwpt': 10.6,
#    'rhum': 94,
#    'prcp': None,
#    'snow': None,
#    'wdir': 130,
#    'wspd': 11.2,
#    'wpgt': None,
#    'pres': 1026.5,
#    'tsun': None,
#    'coco': None},
#   {'time': '2019-01-05 04:00:00',
#    'temp': 11,
#    'dwpt': 10.1,
#    'rhum': 94,
#    'prcp': None,
#    'snow': None,
#    'wdir': 130,
#    'wspd': 9.4,
#    'wpgt': None,
#    'pres': 1026.3,
#    'tsun': None,
#    'coco': None},
#   {'time': '2019-01-05 05:00:00',
#    'temp': 11.1,
#    'dwpt': 10.2,
#    'rhum': 94,
#    'prcp': None,
#    'snow': None,
#    'wdir': 140,
#    'wspd': 9.4,
#    'wpgt': None,
#    'pres': 1025.8,
#    'tsun': None,
#    'coco': None},
#   {'time': '2019-01-05 06:00:00',
#    'temp': 11.5,
#    'dwpt': 10.6,
#    'rhum': 94,
#    'prcp': None,
#    'snow': None,
#    'wdir': 140,
#    'wspd': 11.2,
#    'wpgt': None,
#    'pres': 1025.7,
#    'tsun': None,
#    'coco': None},
#   {'time': '2019-01-05 07:00:00',
#    'temp': 11.5,
#    'dwpt': 10.6,
#    'rhum': 94,
#    'prcp': None,
#    'snow': None,
#    'wdir': 130,
#    'wspd': 14.8,
#    'wpgt': None,
#    'pres': 1026.1,
#    'tsun': None,
#    'coco': None},
#   {'time': '2019-01-05 08:00:00',
#    'temp': 12,
#    'dwpt': 11.2,
#    'rhum': 95,
#    'prcp': None,
#    'snow': None,
#    'wdir': 130,
#    'wspd': 16.6,
#    'wpgt': None,
#    'pres': 1026.5,
#    'tsun': None,
#    'coco': None},
#   {'time': '2019-01-05 09:00:00',
#    'temp': 12.2,
#    'dwpt': 11.7,
#    'rhum': 97,
#    'prcp': None,
#    'snow': None,
#    'wdir': 120,
#    'wspd': 18.4,
#    'wpgt': None,
#    'pres': 1026.9,
#    'tsun': None,
#    'coco': None},
#   {'time': '2019-01-05 10:00:00',
#    'temp': 13,
#    'dwpt': 12.1,
#    'rhum': 94,
#    'prcp': None,
#    'snow': None,
#    'wdir': 120,
#    'wspd': 16.6,
#    'wpgt': None,
#    'pres': 1027.6,
#    'tsun': None,
#    'coco': None},
#   {'time': '2019-01-05 11:00:00',
#    'temp': 13.7,
#    'dwpt': 11.9,
#    'rhum': 89,
#    'prcp': None,
#    'snow': None,
#    'wdir': 110,
#    'wspd': 18.4,
#    'wpgt': None,
#    'pres': 1027.2,
#    'tsun': None,
#    'coco': None},
#   {'time': '2019-01-05 12:00:00',
#    'temp': 15.2,
#    'dwpt': 12.5,
#    'rhum': 84,
#    'prcp': None,
#    'snow': None,
#    'wdir': 110,
#    'wspd': 18.4,
#    'wpgt': None,
#    'pres': 1026.3,
#    'tsun': None,
#    'coco': None},
#   {'time': '2019-01-05 13:00:00',
#    'temp': 15.7,
#    'dwpt': 10.9,
#    'rhum': 73,
#    'prcp': None,
#    'snow': None,
#    'wdir': 110,
#    'wspd': 22.3,
#    'wpgt': None,
#    'pres': 1025.7,
#    'tsun': None,
#    'coco': None},
#   {'time': '2019-01-05 14:00:00',
#    'temp': 16.6,
#    'dwpt': 10,
#    'rhum': 65,
#    'prcp': None,
#    'snow': None,
#    'wdir': 120,
#    'wspd': 18.4,
#    'wpgt': None,
#    'pres': 1024.7,
#    'tsun': None,
#    'coco': None},
#   {'time': '2019-01-05 15:00:00',
#    'temp': 17.5,
#    'dwpt': 1,
#    'rhum': 33,
#    'prcp': None,
#    'snow': None,
#    'wdir': 150,
#    'wspd': 16.6,
#    'wpgt': None,
#    'pres': 1024.6,
#    'tsun': None,
#    'coco': None},
#   {'time': '2019-01-05 16:00:00',
#    'temp': 17.2,
#    'dwpt': 2.4,
#    'rhum': 37,
#    'prcp': None,
#    'snow': None,
#    'wdir': 140,
#    'wspd': 18.4,
#    'wpgt': None,
#    'pres': 1024.4,
#    'tsun': None,
#    'coco': None},
#   {'time': '2019-01-05 17:00:00',
#    'temp': 15.5,
#    'dwpt': 3.6,
#    'rhum': 45,
#    'prcp': None,
#    'snow': None,
#    'wdir': 150,
#    'wspd': 11.2,
#    'wpgt': None,
#    'pres': 1025.3,
#    'tsun': None,
#    'coco': None},
#   {'time': '2019-01-05 18:00:00',
#    'temp': 14.1,
#    'dwpt': 4.9,
#    'rhum': 54,
#    'prcp': None,
#    'snow': None,
#    'wdir': 120,
#    'wspd': 7.6,
#    'wpgt': None,
#    'pres': 1026,
#    'tsun': None,
#    'coco': None},
#   {'time': '2019-01-05 19:00:00',
#    'temp': 12.1,
#    'dwpt': 3.8,
#    'rhum': 57,
#    'prcp': None,
#    'snow': None,
#    'wdir': 150,
#    'wspd': 7.6,
#    'wpgt': None,
#    'pres': 1027.1,
#    'tsun': None,
#    'coco': None},
#   {'time': '2019-01-05 20:00:00',
#    'temp': 12.5,
#    'dwpt': -1.1,
#    'rhum': 39,
#    'prcp': None,
#    'snow': None,
#    'wdir': 170,
#    'wspd': 3.6,
#    'wpgt': None,
#    'pres': 1027.6,
#    'tsun': None,
#    'coco': None},
#   {'time': '2019-01-05 21:00:00',
#    'temp': 13.2,
#    'dwpt': -1.6,
#    'rhum': 36,
#    'prcp': None,
#    'snow': None,
#    'wdir': 130,
#    'wspd': 13,
#    'wpgt': None,
#    'pres': 1027.7,
#    'tsun': None,
#    'coco': None},
#   {'time': '2019-01-05 22:00:00',
#    'temp': 12.5,
#    'dwpt': 9,
#    'rhum': 82,
#    'prcp': None,
#    'snow': None,
#    'wdir': 130,
#    'wspd': 14.8,
#    'wpgt': None,
#    'pres': 1027.8,
#    'tsun': None,
#    'coco': None},
#   {'time': '2019-01-05 23:00:00',
#    'temp': 13,
#    'dwpt': 5.4,
#    'rhum': 60,
#    'prcp': None,
#    'snow': None,
#    'wdir': 120,
#    'wspd': 14.8,
#    'wpgt': None,
#    'pres': 1027.5,
#    'tsun': None,
#    'coco': None},
#   {'time': '2019-01-06 00:00:00',
#    'temp': 12.2,
#    'dwpt': 6.7,
#    'rhum': 69,
#    'prcp': None,
#    'snow': None,
#    'wdir': 130,
#    'wspd': 13,
#    'wpgt': None,
#    'pres': 1027.5,
#    'tsun': None,
#    'coco': None},
#   {'time': '2019-01-06 01:00:00',
#    'temp': 11.5,
#    'dwpt': 6,
#    'rhum': 69,
#    'prcp': None,
#    'snow': None,
#    'wdir': 120,
#    'wspd': 11.2,
#    'wpgt': None,
#    'pres': 1027.6,
#    'tsun': None,
#    'coco': None},
#   {'time': '2019-01-06 02:00:00',
#    'temp': 11.2,
#    'dwpt': 5.7,
#    'rhum': 69,
#    'prcp': None,
#    'snow': None,
#    'wdir': 130,
#    'wspd': 11.2,
#    'wpgt': None,
#    'pres': 1027.4,
#    'tsun': None,
#    'coco': None},
#   {'time': '2019-01-06 03:00:00',
#    'temp': 11.5,
#    'dwpt': 8.2,
#    'rhum': 80,
#    'prcp': None,
#    'snow': None,
#    'wdir': 160,
#    'wspd': 9.4,
#    'wpgt': None,
#    'pres': 1027.1,
#    'tsun': None,
#    'coco': None},
#   {'time': '2019-01-06 04:00:00',
#    'temp': 11.6,
#    'dwpt': 9.7,
#    'rhum': 88,
#    'prcp': None,
#    'snow': None,
#    'wdir': 120,
#    'wspd': 16.6,
#    'wpgt': None,
#    'pres': 1026.8,
#    'tsun': None,
#    'coco': None},
#   {'time': '2019-01-06 05:00:00',
#    'temp': 12,
#    'dwpt': 9.7,
#    'rhum': 86,
#    'prcp': None,
#    'snow': None,
#    'wdir': 120,
#    'wspd': 22.3,
#    'wpgt': None,
#    'pres': 1026.3,
#    'tsun': None,
#    'coco': None},
#   {'time': '2019-01-06 06:00:00',
#    'temp': 12.5,
#    'dwpt': 9,
#    'rhum': 79,
#    'prcp': None,
#    'snow': None,
#    'wdir': 120,
#    'wspd': 22.3,
#    'wpgt': None,
#    'pres': 1025.9,
#    'tsun': None,
#    'coco': None},
#   {'time': '2019-01-06 07:00:00',
#    'temp': 12.7,
#    'dwpt': 6.7,
#    'rhum': 67,
#    'prcp': None,
#    'snow': None,
#    'wdir': 120,
#    'wspd': 22.3,
#    'wpgt': None,
#    'pres': 1025.6,
#    'tsun': None,
#    'coco': None},
#   {'time': '2019-01-06 08:00:00',
#    'temp': 12.2,
#    'dwpt': 7.7,
#    'rhum': 74,
#    'prcp': None,
#    'snow': None,
#    'wdir': 120,
#    'wspd': 20.5,
#    'wpgt': None,
#    'pres': 1025.9,
#    'tsun': None,
#    'coco': None},
#   {'time': '2019-01-06 09:00:00',
#    'temp': 13.5,
#    'dwpt': 6.8,
#    'rhum': 64,
#    'prcp': None,
#    'snow': None,
#    'wdir': 110,
#    'wspd': 25.9,
#    'wpgt': None,
#    'pres': 1026.4,
#    'tsun': None,
#    'coco': None},
#   {'time': '2019-01-06 10:00:00',
#    'temp': 14.2,
#    'dwpt': 7.9,
#    'rhum': 66,
#    'prcp': None,
#    'snow': None,
#    'wdir': 110,
#    'wspd': 27.7,
#    'wpgt': None,
#    'pres': 1026.7,
#    'tsun': None,
#    'coco': None},
#   {'time': '2019-01-06 11:00:00',
#    'temp': 15.2,
#    'dwpt': 6.5,
#    'rhum': 56,
#    'prcp': None,
#    'snow': None,
#    'wdir': 90,
#    'wspd': 16.6,
#    'wpgt': None,
#    'pres': 1026.7,
#    'tsun': None,
#    'coco': None},
#   {'time': '2019-01-06 12:00:00',
#    'temp': 17.2,
#    'dwpt': 3.1,
#    'rhum': 39,
#    'prcp': None,
#    'snow': None,
#    'wdir': 150,
#    'wspd': 20.5,
#    'wpgt': None,
#    'pres': 1025.8,
#    'tsun': None,
#    'coco': None},
#   {'time': '2019-01-06 13:00:00',
#    'temp': 17,
#    'dwpt': 2.6,
#    'rhum': 38,
#    'prcp': None,
#    'snow': None,
#    'wdir': 150,
#    'wspd': 33.5,
#    'wpgt': None,
#    'pres': 1024.8,
#    'tsun': None,
#    'coco': None},
#   {'time': '2019-01-06 14:00:00',
#    'temp': 16.6,
#    'dwpt': 2.6,
#    'rhum': 39,
#    'prcp': None,
#    'snow': None,
#    'wdir': 150,
#    'wspd': 25.9,
#    'wpgt': None,
#    'pres': 1024.3,
#    'tsun': None,
#    'coco': None},
#   {'time': '2019-01-06 15:00:00',
#    'temp': 16,
#    'dwpt': 6.4,
#    'rhum': 53,
#    'prcp': None,
#    'snow': None,
#    'wdir': 140,
#    'wspd': 24.1,
#    'wpgt': None,
#    'pres': 1024.4,
#    'tsun': None,
#    'coco': None},
#   {'time': '2019-01-06 16:00:00',
#    'temp': 15.6,
#    'dwpt': 8.8,
#    'rhum': 64,
#    'prcp': None,
#    'snow': None,
#    'wdir': 110,
#    'wspd': 16.6,
#    'wpgt': None,
#    'pres': 1024.7,
#    'tsun': None,
#    'coco': None},
#   {'time': '2019-01-06 17:00:00',
#    'temp': 14.5,
#    'dwpt': 9.1,
#    'rhum': 70,
#    'prcp': None,
#    'snow': None,
#    'wdir': 110,
#    'wspd': 16.6,
#    'wpgt': None,
#    'pres': 1024.9,
#    'tsun': None,
#    'coco': None},
#   {'time': '2019-01-06 18:00:00',
#    'temp': 13.2,
#    'dwpt': 8.3,
#    'rhum': 72,
#    'prcp': None,
#    'snow': None,
#    'wdir': 100,
#    'wspd': 14.8,
#    'wpgt': None,
#    'pres': 1025.3,
#    'tsun': None,
#    'coco': None},
#   {'time': '2019-01-06 19:00:00',
#    'temp': 12.1,
#    'dwpt': 9.3,
#    'rhum': 83,
#    'prcp': None,
#    'snow': None,
#    'wdir': 100,
#    'wspd': 16.6,
#    'wpgt': None,
#    'pres': 1026,
#    'tsun': None,
#    'coco': None},
#   {'time': '2019-01-06 20:00:00',
#    'temp': 12.5,
#    'dwpt': 7.4,
#    'rhum': 71,
#    'prcp': None,
#    'snow': None,
#    'wdir': 120,
#    'wspd': 20.5,
#    'wpgt': None,
#    'pres': 1026.6,
#    'tsun': None,
#    'coco': None},
#   {'time': '2019-01-06 21:00:00',
#    'temp': 12,
#    'dwpt': 7.3,
#    'rhum': 73,
#    'prcp': None,
#    'snow': None,
#    'wdir': 120,
#    'wspd': 18.4,
#    'wpgt': None,
#    'pres': 1027.1,
#    'tsun': None,
#    'coco': None},
#   {'time': '2019-01-06 22:00:00',
#    'temp': 11.7,
#    'dwpt': 6.8,
#    'rhum': 72,
#    'prcp': None,
#    'snow': None,
#    'wdir': 120,
#    'wspd': 16.6,
#    'wpgt': None,
#    'pres': 1027.1,
#    'tsun': None,
#    'coco': None},
#   {'time': '2019-01-06 23:00:00',
#    'temp': 11.5,
#    'dwpt': 6.6,
#    'rhum': 72,
#    'prcp': None,
#    'snow': None,
#    'wdir': 140,
#    'wspd': 14.8,
#    'wpgt': None,
#    'pres': 1027.3,
#    'tsun': None,
#    'coco': None},
#   {'time': '2019-01-07 00:00:00',
#    'temp': 12,
#    'dwpt': 7.1,
#    'rhum': 72,
#    'prcp': None,
#    'snow': None,
#    'wdir': 130,
#    'wspd': 18.4,
#    'wpgt': None,
#    'pres': 1026.9,
#    'tsun': None,
#    'coco': None},
#   {'time': '2019-01-07 01:00:00',
#    'temp': 11.5,
#    'dwpt': 7.4,
#    'rhum': 76,
#    'prcp': None,
#    'snow': None,
#    'wdir': 130,
#    'wspd': 16.6,
#    'wpgt': None,
#    'pres': 1026.5,
#    'tsun': None,
#    'coco': None},
#   {'time': '2019-01-07 02:00:00',
#    'temp': 11.6,
#    'dwpt': 8.6,
#    'rhum': 82,
#    'prcp': None,
#    'snow': None,
#    'wdir': 130,
#    'wspd': 16.6,
#    'wpgt': None,
#    'pres': 1026,
#    'tsun': None,
#    'coco': None},
#   {'time': '2019-01-07 03:00:00',
#    'temp': 11.7,
#    'dwpt': 8.7,
#    'rhum': 82,
#    'prcp': None,
#    'snow': None,
#    'wdir': 130,
#    'wspd': 16.6,
#    'wpgt': None,
#    'pres': 1026.1,
#    'tsun': None,
#    'coco': None},
#   {'time': '2019-01-07 04:00:00',
#    'temp': 12,
#    'dwpt': 8.3,
#    'rhum': 78,
#    'prcp': None,
#    'snow': None,
#    'wdir': 130,
#    'wspd': 14.8,
#    'wpgt': None,
#    'pres': 1025.9,
#    'tsun': None,
#    'coco': None},
#   {'time': '2019-01-07 05:00:00',
#    'temp': 11.7,
#    'dwpt': 8.5,
#    'rhum': 81,
#    'prcp': None,
#    'snow': None,
#    'wdir': 130,
#    'wspd': 13,
#    'wpgt': None,
#    'pres': 1025.7,
#    'tsun': None,
#    'coco': None},
#   {'time': '2019-01-07 06:00:00',
#    'temp': 12.6,
#    'dwpt': 8.9,
#    'rhum': 78,
#    'prcp': None,
#    'snow': None,
#    'wdir': 110,
#    'wspd': 18.4,
#    'wpgt': None,
#    'pres': 1025.6,
#    'tsun': None,
#    'coco': None},
#   {'time': '2019-01-07 07:00:00',
#    'temp': 12.2,
#    'dwpt': 9.6,
#    'rhum': 84,
#    'prcp': None,
#    'snow': None,
#    'wdir': 110,
#    'wspd': 18.4,
#    'wpgt': None,
#    'pres': 1025.8,
#    'tsun': None,
#    'coco': None},
#   {'time': '2019-01-07 08:00:00',
#    'temp': 12.5,
#    'dwpt': 9.5,
#    'rhum': 82,
#    'prcp': None,
#    'snow': None,
#    'wdir': 120,
#    'wspd': 16.6,
#    'wpgt': None,
#    'pres': 1026.4,
#    'tsun': None,
#    'coco': None},
#   {'time': '2019-01-07 09:00:00',
#    'temp': 13,
#    'dwpt': 9.8,
#    'rhum': 81,
#    'prcp': None,
#    'snow': None,
#    'wdir': 110,
#    'wspd': 16.6,
#    'wpgt': None,
#    'pres': 1026.4,
#    'tsun': None,
#    'coco': None},
#   {'time': '2019-01-07 10:00:00',
#    'temp': 13.6,
#    'dwpt': 10.6,
#    'rhum': 82,
#    'prcp': None,
#    'snow': None,
#    'wdir': 110,
#    'wspd': 22.3,
#    'wpgt': None,
#    'pres': 1026.7,
#    'tsun': None,
#    'coco': None},
#   {'time': '2019-01-07 11:00:00',
#    'temp': 14.5,
#    'dwpt': 11.3,
#    'rhum': 81,
#    'prcp': None,
#    'snow': None,
#    'wdir': 100,
#    'wspd': 24.1,
#    'wpgt': None,
#    'pres': 1026.5,
#    'tsun': None,
#    'coco': None},
#   {'time': '2019-01-07 12:00:00',
#    'temp': 15.6,
#    'dwpt': 9.7,
#    'rhum': 68,
#    'prcp': None,
#    'snow': None,
#    'wdir': 110,
#    'wspd': 24.1,
#    'wpgt': None,
#    'pres': 1025.5,
#    'tsun': None,
#    'coco': None},
#   {'time': '2019-01-07 13:00:00',
#    'temp': 16,
#    'dwpt': 9.4,
#    'rhum': 65,
#    'prcp': None,
#    'snow': None,
#    'wdir': 110,
#    'wspd': 18.4,
#    'wpgt': None,
#    'pres': 1024.8,
#    'tsun': None,
#    'coco': None},
#   {'time': '2019-01-07 14:00:00',
#    'temp': 15.5,
#    'dwpt': 9.2,
#    'rhum': 66,
#    'prcp': None,
#    'snow': None,
#    'wdir': 100,
#    'wspd': 24.1,
#    'wpgt': None,
#    'pres': 1024.1,
#    'tsun': None,
#    'coco': None},
#   {'time': '2019-01-07 15:00:00',
#    'temp': 14.6,
#    'dwpt': 9,
#    'rhum': 69,
#    'prcp': None,
#    'snow': None,
#    'wdir': 110,
#    'wspd': 25.9,
#    'wpgt': None,
#    'pres': 1023.9,
#    'tsun': None,
#    'coco': None},
#   {'time': '2019-01-07 16:00:00',
#    'temp': 14.6,
#    'dwpt': 9.6,
#    'rhum': 72,
#    'prcp': None,
#    'snow': None,
#    'wdir': 110,
#    'wspd': 25.9,
#    'wpgt': None,
#    'pres': 1023.5,
#    'tsun': None,
#    'coco': None},
#   {'time': '2019-01-07 17:00:00',
#    'temp': 13.5,
#    'dwpt': 9.5,
#    'rhum': 77,
#    'prcp': None,
#    'snow': None,
#    'wdir': 110,
#    'wspd': 24.1,
#    'wpgt': None,
#    'pres': 1024,
#    'tsun': None,
#    'coco': None},
#   {'time': '2019-01-07 18:00:00',
#    'temp': 13,
#    'dwpt': 10.2,
#    'rhum': 83,
#    'prcp': None,
#    'snow': None,
#    'wdir': 110,
#    'wspd': 22.3,
#    'wpgt': None,
#    'pres': 1024.3,
#    'tsun': None,
#    'coco': None},
#   {'time': '2019-01-07 19:00:00',
#    'temp': 12.6,
#    'dwpt': 10,
#    'rhum': 84,
#    'prcp': None,
#    'snow': None,
#    'wdir': 110,
#    'wspd': 18.4,
#    'wpgt': None,
#    'pres': 1024.6,
#    'tsun': None,
#    'coco': None},
#   {'time': '2019-01-07 20:00:00',
#    'temp': 12.6,
#    'dwpt': 9.2,
#    'rhum': 80,
#    'prcp': None,
#    'snow': None,
#    'wdir': 110,
#    'wspd': 22.3,
#    'wpgt': None,
#    'pres': 1024.5,
#    'tsun': None,
#    'coco': None},
#   {'time': '2019-01-07 21:00:00',
#    'temp': 13,
#    'dwpt': 11.1,
#    'rhum': 88,
#    'prcp': None,
#    'snow': None,
#    'wdir': 120,
#    'wspd': 24.1,
#    'wpgt': None,
#    'pres': 1024.4,
#    'tsun': None,
#    'coco': None},
#   {'time': '2019-01-07 22:00:00',
#    'temp': 13,
#    'dwpt': 11.4,
#    'rhum': 90,
#    'prcp': None,
#    'snow': None,
#    'wdir': 120,
#    'wspd': 20.5,
#    'wpgt': None,
#    'pres': 1024.7,
#    'tsun': None,
#    'coco': None},
#   {'time': '2019-01-07 23:00:00',
#    'temp': 13,
#    'dwpt': 12.4,
#    'rhum': 96,
#    'prcp': None,
#    'snow': None,
#    'wdir': 120,
#    'wspd': 20.5,
#    'wpgt': None,
#    'pres': 1025,
#    'tsun': None,
#    'coco': None},
#   {'time': '2019-01-08 00:00:00',
#    'temp': 12.7,
#    'dwpt': 12.2,
#    'rhum': 97,
#    'prcp': None,
#    'snow': None,
#    'wdir': 120,
#    'wspd': 24.1,
#    'wpgt': None,
#    'pres': 1024.4,
#    'tsun': None,
#    'coco': None},
#   {'time': '2019-01-08 01:00:00',
#    'temp': 12.5,
#    'dwpt': 11.7,
#    'rhum': 95,
#    'prcp': None,
#    'snow': None,
#    'wdir': 130,
#    'wspd': 16.6,
#    'wpgt': None,
#    'pres': 1023.9,
#    'tsun': None,
#    'coco': None},
#   {'time': '2019-01-08 02:00:00',
#    'temp': 12.5,
#    'dwpt': 11.6,
#    'rhum': 94,
#    'prcp': None,
#    'snow': None,
#    'wdir': 130,
#    'wspd': 14.8,
#    'wpgt': None,
#    'pres': 1024,
#    'tsun': None,
#    'coco': None},
#   {'time': '2019-01-08 03:00:00',
#    'temp': 12,
#    'dwpt': 11.1,
#    'rhum': 94,
#    'prcp': None,
#    'snow': None,
#    'wdir': 130,
#    'wspd': 14.8,
#    'wpgt': None,
#    'pres': 1024.2,
#    'tsun': None,
#    'coco': None},
#   {'time': '2019-01-08 04:00:00',
#    'temp': 11.7,
#    'dwpt': 10.9,
#    'rhum': 95,
#    'prcp': None,
#    'snow': None,
#    'wdir': 130,
#    'wspd': 11.2,
#    'wpgt': None,
#    'pres': 1024,
#    'tsun': None,
#    'coco': None},
#   {'time': '2019-01-08 05:00:00',
#    'temp': 11,
#    'dwpt': 10.2,
#    'rhum': 95,
#    'prcp': None,
#    'snow': None,
#    'wdir': 160,
#    'wspd': 9.4,
#    'wpgt': None,
#    'pres': 1024.1,
#    'tsun': None,
#    'coco': None},
#   {'time': '2019-01-08 06:00:00',
#    'temp': 11.5,
#    'dwpt': 10.6,
#    'rhum': 94,
#    'prcp': None,
#    'snow': None,
#    'wdir': 140,
#    'wspd': 13,
#    'wpgt': None,
#    'pres': 1023.8,
#    'tsun': None,
#    'coco': None},
#   {'time': '2019-01-08 07:00:00',
#    'temp': 11.2,
#    'dwpt': 10.4,
#    'rhum': 95,
#    'prcp': None,
#    'snow': None,
#    'wdir': 140,
#    'wspd': 13,
#    'wpgt': None,
#    'pres': 1024.1,
#    'tsun': None,
#    'coco': None},
#   {'time': '2019-01-08 08:00:00',
#    'temp': 11.2,
#    'dwpt': 10.4,
#    'rhum': 95,
#    'prcp': None,
#    'snow': None,
#    'wdir': 130,
#    'wspd': 13,
#    'wpgt': None,
#    'pres': 1024.4,
#    'tsun': None,
#    'coco': None},
#   {'time': '2019-01-08 09:00:00',
#    'temp': 12.5,
#    'dwpt': 11.6,
#    'rhum': 94,
#    'prcp': None,
#    'snow': None,
#    'wdir': 150,
#    'wspd': 7.6,
#    'wpgt': None,
#    'pres': 1024.6,
#    'tsun': None,
#    'coco': None},
#   {'time': '2019-01-08 10:00:00',
#    'temp': 13.1,
#    'dwpt': 11.5,
#    'rhum': 90,
#    'prcp': None,
#    'snow': None,
#    'wdir': 100,
#    'wspd': 11.2,
#    'wpgt': None,
#    'pres': 1025.1,
#    'tsun': None,
#    'coco': None},
#   {'time': '2019-01-08 11:00:00',
#    'temp': 13.6,
#    'dwpt': 10,
#    'rhum': 79,
#    'prcp': None,
#    'snow': None,
#    'wdir': 100,
#    'wspd': 11.2,
#    'wpgt': None,
#    'pres': 1025.1,
#    'tsun': None,
#    'coco': None},
#   {'time': '2019-01-08 12:00:00',
#    'temp': 14.7,
#    'dwpt': 10.1,
#    'rhum': 74,
#    'prcp': None,
#    'snow': None,
#    'wdir': 110,
#    'wspd': 14.8,
#    'wpgt': None,
#    'pres': 1024,
#    'tsun': None,
#    'coco': None},
#   {'time': '2019-01-08 13:00:00',
#    'temp': 15,
#    'dwpt': 10.4,
#    'rhum': 74,
#    'prcp': None,
#    'snow': None,
#    'wdir': 110,
#    'wspd': 16.6,
#    'wpgt': None,
#    'pres': 1022.9,
#    'tsun': None,
#    'coco': None},
#   {'time': '2019-01-08 14:00:00',
#    'temp': 15.6,
#    'dwpt': 10.6,
#    'rhum': 72,
#    'prcp': None,
#    'snow': None,
#    'wdir': 100,
#    'wspd': 18.4,
#    'wpgt': None,
#    'pres': 1022.1,
#    'tsun': None,
#    'coco': None},
#   {'time': '2019-01-08 15:00:00',
#    'temp': 14.5,
#    'dwpt': 10.5,
#    'rhum': 77,
#    'prcp': None,
#    'snow': None,
#    'wdir': 110,
#    'wspd': 14.8,
#    'wpgt': None,
#    'pres': 1021.9,
#    'tsun': None,
#    'coco': None},
#   {'time': '2019-01-08 16:00:00',
#    'temp': 14.2,
#    'dwpt': 10.8,
#    'rhum': 80,
#    'prcp': None,
#    'snow': None,
#    'wdir': 110,
#    'wspd': 16.6,
#    'wpgt': None,
#    'pres': 1021.9,
#    'tsun': None,
#    'coco': None},
#   {'time': '2019-01-08 17:00:00',
#    'temp': 13.6,
#    'dwpt': 10.8,
#    'rhum': 83,
#    'prcp': None,
#    'snow': None,
#    'wdir': 110,
#    'wspd': 18.4,
#    'wpgt': None,
#    'pres': 1022.2,
#    'tsun': None,
#    'coco': None},
#   {'time': '2019-01-08 18:00:00',
#    'temp': 13.2,
#    'dwpt': 10.6,
#    'rhum': 84,
#    'prcp': None,
#    'snow': None,
#    'wdir': 120,
#    'wspd': 18.4,
#    'wpgt': None,
#    'pres': 1022.1,
#    'tsun': None,
#    'coco': None},
#   {'time': '2019-01-08 19:00:00',
#    'temp': 12.7,
#    'dwpt': 10.8,
#    'rhum': 88,
#    'prcp': None,
#    'snow': None,
#    'wdir': 120,
#    'wspd': 18.4,
#    'wpgt': None,
#    'pres': 1022.5,
#    'tsun': None,
#    'coco': None},
#   {'time': '2019-01-08 20:00:00',
#    'temp': 12.1,
#    'dwpt': 9.7,
#    'rhum': 85,
#    'prcp': None,
#    'snow': None,
#    'wdir': 120,
#    'wspd': 14.8,
#    'wpgt': None,
#    'pres': 1023.1,
#    'tsun': None,
#    'coco': None},
#   {'time': '2019-01-08 21:00:00',
#    'temp': 11.7,
#    'dwpt': 9.3,
#    'rhum': 85,
#    'prcp': None,
#    'snow': None,
#    'wdir': 130,
#    'wspd': 14.8,
#    'wpgt': None,
#    'pres': 1023.6,
#    'tsun': None,
#    'coco': None},
#   {'time': '2019-01-08 22:00:00',
#    'temp': 12,
#    'dwpt': 9.2,
#    'rhum': 83,
#    'prcp': None,
#    'snow': None,
#    'wdir': 140,
#    'wspd': 16.6,
#    'wpgt': None,
#    'pres': 1023.6,
#    'tsun': None,
#    'coco': None},
#   {'time': '2019-01-08 23:00:00',
#    'temp': 12.2,
#    'dwpt': 11.1,
#    'rhum': 93,
#    'prcp': None,
#    'snow': None,
#    'wdir': 120,
#    'wspd': 14.8,
#    'wpgt': None,
#    'pres': 1023.6,
#    'tsun': None,
#    'coco': None},
#   {'time': '2019-01-09 00:00:00',
#    'temp': 12,
#    'dwpt': 11.4,
#    'rhum': 96,
#    'prcp': None,
#    'snow': None,
#    'wdir': 130,
#    'wspd': 13,
#    'wpgt': None,
#    'pres': 1023.2,
#    'tsun': None,
#    'coco': None},
#   {'time': '2019-01-09 01:00:00',
#    'temp': 11.7,
#    'dwpt': 11.1,
#    'rhum': 96,
#    'prcp': None,
#    'snow': None,
#    'wdir': 150,
#    'wspd': 13,
#    'wpgt': None,
#    'pres': 1023.1,
#    'tsun': None,
#    'coco': None},
#   {'time': '2019-01-09 02:00:00',
#    'temp': 11.5,
#    'dwpt': 10.9,
#    'rhum': 96,
#    'prcp': None,
#    'snow': None,
#    'wdir': 150,
#    'wspd': 11.2,
#    'wpgt': None,
#    'pres': 1022.8,
#    'tsun': None,
#    'coco': None},
#   {'time': '2019-01-09 03:00:00',
#    'temp': 10.6,
#    'dwpt': 10,
#    'rhum': 96,
#    'prcp': None,
#    'snow': None,
#    'wdir': 170,
#    'wspd': 9.4,
#    'wpgt': None,
#    'pres': 1023.2,
#    'tsun': None,
#    'coco': None},
#   {'time': '2019-01-09 04:00:00',
#    'temp': 9.2,
#    'dwpt': 8.4,
#    'rhum': 95,
#    'prcp': None,
#    'snow': None,
#    'wdir': 160,
#    'wspd': 9.4,
#    'wpgt': None,
#    'pres': 1023.4,
#    'tsun': None,
#    'coco': None},
#   {'time': '2019-01-09 05:00:00',
#    'temp': 10.2,
#    'dwpt': 9.7,
#    'rhum': 97,
#    'prcp': None,
#    'snow': None,
#    'wdir': 360,
#    'wspd': 0,
#    'wpgt': None,
#    'pres': 1022.9,
#    'tsun': None,
#    'coco': None},
#   {'time': '2019-01-09 06:00:00',
#    'temp': 10,
#    'dwpt': 9.4,
#    'rhum': 96,
#    'prcp': None,
#    'snow': None,
#    'wdir': 360,
#    'wspd': 0,
#    'wpgt': None,
#    'pres': 1022.6,
#    'tsun': None,
#    'coco': None},
#   {'time': '2019-01-09 07:00:00',
#    'temp': 11.2,
#    'dwpt': 10.7,
#    'rhum': 97,
#    'prcp': None,
#    'snow': None,
#    'wdir': 130,
#    'wspd': 9.4,
#    'wpgt': None,
#    'pres': 1022.4,
#    'tsun': None,
#    'coco': None},
#   {'time': '2019-01-09 08:00:00',
#    'temp': 11.6,
#    'dwpt': 11.1,
#    'rhum': 97,
#    'prcp': None,
#    'snow': None,
#    'wdir': 140,
#    'wspd': 7.6,
#    'wpgt': None,
#    'pres': 1022.6,
#    'tsun': None,
#    'coco': None},
#   {'time': '2019-01-09 09:00:00',
#    'temp': 11.7,
#    'dwpt': 11.4,
#    'rhum': 98,
#    'prcp': None,
#    'snow': None,
#    'wdir': 150,
#    'wspd': 5.4,
#    'wpgt': None,
#    'pres': 1022.8,
#    'tsun': None,
#    'coco': None},
#   {'time': '2019-01-09 10:00:00',
#    'temp': 12.5,
#    'dwpt': 11.9,
#    'rhum': 96,
#    'prcp': None,
#    'snow': None,
#    'wdir': 120,
#    'wspd': 11.2,
#    'wpgt': None,
#    'pres': 1023.1,
#    'tsun': None,
#    'coco': None},
#   {'time': '2019-01-09 11:00:00',
#    'temp': 13.6,
#    'dwpt': 11.6,
#    'rhum': 88,
#    'prcp': None,
#    'snow': None,
#    'wdir': 100,
#    'wspd': 9.4,
#    'wpgt': None,
#    'pres': 1022.9,
#    'tsun': None,
#    'coco': None},
#   {'time': '2019-01-09 12:00:00',
#    'temp': 14.5,
#    'dwpt': 10.7,
#    'rhum': 78,
#    'prcp': None,
#    'snow': None,
#    'wdir': 110,
#    'wspd': 11.2,
#    'wpgt': None,
#    'pres': 1022.2,
#    'tsun': None,
#    'coco': None},
#   {'time': '2019-01-09 13:00:00',
#    'temp': 14.7,
#    'dwpt': 11.7,
#    'rhum': 82,
#    'prcp': None,
#    'snow': None,
#    'wdir': 90,
#    'wspd': 11.2,
#    'wpgt': None,
#    'pres': 1021,
#    'tsun': None,
#    'coco': None},
#   {'time': '2019-01-09 14:00:00',
#    'temp': 15.7,
#    'dwpt': 11.3,
#    'rhum': 75,
#    'prcp': None,
#    'snow': None,
#    'wdir': 90,
#    'wspd': 11.2,
#    'wpgt': None,
#    'pres': 1020,
#    'tsun': None,
#    'coco': None},
#   {'time': '2019-01-09 15:00:00',
#    'temp': 16.2,
#    'dwpt': 11.6,
#    'rhum': 74,
#    'prcp': None,
#    'snow': None,
#    'wdir': 100,
#    'wspd': 11.2,
#    'wpgt': None,
#    'pres': 1019.2,
#    'tsun': None,
#    'coco': None},
#   {'time': '2019-01-09 16:00:00',
#    'temp': 15.5,
#    'dwpt': 11.5,
#    'rhum': 77,
#    'prcp': None,
#    'snow': None,
#    'wdir': 100,
#    'wspd': 9.4,
#    'wpgt': None,
#    'pres': 1019.1,
#    'tsun': None,
#    'coco': None},
#   {'time': '2019-01-09 17:00:00',
#    'temp': 15.2,
#    'dwpt': 12,
#    'rhum': 81,
#    'prcp': None,
#    'snow': None,
#    'wdir': 120,
#    'wspd': 7.6,
#    'wpgt': None,
#    'pres': 1019.1,
#    'tsun': None,
#    'coco': None},
#   {'time': '2019-01-09 18:00:00',
#    'temp': 13.6,
#    'dwpt': 11.5,
#    'rhum': 87,
#    'prcp': None,
#    'snow': None,
#    'wdir': 130,
#    'wspd': 3.6,
#    'wpgt': None,
#    'pres': 1019.8,
#    'tsun': None,
#    'coco': None},
#   {'time': '2019-01-09 19:00:00',
#    'temp': 11.2,
#    'dwpt': 9.1,
#    'rhum': 87,
#    'prcp': None,
#    'snow': None,
#    'wdir': 270,
#    'wspd': 11.2,
#    'wpgt': None,
#    'pres': 1020.5,
#    'tsun': None,
#    'coco': None},
#   {'time': '2019-01-09 20:00:00',
#    'temp': 11.6,
#    'dwpt': 9.2,
#    'rhum': 85,
#    'prcp': None,
#    'snow': None,
#    'wdir': 240,
#    'wspd': 9.4,
#    'wpgt': None,
#    'pres': 1020.6,
#    'tsun': None,
#    'coco': None},
#   {'time': '2019-01-09 21:00:00',
#    'temp': 10.7,
#    'dwpt': 8.5,
#    'rhum': 86,
#    'prcp': None,
#    'snow': None,
#    'wdir': 230,
#    'wspd': 11.2,
#    'wpgt': None,
#    'pres': 1021.1,
#    'tsun': None,
#    'coco': None},
#   {'time': '2019-01-09 22:00:00',
#    'temp': 10.2,
#    'dwpt': 8.6,
#    'rhum': 90,
#    'prcp': None,
#    'snow': None,
#    'wdir': 260,
#    'wspd': 18.4,
#    'wpgt': None,
#    'pres': 1021.5,
#    'tsun': None,
#    'coco': None},
#   {'time': '2019-01-09 23:00:00',
#    'temp': 10.1,
#    'dwpt': 8.9,
#    'rhum': 92,
#    'prcp': None,
#    'snow': None,
#    'wdir': 270,
#    'wspd': 18.4,
#    'wpgt': None,
#    'pres': 1021.5,
#    'tsun': None,
#    'coco': None},
#   {'time': '2019-01-10 00:00:00',
#    'temp': 9.7,
#    'dwpt': 8.9,
#    'rhum': 95,
#    'prcp': None,
#    'snow': None,
#    'wdir': 270,
#    'wspd': 18.4,
#    'wpgt': None,
#    'pres': 1021.2,
#    'tsun': None,
#    'coco': None},
#   {'time': '2019-01-10 01:00:00',
#    'temp': 9.5,
#    'dwpt': 8.6,
#    'rhum': 94,
#    'prcp': None,
#    'snow': None,
#    'wdir': 280,
#    'wspd': 22.3,
#    'wpgt': None,
#    'pres': 1020.8,
#    'tsun': None,
#    'coco': None},
#   {'time': '2019-01-10 02:00:00',
#    'temp': 9.7,
#    'dwpt': 8.6,
#    'rhum': 93,
#    'prcp': None,
#    'snow': None,
#    'wdir': 290,
#    'wspd': 18.4,
#    'wpgt': None,
#    'pres': 1020.7,
#    'tsun': None,
#    'coco': None},
#   {'time': '2019-01-10 03:00:00',
#    'temp': 8.7,
#    'dwpt': 7.6,
#    'rhum': 93,
#    'prcp': None,
#    'snow': None,
#    'wdir': 290,
#    'wspd': 16.6,
#    'wpgt': None,
#    'pres': 1020.9,
#    'tsun': None,
#    'coco': None},
#   {'time': '2019-01-10 04:00:00',
#    'temp': 9,
#    'dwpt': 7.8,
#    'rhum': 92,
#    'prcp': None,
#    'snow': None,
#    'wdir': 280,
#    'wspd': 13,
#    'wpgt': None,
#    'pres': 1020.6,
#    'tsun': None,
#    'coco': None},
#   {'time': '2019-01-10 05:00:00',
#    'temp': 9.2,
#    'dwpt': 8,
#    'rhum': 92,
#    'prcp': None,
#    'snow': None,
#    'wdir': 270,
#    'wspd': 14.8,
#    'wpgt': None,
#    'pres': 1020.3,
#    'tsun': None,
#    'coco': None},
#   {'time': '2019-01-10 06:00:00',
#    'temp': 9,
#    'dwpt': 7.6,
#    'rhum': 91,
#    'prcp': None,
#    'snow': None,
#    'wdir': 280,
#    'wspd': 16.6,
#    'wpgt': None,
#    'pres': 1020.4,
#    'tsun': None,
#    'coco': None},
#   {'time': '2019-01-10 07:00:00',
#    'temp': 9.2,
#    'dwpt': 8.1,
#    'rhum': 93,
#    'prcp': None,
#    'snow': None,
#    'wdir': 270,
#    'wspd': 16.6,
#    'wpgt': None,
#    'pres': 1020.4,
#    'tsun': None,
#    'coco': None},
#   {'time': '2019-01-10 08:00:00',
#    'temp': 9.2,
#    'dwpt': 8.1,
#    'rhum': 93,
#    'prcp': None,
#    'snow': None,
#    'wdir': 270,
#    'wspd': 13,
#    'wpgt': None,
#    'pres': 1020.9,
#    'tsun': None,
#    'coco': None},
#   {'time': '2019-01-10 09:00:00',
#    'temp': 10.7,
#    'dwpt': 9,
#    'rhum': 89,
#    'prcp': None,
#    'snow': None,
#    'wdir': 300,
#    'wspd': 14.8,
#    'wpgt': None,
#    'pres': 1021.1,
#    'tsun': None,
#    'coco': None},
#   {'time': '2019-01-10 10:00:00',
#    'temp': 12.5,
#    'dwpt': 9.3,
#    'rhum': 81,
#    'prcp': None,
#    'snow': None,
#    'wdir': 300,
#    'wspd': 14.8,
#    'wpgt': None,
#    'pres': 1021.2,
#    'tsun': None,
#    'coco': None},
#   {'time': '2019-01-10 11:00:00',
#    'temp': 14.1,
#    'dwpt': 9.1,
#    'rhum': 72,
#    'prcp': None,
#    'snow': None,
#    'wdir': 280,
#    'wspd': 5.4,
#    'wpgt': None,
#    'pres': 1020.9,
#    'tsun': None,
#    'coco': None},
#   {'time': '2019-01-10 12:00:00',
#    'temp': 14.5,
#    'dwpt': 8.7,
#    'rhum': 68,
#    'prcp': None,
#    'snow': None,
#    'wdir': 280,
#    'wspd': 14.8,
#    'wpgt': None,
#    'pres': 1020.1,
#    'tsun': None,
#    'coco': None},
#   {'time': '2019-01-10 13:00:00',
#    'temp': 16,
#    'dwpt': 8.5,
#    'rhum': 61,
#    'prcp': None,
#    'snow': None,
#    'wdir': 280,
#    'wspd': 13,
#    'wpgt': None,
#    'pres': 1018.6,
#    'tsun': None,
#    'coco': None},
#   {'time': '2019-01-10 14:00:00',
#    'temp': 15.5,
#    'dwpt': 9.2,
#    'rhum': 66,
#    'prcp': None,
#    'snow': None,
#    'wdir': 300,
#    'wspd': 11.2,
#    'wpgt': None,
#    'pres': 1018.1,
#    'tsun': None,
#    'coco': None},
#   {'time': '2019-01-10 15:00:00',
#    'temp': 15.5,
#    'dwpt': 9.2,
#    'rhum': 66,
#    'prcp': None,
#    'snow': None,
#    'wdir': 260,
#    'wspd': 7.6,
#    'wpgt': None,
#    'pres': 1017.5,
#    'tsun': None,
#    'coco': None},
#   {'time': '2019-01-10 16:00:00',
#    'temp': 15.2,
#    'dwpt': 9.1,
#    'rhum': 67,
#    'prcp': None,
#    'snow': None,
#    'wdir': 270,
#    'wspd': 9.4,
#    'wpgt': None,
#    'pres': 1017.5,
#    'tsun': None,
#    'coco': None},
#   {'time': '2019-01-10 17:00:00',
#    'temp': 14.7,
#    'dwpt': 9.1,
#    'rhum': 69,
#    'prcp': None,
#    'snow': None,
#    'wdir': 280,
#    'wspd': 11.2,
#    'wpgt': None,
#    'pres': 1017.8,
#    'tsun': None,
#    'coco': None},
#   {'time': '2019-01-10 18:00:00',
#    'temp': 12.6,
#    'dwpt': 8.7,
#    'rhum': 77,
#    'prcp': None,
#    'snow': None,
#    'wdir': 260,
#    'wspd': 9.4,
#    'wpgt': None,
#    'pres': 1018.7,
#    'tsun': None,
#    'coco': None},
#   {'time': '2019-01-10 19:00:00',
#    'temp': 11.5,
#    'dwpt': 8.4,
#    'rhum': 81,
#    'prcp': None,
#    'snow': None,
#    'wdir': 230,
#    'wspd': 7.6,
#    'wpgt': None,
#    'pres': 1019,
#    'tsun': None,
#    'coco': None},
#   {'time': '2019-01-10 20:00:00',
#    'temp': 11.1,
#    'dwpt': 8.5,
#    'rhum': 84,
#    'prcp': None,
#    'snow': None,
#    'wdir': 230,
#    'wspd': 11.2,
#    'wpgt': None,
#    'pres': 1019.3,
#    'tsun': None,
#    'coco': None},
#   {'time': '2019-01-10 21:00:00',
#    'temp': 10.5,
#    'dwpt': 8.1,
#    'rhum': 85,
#    'prcp': None,
#    'snow': None,
#    'wdir': 250,
#    'wspd': 11.2,
#    'wpgt': None,
#    'pres': 1020.1,
#    'tsun': None,
#    'coco': None},
#   {'time': '2019-01-10 22:00:00',
#    'temp': 10.5,
#    'dwpt': 7.7,
#    'rhum': 83,
#    'prcp': None,
#    'snow': None,
#    'wdir': 240,
#    'wspd': 9.4,
#    'wpgt': None,
#    'pres': 1020.5,
#    'tsun': None,
#    'coco': None},
#   {'time': '2019-01-10 23:00:00',
#    'temp': 9.7,
#    'dwpt': 7.5,
#    'rhum': 86,
#    'prcp': None,
#    'snow': None,
#    'wdir': 160,
#    'wspd': 7.6,
#    'wpgt': None,
#    'pres': 1020.4,
#    'tsun': None,
#    'coco': None}]}

# %% [markdown]
# On the following cell we try to request data from different stations on the desired range, no matter it's longer than 10 days. After that we build a dataset with all features we want to analize for each station.

# %%
inicio = datetime(2018,1,1)   # start date
fin    = datetime(2018,1,31)   # end date

lista_fechas = [(inicio + timedelta(days=d)).strftime("%Y-%m-%d") for d in range((fin - inicio).days + 1)] 
lista_estaciones=["60015","60025"]
df_parcial=[]

#LISTADO IDENTIFICADORES DE ESTACIONES:

#id:60025 Tenerife Sur (Aeropuerto sur)
#id:60010 Izaña
#id:60015 Tenerife/Los Rodeos (Aeropuerto norte)

# In order to query data you will need to sign up for the Meteostat Developers Network and obtain an API key. 
# You must send your API Key along with every request. 
# Each request will be logged. 
# Free access to the Meteostat API is limited to 2,000 requests per day and no more than two requests per second. 
# Once this limit is reached, all of your requests will result in HTTP 429, too many requests, until your quota is cleared.
# Hourly data can be queried for a maximum of 10 days per request.

print ("Recorrer lista estaciones por Indices")
for x in range(0,len(lista_estaciones)):
    
    matriz=[]
    encabezado = ["time_"+lista_estaciones[x],"temp_"+lista_estaciones[x],"rhum_"+lista_estaciones[x],"wspd_"+lista_estaciones[x]]
       
    for y in range(0,len(lista_fechas)): #La API permite un rango máximo de 10 días por request
        website = 'https://api.meteostat.net/v2/stations/hourly?station='+lista_estaciones[x]+'&start='+lista_fechas[y]+'&end='+lista_fechas[y]
        URL = website # host website
        HEADERS = {'x-api-key':'erwezi3EUbckJZTIyEykn16bDspMbFg5'}
    
        # Runs the request to get the total URL with access key
        response = requests.get(url = URL, headers = HEADERS)#, params = PARAMS) 
        
        for stuff in response.json()['data']:
            matriz.append([stuff['time'],stuff['temp'],stuff['rhum'],stuff['wspd']]) #recorremos todas las filas y guardamos los parámetros que nos interesan
           
        time.sleep(0.35) #La API permite un máximo de 2 request por segundo!
            
    df_parcial.append(pd.DataFrame(data=matriz,columns=encabezado))
    
dataset = pd.concat(df_parcial, axis=1)                    

print('Checking dates: ' , inicio.strftime("%Y-%m-%d") , "to" , fin.strftime("%Y-%m-%d")) # printing the date 


# Read the status code
status = response.status_code

print(dataset)
# Out:
# Recorrer lista estaciones por Indices
# Checking dates:  2018-01-01 to 2018-01-31
#               time_60015  temp_60015  rhum_60015  wspd_60015  \
# 0    2018-01-01 00:00:00        13.7          86        16.6
# 1    2018-01-01 01:00:00        13.7          97        16.6
# 2    2018-01-01 02:00:00        13.2          98        11.2
# 3    2018-01-01 03:00:00        13.1          89        14.8
# 4    2018-01-01 04:00:00        13.0          94        13.0
# ..                   ...         ...         ...         ...
# 739  2018-01-31 19:00:00        11.7          91        38.9
# 740  2018-01-31 20:00:00        11.6          93        38.9
# 741  2018-01-31 21:00:00        11.0          94        31.3
# 742  2018-01-31 22:00:00        11.2          89        31.3
# 743  2018-01-31 23:00:00        11.1          83        31.3
#
#               time_60025  temp_60025  rhum_60025  wspd_60025
# 0    2018-01-01 00:00:00        19.0          64        31.3
# 1    2018-01-01 01:00:00        19.5          47        35.3
# 2    2018-01-01 02:00:00        19.7          38        37.1
# 3    2018-01-01 03:00:00        19.1          49        29.5
# 4    2018-01-01 04:00:00        19.0          48        29.5
# ..                   ...         ...         ...         ...
# 739  2018-01-31 19:00:00        17.5          63         0.0
# 740  2018-01-31 20:00:00        16.8          63         0.0
# 741  2018-01-31 21:00:00        16.6          73         1.8
# 742  2018-01-31 22:00:00        16.3          77         3.6
# 743  2018-01-31 23:00:00        15.3          77         9.4
#
# [744 rows x 8 columns]
