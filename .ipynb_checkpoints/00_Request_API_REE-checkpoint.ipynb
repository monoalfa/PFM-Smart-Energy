# %% [markdown]
# # PFM: Requests - API Esios REE

# %% [markdown]
# The objective of this session is to understand how data can be retrieved from specific sources as REE API.
#
# To do so, we will use `requests` library and `json` libraries for Python. These libraries are considered as wrappers.
#
# Later on, we will use specific libraries for plotting as `matplotlib` and `datetime`.

# %%
# import requests library
import requests 
import json
# import plotting library
import matplotlib
import matplotlib.pyplot as plt 
import datetime
import pandas as pd #importamos Pandas!
import numpy as np

# %% [markdown]
# As we have seen before, when we work with APIs, we have to write the endpoint we want to access.
# We need to write also the folder/section we want to access. We can have the same endpoint and different sections from where to get information.
#
# Most of the times, we need to add some headers to our requests that are required to get the information. The most important one is the **Authorization**, which corresponds to our ID to access that API.

# %% [markdown]
# ### Listado de archivos JSON

# %%
endpoint = 'https://api.esios.ree.es'
get_archives = '/archives_json'
headers = {'Accept': 'application/json;application/vnd.esios-api-v1+json',
           'Host': 'api.esios.ree.es',
           'Authorization': 'Token token=\"3627f9a1b46617055cb615ed161382e551ec7baa18466965dfd2cda3ebfc7307"',
          }

params = {'date': '20190101'}

# %% [markdown]
# Then, we can write the request according to the requests library and get callable object.

# %%
request = requests.get(endpoint+get_archives, headers=headers, params=params)

# %% [markdown]
# After that, we can check if the request is correct or not according to the response we get from the API.

# %%
request
# Out:
# <Response [200]>

# %% [markdown]
# In this case, the response we get is **200**, meaning that is has been accepted and the connection is established.
# There are different codes that tell us which is our connection status between us and the API.

# %%
status = request.status_code

# %%
#Check the status code
if status < 200:
    print('informational')
    # If the status code is 200, treat the information.
elif status >= 200 and status < 300:
    print('Connection is established')
    #okBehavior(response) # runs the function to get list of archives
elif status >= 300 and status < 400:
    print('redirection')
elif status >= 400 and status < 500:
    print('client error')
else:
    print('server error')
# Out:
# Connection is established

# %% [markdown]
# The data can be accessed by means of a json file. By doing this, we can see all the IDs available for us to obtain data.

# %%
# accessing data by means of a json object
data = request.json()

# %%
data
# Out:
# {'archives': [{'id': 171,
#    'name': 'IND_InformacionApp',
#    'description': 'IND_InformacionApp',
#    'horizon': 'NA',
#    'archive_type': 'json',
#    'json_download': {'name': 'IND_InformacionApp',
#     'type': 'JSON',
#     'url': '/archives/171/download_json?locale=es'},
#    'taxonomy_terms': [],
#    'vocabularies': [{'id_vocabulary': 20, 'name': 'Universo'},
#     {'id_vocabulary': 21, 'name': 'Temática'},
#     {'id_vocabulary': 22, 'name': 'Área'}]},
#   {'id': 170,
#    'name': 'IND_CoeficientesCO2',
#    'description': 'IND_CoeficientesCO2',
#    'horizon': 'NA',
#    'archive_type': 'json',
#    'json_download': {'name': 'IND_CoeficientesCO2',
#     'type': 'JSON',
#     'url': '/archives/170/download_json?locale=es'},
#    'taxonomy_terms': [],
#    'vocabularies': [{'id_vocabulary': 20, 'name': 'Universo'},
#     {'id_vocabulary': 21, 'name': 'Temática'},
#     {'id_vocabulary': 22, 'name': 'Área'}]},
#   {'id': 169,
#    'name': 'IND_EnergiaAnualNacional',
# ...

# %% [markdown]
# As we can see from the script below, we can see different IDs that are related to different types of information. For example:
#
# - ID:140 → means the Annual Energy consumed by resource type.
# - ID:139 → means the Monthly Energy consumed by resource type.
# - ID:64 → Installed capacity in Spain, per resource.
# - ID:115 → Demanda Real Generada.
# - ID:114 → Demanda Prevista Generada.
# - ID:111 → Datos estructurales de las unidades de programación.
# - ID:110 → Datos estructurales de las unidades de generación.
# - ID:82/81?
#
#
# In our case, today we would like to check ID 66, analysing the final PVPC prices for different days and timeperiods.

# %% [markdown]
# ### Archivo de demanda real generada

# %%
get_json = '/archives/115/download_json?locale=es'
request = requests.get(endpoint+get_json, headers=headers, params=params)
request
# Out:
# <Response [200]>

# %%
request.headers
# Out:
# {'Date': 'Thu, 01 Oct 2020 10:55:47 GMT', 'Server': 'MSX-2', 'Strict-Transport-Security': 'max-age=63072000;', 'X-Frame-Options': 'SAMEORIGIN, SAMEORIGIN', 'Content-Type': 'application/json', 'Status': '200 OK', 'X-XSS-Protection': '1; mode=block', 'X-Content-Type-Options': 'nosniff', 'Content-Disposition': 'download; filename="IND_DemandaRealGen"', 'Content-Transfer-Encoding': 'binary', 'Cache-Control': 'private', 'X-Request-Id': 'e0410ba4-b1e6-495f-a5f1-587615602d98', 'X-Runtime': '0.071188', 'Referrer-policy': 'no-referrer', 'Keep-Alive': 'timeout=5, max=100', 'Connection': 'Keep-Alive', 'Transfer-Encoding': 'chunked', 'Set-Cookie': 'visid_incap_1885724=/ONGciuXQyKVHjcCVDSi3rC1dV8AAAAAQUIPAAAAAACeF8wM/6XX1LU1AfDNncVU; expires=Thu, 30 Sep 2021 16:43:47 GMT; HttpOnly; path=/; Domain=.esios.ree.es; Secure; SameSite=None, incap_ses_509_1885724=0PrOSRYjhAoXuzDt8lQQB7K1dV8AAAAAbhJjOQu7VfL+Yg9cpLtqmQ==; path=/; Domain=.esios.ree.es; Secure; SameSite=None', 'X-CDN': 'Incapsula', 'Content-
# ...

# %%
request.text
# Out:
# 'IND_DemandaRealGen({"valoresHorariosGeneracion":[{"ts":"2018-12-31 21:00","dem":29148,"nuc":6079,"gf":0,"car":2519,"cc":4653,"hid":4660,"eol":3395,"aut":0,"inter":4560,"icb":-253,"sol":30,"solFot":2,"solTer":28,"termRenov":376,"cogenResto":3103},{"ts":"2018-12-31 21:10","dem":28937,"nuc":6072,"gf":0,"car":2546,"cc":4759,"hid":4592,"eol":3440,"aut":0,"inter":4273,"icb":-224,"sol":30,"solFot":2,"solTer":27,"termRenov":377,"cogenResto":3087},{"ts":"2018-12-31 21:20","dem":28555,"nuc":6073,"gf":0,"car":2535,"cc":4744,"hid":4233,"eol":3438,"aut":0,"inter":4241,"icb":-202,"sol":30,"solFot":2,"solTer":28,"termRenov":377,"cogenResto":3087},{"ts":"2018-12-31 21:30","dem":28120,"nuc":6077,"gf":0,"car":2471,"cc":4586,"hid":3639,"eol":3495,"aut":0,"inter":4540,"icb":-201,"sol":30,"solFot":2,"solTer":28,"termRenov":377,"cogenResto":3087},{"ts":"2018-12-31 21:40","dem":27680,"nuc":6078,"gf":0,"car":2339,"cc":4578,"hid":3765,"eol":3567,"aut":0,"inter":4052,"icb":-201,"sol":30,"solFot":2,"solTer":2
# ...

# %%
fix_json=lambda t:json.loads(t[t.find('(')+1:t.rfind(')')])
fix_json(request.text)
# Out:
# {'valoresHorariosGeneracion': [{'ts': '2018-12-31 21:00',
#    'dem': 29148,
#    'nuc': 6079,
#    'gf': 0,
#    'car': 2519,
#    'cc': 4653,
#    'hid': 4660,
#    'eol': 3395,
#    'aut': 0,
#    'inter': 4560,
#    'icb': -253,
#    'sol': 30,
#    'solFot': 2,
#    'solTer': 28,
#    'termRenov': 376,
#    'cogenResto': 3103},
#   {'ts': '2018-12-31 21:10',
#    'dem': 28937,
#    'nuc': 6072,
#    'gf': 0,
#    'car': 2546,
#    'cc': 4759,
#    'hid': 4592,
#    'eol': 3440,
#    'aut': 0,
#    'inter': 4273,
#    'icb': -224,
#    'sol': 30,
#    'solFot': 2,
#    'solTer': 27,
#    'termRenov': 377,
#    'cogenResto': 3087},
#   {'ts': '2018-12-31 21:20',
#    'dem': 28555,
#    'nuc': 6073,
#    'gf': 0,
#    'car': 2535,
#    'cc': 4744,
#    'hid': 4233,
#    'eol': 3438,
#    'aut': 0,
#    'inter': 4241,
#    'icb': -202,
#    'sol': 30,
#    'solFot': 2,
#    'solTer': 28,
#    'termRenov': 377,
#    'cogenResto': 3087},
#   {'ts': '2018-12-31 21:30',
# ...

# %% [markdown]
# info:
# Es el sumatorio de la medida en tiempo real para los distintos tipos de producción.
# El desglose de este indicador proporciona los MW generados por cada tipo de producción medidos en tiempo real.
# Publicación: cada 10 minutos con la información de los 10 minutos anteriores.
#
# Podemos obtener estos datos con enlace web URL Indicador DEMANDA REAL SUMA GENERACIÓN:
# https://www.esios.ree.es/es/analisis/10004?vis=1&start_date=01-01-2019T00%3A00&end_date=01-01-2019T23%3A50&compare_start_date=31-12-2018T00%3A00&groupby=minutes10&compare_indicators=550,1297,1295,1294,1296,547,554,551,548,546,553,549,552,555
#
# Podemos conseguir mucha info interesante creo así y desglosar según nuestros intereses.

# %%
request.headers
# Out:
# {'Date': 'Thu, 01 Oct 2020 10:55:47 GMT', 'Server': 'MSX-2', 'Strict-Transport-Security': 'max-age=63072000;', 'X-Frame-Options': 'SAMEORIGIN, SAMEORIGIN', 'Content-Type': 'application/json', 'Status': '200 OK', 'X-XSS-Protection': '1; mode=block', 'X-Content-Type-Options': 'nosniff', 'Content-Disposition': 'download; filename="IND_DemandaRealGen"', 'Content-Transfer-Encoding': 'binary', 'Cache-Control': 'private', 'X-Request-Id': 'e0410ba4-b1e6-495f-a5f1-587615602d98', 'X-Runtime': '0.071188', 'Referrer-policy': 'no-referrer', 'Keep-Alive': 'timeout=5, max=100', 'Connection': 'Keep-Alive', 'Transfer-Encoding': 'chunked', 'Set-Cookie': 'visid_incap_1885724=/ONGciuXQyKVHjcCVDSi3rC1dV8AAAAAQUIPAAAAAACeF8wM/6XX1LU1AfDNncVU; expires=Thu, 30 Sep 2021 16:43:47 GMT; HttpOnly; path=/; Domain=.esios.ree.es; Secure; SameSite=None, incap_ses_509_1885724=0PrOSRYjhAoXuzDt8lQQB7K1dV8AAAAAbhJjOQu7VfL+Yg9cpLtqmQ==; path=/; Domain=.esios.ree.es; Secure; SameSite=None', 'X-CDN': 'Incapsula', 'Content-
# ...

# %%
demanda = []

# %%
for time_period in fix_json(request.text)['valoresHorariosGeneracion']:
    demanda.append(time_period['dem'])
    print(f"Demand at {time_period['ts']} is {time_period['dem']} MW")
# Out:
# Demand at 2018-12-31 21:00 is 29148 MW
# Demand at 2018-12-31 21:10 is 28937 MW
# Demand at 2018-12-31 21:20 is 28555 MW
# Demand at 2018-12-31 21:30 is 28120 MW
# Demand at 2018-12-31 21:40 is 27680 MW
# Demand at 2018-12-31 21:50 is 27207 MW
# Demand at 2018-12-31 22:00 is 26695 MW
# Demand at 2018-12-31 22:10 is 26453 MW
# Demand at 2018-12-31 22:20 is 26058 MW
# Demand at 2018-12-31 22:30 is 25696 MW
# Demand at 2018-12-31 22:40 is 25419 MW
# Demand at 2018-12-31 22:50 is 25232 MW
# Demand at 2018-12-31 23:00 is 25055 MW
# Demand at 2018-12-31 23:10 is 24762 MW
# Demand at 2018-12-31 23:20 is 24656 MW
# Demand at 2018-12-31 23:30 is 24486 MW
# Demand at 2018-12-31 23:40 is 24365 MW
# Demand at 2018-12-31 23:50 is 24212 MW
# Demand at 2019-01-01 00:00 is 23676 MW
# Demand at 2019-01-01 00:10 is 23511 MW
# Demand at 2019-01-01 00:20 is 23531 MW
# Demand at 2019-01-01 00:30 is 23420 MW
# Demand at 2019-01-01 00:40 is 23352 MW
# Demand at 2019-01-01 00:50 is 23264 MW
# ...

# %%
demanda
# Out:
# [29148,
#  28937,
#  28555,
#  28120,
#  27680,
#  27207,
#  26695,
#  26453,
#  26058,
#  25696,
#  25419,
#  25232,
#  25055,
#  24762,
#  24656,
#  24486,
#  24365,
#  24212,
#  23676,
#  23511,
#  23531,
#  23420,
#  23352,
#  23264,
#  23128,
#  23108,
#  22889,
#  22705,
#  22548,
#  22308,
#  22109,
#  21824,
#  21550,
#  21297,
#  21044,
#  20867,
#  20666,
#  20528,
#  20349,
#  20159,
#  20012,
#  19859,
#  19680,
#  19636,
#  19530,
#  19411,
#  19305,
#  19219,
#  19227,
#  19221,
#  19168,
#  19159,
#  19114,
#  19095,
#  19156,
#  19329,
#  19247,
#  19331,
#  19348,
#  19378,
#  19471,
#  19703,
#  19773,
#  19686,
#  19902,
#  19900,
#  19873,
#  19961,
#  19793,
#  19670,
#  19650,
#  19566,
#  19642,
#  19894,
#  20101,
#  20326,
#  20671,
#  20940,
#  21205,
#  21519,
#  21809,
#  22020,
#  22449,
#  22515,
#  22733,
#  23043,
#  23217,
#  23431,
#  23523,
#  23610,
#  23682,
#  23691,
#  23710,
#  23757,
#  23964,
#  24026,
#  24151,
#  24218,
#  24323,
#  24302,
# ...

# %%
matplotlib.rc('xtick', labelsize=15)     
matplotlib.rc('ytick', labelsize=15)

plt.style.use('ggplot')
plt.figure(figsize=(20,10))
plt.plot(demanda,'r',linewidth=1.5)
plt.title(f"Demand curve", fontsize=20)
plt.xlabel('time series',fontsize=20 )
plt.ylabel('Demanda [MW]',fontsize=20)
plt.show()

# %% [markdown]
# ### Otros archivos

# %%
get_json = '/archives/114/download_json?locale=es'
request = requests.get(endpoint+get_json, headers=headers, params=params)
request
# Out:
# <Response [200]>

# %%
fix_json=lambda t:json.loads(t[t.find('(')+1:t.rfind(')')])
fix_json(request.text)
# Out:
# {'valoresPrevistaProgramada': [{'ts': '2018-12-31 21:00',
#    'pro': 27658,
#    'pre': 29109},
#   {'ts': '2018-12-31 21:10', 'pro': 27658, 'pre': 28797},
#   {'ts': '2018-12-31 21:20', 'pro': 27658, 'pre': 28453},
#   {'ts': '2018-12-31 21:30', 'pro': 27658, 'pre': 28075},
#   {'ts': '2018-12-31 21:40', 'pro': 27658, 'pre': 27664},
#   {'ts': '2018-12-31 21:50', 'pro': 27658, 'pre': 27219},
#   {'ts': '2018-12-31 22:00', 'pro': 25423, 'pre': 26741},
#   {'ts': '2018-12-31 22:10', 'pro': 25423, 'pre': 26278},
#   {'ts': '2018-12-31 22:20', 'pro': 25423, 'pre': 25877},
#   {'ts': '2018-12-31 22:30', 'pro': 25423, 'pre': 25539},
#   {'ts': '2018-12-31 22:40', 'pro': 25423, 'pre': 25263},
#   {'ts': '2018-12-31 22:50', 'pro': 25423, 'pre': 25050},
#   {'ts': '2018-12-31 23:00', 'pro': 23922, 'pre': 24899},
#   {'ts': '2018-12-31 23:10', 'pro': 23922, 'pre': 24771},
#   {'ts': '2018-12-31 23:20', 'pro': 23922, 'pre': 24627},
#   {'ts': '2018-12-31 23:30', 'pro': 23922, 'pre': 24466},
# ...

# %% [markdown]
# #### Leyenda
# pro: Potencia programada según P48. Es la demanda de energía programada calculada mediante los intercambios internacionales programados y los programas de los grupos de generación a los que se les haya asignado suministro de energía en la casación de los mercados diario e intradiario, así como en los mercados de energías de balance RR y regulación terciaria. Estos dos últimos son gestionados por REE teniendo en cuenta la evolución de la demanda.
#
# pre: Potencia prevista según REE teniendo en cuenta los valores de consumo registrados en periodos precedentes similares, así como otros factores con influencia en el consumo eléctrico como la laboralidad, la climatología y la actividad económica.
#
# NOTA: creo que puedo conseguir el P48 (programado) desglosado por tecnología, con el enlace URL como hacemos más abajo en el day-ahead market. Quizás nos va mejor para nuestro modelo. Pero perderemos granularidad, de 10 minutos a periodos horarios.
#
# https://www.esios.ree.es/es/balance?date=01-01-2019&program=P48&agg=hour

# %%
get_json = '/archives/111/download_json?locale=es'
request = requests.get(endpoint+get_json, headers=headers, params=params)
request.json()
# Out:
# {'message': 'No values for specified archive'}

# %%
get_json = '/archives/110/download_json?locale=es'
request = requests.get(endpoint+get_json, headers=headers, params=params)
request.json()
# Out:
# {'message': 'No values for specified archive'}

# %%
get_json = '/archives/82/download_json?locale=es'
request = requests.get(endpoint+get_json, headers=headers, params=params)
request.json()
# Out:
# {'message': 'No values for specified archive'}

# %%
get_json = '/archives/81/download_json?locale=es'
request = requests.get(endpoint+get_json, headers=headers, params=params)
request.json()
# Out:
# {'message': 'No values for specified archive'}

# %%
get_json = '/archives/65/download_json?locale=es'
request = requests.get(endpoint+get_json, headers=headers, params=params)
request.json()
# Out:
# {'PrecioDesvíos': [{'Precio': [{'Dia': '01-01-2019',
#      'Hora': '00-01',
#      'PRSU': '66,88',
#      'PRBA': '66,88',
#      'COS': '-',
#      'SEN': 'Bajar'},
#     {'Dia': '01-01-2019',
#      'Hora': '01-02',
#      'PRSU': '66,88',
#      'PRBA': '66,88',
#      'COS': '-',
#      'SEN': 'Bajar'},
#     {'Dia': '01-01-2019',
#      'Hora': '02-03',
#      'PRSU': '38,68',
#      'PRBA': '66,00',
#      'COS': '41',
#      'SEN': 'Subir'},
#     {'Dia': '01-01-2019',
#      'Hora': '03-04',
#      'PRSU': '46,14',
#      'PRBA': '63,64',
#      'COS': '27',
#      'SEN': 'Subir'},
#     {'Dia': '01-01-2019',
#      'Hora': '04-05',
#      'PRSU': '47,06',
#      'PRBA': '58,85',
#      'COS': '20',
#      'SEN': 'Subir'},
#     {'Dia': '01-01-2019',
#      'Hora': '05-06',
#      'PRSU': '47,04',
#      'PRBA': '55,47',
#      'COS': '15',
#      'SEN': 'Subir'},
#     {'Dia': '01-01-2019',
#      'Hora': '06-07',
#      'PRSU': '47,04',
#      'PRBA': '56,00',
# ...

# %%
get_json = '/archives/63/download_json?locale=es'
request = requests.get(endpoint+get_json, headers=headers, params=params)
request.json()
# Out:
# {'Interconexiones': [{'CAPT': [{'Dia': '01-01-2019',
#      'Hora': '00-01',
#      'SEN': 'IMP',
#      'COM': '6.733',
#      'UTI': '37,0'},
#     {'Dia': '01-01-2019',
#      'Hora': '00-01',
#      'SEN': 'EXP',
#      'COM': '4.933',
#      'UTI': '0,0'},
#     {'Dia': '01-01-2019',
#      'Hora': '01-02',
#      'SEN': 'IMP',
#      'COM': '6.133',
#      'UTI': '33,3'},
#     {'Dia': '01-01-2019',
#      'Hora': '01-02',
#      'SEN': 'EXP',
#      'COM': '6.533',
#      'UTI': '0,0'},
#     {'Dia': '01-01-2019',
#      'Hora': '02-03',
#      'SEN': 'IMP',
#      'COM': '6.133',
#      'UTI': '29,0'},
#     {'Dia': '01-01-2019',
#      'Hora': '02-03',
#      'SEN': 'EXP',
#      'COM': '6.533',
#      'UTI': '0,0'},
#     {'Dia': '01-01-2019',
#      'Hora': '03-04',
#      'SEN': 'IMP',
#      'COM': '6.133',
#      'UTI': '22,3'},
#     {'Dia': '01-01-2019',
#      'Hora': '03-04',
#      'SEN': 'EXP',
#      'COM': '6.533',
#      'UTI': '0,0'},
# ...

# %%
get_json = '/archives/62/download_json?locale=es'
request = requests.get(endpoint+get_json, headers=headers, params=params)
request.json()
# Out:
# {'DemandaInterrumpible': [{'Comunidades': [{'ts': '0101190000',
#      'ca': 'AN',
#      'dem': '137,2',
#      'co2': '21,5'},
#     {'ts': '0101190000', 'ca': 'AR', 'dem': '98,8', 'co2': '19,9'},
#     {'ts': '0101190000', 'ca': 'AS', 'dem': '524,8', 'co2': '87,7'},
#     {'ts': '0101190000', 'ca': 'CA', 'dem': '52,7', 'co2': '11,8'},
#     {'ts': '0101190000', 'ca': 'CL', 'dem': '21,1', 'co2': '4,5'},
#     {'ts': '0101190000', 'ca': 'CM', 'dem': '2,4', 'co2': ',4'},
#     {'ts': '0101190000', 'ca': 'CT', 'dem': '122,3', 'co2': '22,3'},
#     {'ts': '0101190000', 'ca': 'EX', 'dem': '3,7', 'co2': ',7'},
#     {'ts': '0101190000', 'ca': 'GL', 'dem': '619,9', 'co2': '135,1'},
#     {'ts': '0101190000', 'ca': 'IB', 'dem': ',2', 'co2': '0'},
#     {'ts': '0101190000', 'ca': 'MA', 'dem': '17,3', 'co2': '3,2'},
#     {'ts': '0101190000', 'ca': 'MU', 'dem': '11,3', 'co2': '2,5'},
#     {'ts': '0101190000', 'ca': 'NA', 'dem': '26,9', 'co2': '4,4'},
# ...

# %% [markdown]
# ### Listado de indicadores

# %%
get_indicators = '/indicators'
request = requests.get(endpoint+get_indicators, headers=headers, params=params)
request.json()
# Out:
# {'indicators': [{'name': 'Requisito mínimo de control de flujo en España-Francia en sentido exportador',
#    'description': '<p>El mecanismo de asignaci&oacute;n de energ&iacute;as de balance RR es un servicio que tiene por objeto restablecer o mantener el nivel de energ&iacute;as de recuperaci&oacute;n de la frecuencia con activaci&oacute;n manual y autom&aacute;tica (energ&iacute;as de regulaci&oacute;n secundaria y terciaria) requerido al objeto de prepararse para desequilibrios adicionales del sistema.</p>\n\n<p>Este servicio se encuentra regulado en el P.O.-3.3</p>\n\n<p>En concreto este indicador se refiere al requisito m&iacute;nimo de control de flujo solicitado por el OS para la interconexi&oacute;n entre Espa&ntilde;a y Francia&nbsp;en sentido exportador.</p>\n\n<p><b>Publicaci&oacute;n:</b>&nbsp;diariamente con la informaci&oacute;n del d&iacute;a D-1 sobre las 5:00 horas.</p>',
#    'id': 1829},
#   {'name': 'Asignación a bajar de energías de balance RR por IC SEE',
# ...

# %% [markdown]
# INDICADORES DE INTERÉS
#
# ID:10354 Generación T.Real no renovable SNP (desglose subsistemas)
# ID:10353 Generación T.Real renovable SNP (desglose subsistemas)
# ID:10350 Demanda real suma de generación SNP (desglose subsistemas)
# ID:1748 Generación T.Real solar fotovoltaica SNP (desglose subsistemas)
# ID:1749 Generación T.Real hidráulica SNP (desglose subsistemas)
# ID:1747 Generación T.Real turbina de vapor SNP (desglose subsistemas)
# ID:1755 Generación T.Real cogeneración SNP (desglose subsistemas)
# ID:1754 Generación T.Real generación auxiliar SNP (desglose subsistemas)
# ID:1753 Generación T.Real residuos SNP (desglose subsistemas)
# ID:1752 Generación T.Real otras renovables SNP (desglose subsistemas)
# ID:1745 Generación T.Real eólica SNP (desglose subsistemas)
# ID:1751 Generación T.Real enlace balear SNP (desglose subsistemas)
# ID:1746 Generación T.Real ciclo combinado SNP (desglose subsistemas)
# ID:1744 Generación T.Real turbina de gas SNP (desglose subsistemas)
# ID:1743 Generación T.Real motores diésel SNP (desglose subsistemas)
# ID:1750 Generación T.Real carbón SNP (desglose subsistemas)
# ID:1740 Demanda Real SNP (desglose subsistemas)
# ID:1741 Demanda programada SNP (desglose subsistemas)
# ID:10248 Generación en los SNP (desglose subsistemas)
# ID:10246 Generación en Canarias (desglose subsistemas)
# ID:10245 Demanda en los SNP (desglose subsistemas)
# ID:10243 Demanda en Canarias (desglose subsistemas)
# ID:1337 Precio medio de la generación en los SNP por subsistema (desglose subsistemas)
# ID:1336 Precio medio de la demanda en los SNP por subsistema (desglose subsistemas)
#
# CREO QUE PODRÍAMOS HACER UN MODELO CON LOS DATOS DE LOS SISTEMAS NO PENINSULARES Y CALCULAR EL COSTE POR BANDA DE REGULACIÓN SECUNDARÍA SEGÚN EL MIX DE GENERACIÓN REAL, LA CURVA PROGRAMADA Y DATOS METEOROLÓGICOS.
#
# ID:10271 Generación programada PHFC UGH + no UGH
# ID:10287 Generación programada PHFC total
# ID:10286 Generación programada + Consumo bombeo + Cable Baleares PHFC
# ID:10285 Ajuste de programas PHFC
# ID:10284 Saldo total interconexiones programa PHFC
# ID:10283 Generación programada PHFC otras renovables
# ID:10282 Generación programada PHFC Carbón
# ID:10281 Generación programada PHFC Eólica
# ID:10280 Generación programada PHFC Anexo II RD 134/2010
# ID:10279 Demanda programada PHFC total
# ID:10278 Generación programada PHFC Saldo Andorra
# ID:10277 Generación programada PHFC Saldo Marruecos
# ID:10273 Generación programada PHFC Cogeneración
# ID:10276 Generación programada PHFC Saldo Portugal
# ID:10275 Generación programada PHFC Saldo Francia
# ID:10274 Generación programada PHFC Residuos
# ID:10272 Generación programada PHFC Fuel-Gas
# ID:1426 Generación programada PHFC Genéricas
# ID:1425 Generación programada PHFC Enlace Baleares
# ID:1424 Generación programada PHFC Consumo bombeo
# ID:1423 Generación programada PHFC Residuos varios
# ID:1439 Demanda programada PHFC Corrección eólica
# ID:1437 Demanda programada PHFC Consumos directos en mercado
# ID:1438 Demanda programada PHFC Consumo de Servicios Auxiliares
# ID:1441 Demanda programada PHFC Corrección REE
# ID:1436 Demanda programada PHFC Comercializadores de referencia
# ID:1440 Demanda programada PHFC Corrección solar
# ID:1435 Demanda programada PHFC Comercializadores mercado libre
# ID:1409 Generación programada PHFC Fuel
# ID:1408 Generación programada PHFC Ciclo combinado
# ID:1407 Generación programada PHFC Hulla sub-bituminosa
# ID:1406 Generación programada PHFC Hulla antracita
# ID:1405 Generación programada PHFC Hulla sub-bituminosa Anexo II RD 134/2010
# ID:1404 Generación programada PHFC Hulla antracita Anexo II RD 134/2010
# ID:1403 Generación programada PHFC Nuclear
# ID:1402 Generación programada PHFC Turbinación bombeo
# ID:1401 Generación programada PHFC Hidráulica no UGH
# ID:1400 Generación programada PHFC Hidráulica UGH
# ID:1422 Generación programada PHFC Residuos domésticos y similares
# ID:1421 Generación programada PHFC Biogás
# ID:1420 Generación programada PHFC Biomasa
# ID:1419 Generación programada PHFC Energía residual
# ID:1418 Generación programada PHFC Subproductos minería
# ID:1417 Generación programada PHFC Derivados del petróleo ó carbón
# ID:1416 Generación programada PHFC Gas Natural Cogeneración
# ID:1415 Generación programada PHFC Océano y geotérmica
# ID:1414 Generación programada PHFC Solar térmica
# ID:1413 Generación programada PHFC Solar fotovoltaica
# ID:1412 Generación programada PHFC Eólica marina
# ID:1411 Generación programada PHFC Eólica terrestre
# ID:1410 Generación programada PHFC Gas Natural
#
# ID:10259 Generación programada PVP total
# ID:10229 Generación programada + Consumo bombeo + Cable Baleares PVP
# ID:10228 Generación programada + Consumo bombeo + Cable Baleares PVP
# ID:10197 Ajuste de programas PVP
# ID:10187 Saldo total interconexiones programa PVP
# ID:10176 Generación programada PVP otras renovables
# ID:10168 Generación programada PVP Carbón
# ID:10158 Generación programada PVP Eólica
# ID:10150 Generación programada PVP Anexo II RD 134/2010
# ID:10142 Demanda programada PVP total
# ID:10096 Generación programada PVP Residuos
# ID:10087 Generación programada PVP Cogeneración
# ID:10078 Generación programada PVP Fuel-Gas
# ID:10065 Generación programada PVP UGH + no UGH
#
# ID:10257 Generación programada P48 total
# ID:10238 Generación programada P48 Exportación Total
# ID:10237 Generación programada P48 Importación Total
# ID:10063 Generación programada P48 UGH + no UGH
# ID:10061 Generación programada P48 Anexo II RD 134/2010
# ID:10042 Total Generación + Total Interconexiones programada p48
# ID:10027 Demanda programada P48 total
# ID:10026 Saldo total interconexiones programa p48
# ID:10025 Ajuste de programas p48
# ID:10024 Generación programada + Consumo bombeo + Cable Baleares P48
# ID:10013 Generación programada P48 otras renovables
# ID:10012 Generación programada P48 Residuos no renovables
# ID:10011 Generación programada P48 Cogeneración
# ID:10010 Generación programada P48 Eólica
# ID:10009 Generación programada P48 Fuel-Gas
# ID:10008 Generación programada P48 Carbón
#
# ID:10352 Generación T.Real no renovable
# ID:10351 Generación T.Real renovable
# ID:10195 Generación medida total tipo producción (filtro provincias)
# ID:10206 Generación T.Real Solar
# ID:1297 Generación T.Real Cogeneración y resto
# ID:1296 Generación T.Real Térmica renovable
# ID:1295 Generación T.Real Solar fotovoltaica
# ID:1294 Generación T.Real Solar térmica
# ID:10004 Demanda real suma de generación
# ID:1293 Demanda real
# ID:1193 Demanda en consumo
# ID:1192 Demanda en barras de central
# ID:1183 Generación medida red de distribución (filtro por provincias)
# ID:10049 Total Generación + Total Interconexiones medidas (filtro por provincias)
# ID:10048 Saldo total interconexiones medidas (filtro por provincias)
# ID:10043 Generación medida total (filtro por provincias)
# ID:10041 Generación medida otras renovables (filtro por provincias)
# ID:10040 Generación medida Residuos no renovables (filtro por provincias)
# ID:10039 Generación medida cogeneración (filtro por provincias)
# ID:10038 Generación medida Fuel-gas (filtro por provincias)
# ID:10037 Generación medida Eólica (filtro por provincias)
# ID:10036 Generación medida Carbón (filtro por provincias)
# ID:10035 Generación medida Hidráulica (filtro por provincias)
# ID:1173 Generación medida Enlace Baleares (filtro por provincias)
# ID:1170 Generación medida Residuos domésticos y similares (filtro por provincias)
# ID:1167 Generación medida Energía residual (filtro por provincias)
# ID:1165 Generación medida Derivados del petróleo ó carbón (filtro por provincias)
# ID:1172 Generación medida Consumo bombeo (filtro por provincias)
# ID:1171 Generación medida Residuos varios (filtro por provincias)
# ID:1168 Generación medida Biomasa (filtro por provincias)
# ID:1166 Generación medida Subproductos minería (filtro por provincias)
# ID:1164 Generación medida Gas Natural Cogeneración (filtro por provincias)
# ID:1169 Generación medida Biogás (filtro por provincias)
# ID:1150 Generación medida Hidráulica UGH (filtro por provincias)
# ID:1162 Generación medida Solar térmica (filtro por provincias)
# ID:1160 Generación medida Eólica marina (filtro por provincias)
# ID:1156 Generación medida Ciclo combinado (filtro por provincias)
# ID:1155 Generación medida Hulla sub-bituminosa (filtro por provincias)
# ID:1154 Generación medida Hulla antracita (filtro por provincias)
# ID:1153 Generación medida Nuclear (filtro por provincias)
# ID:1152 Generación medida Turbinación bombeo (filtro por provincias)
# ID:1163 Generación medida Océano y geotérmica (filtro por provincias)
# ID:1161 Generación medida Solar fotovoltaica (filtro por provincias)
# ID:1158 Generación medida Gas Natural (filtro por provincias)
# ID:1159 Generación medida Eólica terrestre (filtro por provincias)
# ID:1157 Generación medida Fuel (filtro por provincias)
# ID:1151 Generación medida Hidráulica no UGH (filtro por provincias)
# ID:10205 Generación medida solar (desglose provincias)
#
#
# ID:10057 Energía total mercado de producción
# ID:10252 Volumen neto de energía utilizada de regulación secundaria
# ID:10056 Volumen absoluto de Energía utilizada de Regulación Secundaria
# ID:680 Energía utilizada de Regulación Secundaria subir
# ID:681 Energía utilizada de Regulación Secundaria bajar
# ID:682 Precio de Regulación Secundaria subir
# ID 683 Precio de Regulación Secundaria bajar
# ID:634 Precio Banda de regulación secundaria
# ID:899 Coste asignación de banda de Regulación Secundaria
# ID:811 Precio medio horario componente banda secundaria
# ID:712 Coste de banda de Regulación Secundaria
#
# ID:10032 Balance de desvíos medidos total
# ID:1338 Volumen neto de los desvíos generación-demanda
# ID:10211 Precio medio horario final suma de componentes
# ID:817 Precio medio horario final (creo que es igual que el id 10211)
#
# *Si conseguimos la energía total de las canarias, obtenemos el coste por banda secundaria creo...que lo podríamos meter en el dataset multiplicando por el ID:811. El problema es que el ID:811 y por lo tanto la nueva columna, dependen de todo el sistema eléctrico español, no únicamente de las curvas de generación y consumo de Tenerife por lo que hay que vigilar con eso a la hora de estructurar el modelo de aprendizaje.

# %%
get_indicators = '/indicators?text=regulación'
request = requests.get(endpoint+get_indicators, headers=headers, params=params)
request.json()
# Out:
# {'indicators': [{'name': 'Requerimientos de Regulación Terciaria bajar',
# ...

# %% [markdown]
# ### Indicador X (pruebas)

# %%
date_start = "2019-12-31"                # start date
date_end = "2019-12-31"                  # end date

startdate = date_start + "T00:00:00.00" # can specify more if desired
enddate = date_end + "T23:50:00.00"
indicator = str(1337)    # INDICADOR
#geo_id = str(8797)         # GEO_IDS 8797-Tenerife

#Energía correspondiente al programa operativo que el OS establece en cada período hasta el final del horizonte de programación diario

# You can get it by putting the mouse over the indicator name on the webpage. 
# webpage: https://www.esios.ree.es/es/analisis/10024
website = 'https://api.esios.ree.es/indicators/'+indicator+'?start_date='+startdate+'&end_date='+enddate#+'&geo_id[]='+geo_ids
     
     
print('Checking dates: ' , startdate , "to" , enddate) # printing the date 

URL = website # host website
GET = '/archives_json' # API link
HEADERS = {
            'Accept': "application/json; application/vnd.esios-api-v1+json",
            'Host': 'api.esios.ree.es',
            'Authorization': "Token token=\"3627f9a1b46617055cb615ed161382e551ec7baa18466965dfd2cda3ebfc7307",#"a6f2f926dea90ade64acc97b3b4fff73af5bdc5d7bce554a1adfa16d554ede81"',
            'Content-Type': 'application/json'}
#PARAMS = {'date':date}

# Runs the request to get the total URL with access token
response = requests.get(url = URL+GET, headers = HEADERS)#, params = PARAMS)

# Read the status code
status = response.status_code
# Out:
# Checking dates:  2019-12-31T00:00:00.00 to 2019-12-31T23:50:00.00

# %%
response.json()
# Out:
# {'indicator': {'name': 'Precio medio de la generación en los SNP por subsistema',
#   'short_name': 'Precio medio generación subsistema',
#   'id': 1337,
#   'composited': False,
#   'step_type': 'linear',
#   'disaggregated': True,
#   'magnitud': [{'name': 'Precio', 'id': 23}],
#   'tiempo': [{'name': 'Hora', 'id': 4}],
#   'geos': [{'geo_id': 8795, 'geo_name': 'Gran Canaria'},
#    {'geo_id': 8796, 'geo_name': 'Lanzarote y Fuerteventura'},
#    {'geo_id': 8797, 'geo_name': 'Tenerife'},
#    {'geo_id': 8798, 'geo_name': 'La Palma'},
#    {'geo_id': 8799, 'geo_name': 'La Gomera'},
#    {'geo_id': 8800, 'geo_name': 'El Hierro'},
#    {'geo_id': 8803, 'geo_name': 'Ceuta'},
#    {'geo_id': 8804, 'geo_name': 'Melilla'},
#    {'geo_id': 8823, 'geo_name': 'Baleares'}],
#   'values_updated_at': '2020-08-28T08:11:13.000+02:00',
#   'values': [{'value': 141.87,
#     'datetime': '2019-12-31T00:00:00.000+01:00',
#     'datetime_utc': '2019-12-30T23:00:00Z',
# ...

# %% [markdown]
# ### Preparación del dataset filtrando los datos para TENERIFE

# %%
date_start = "2019-12-31"                # start date
date_end = "2019-12-31"                  # end date

startdate = date_start + "T00:00:00.00" # can specify more if desired
enddate = date_end + "T23:50:00.00"

#ID:10354 Generación T.Real no renovable SNP (desglose subsistemas, granularidad 10')
#ID:10353 Generación T.Real renovable SNP (desglose subsistemas, granularidad 10')
#ID:10350 Demanda real suma de generación SNP (desglose subsistemas, granularidad 10')
#ID:1748 Generación T.Real solar fotovoltaica SNP (desglose subsistemas, granularidad 10')
#ID:1749 Generación T.Real hidráulica SNP (desglose subsistemas, granularidad 10')
#ID:1747 Generación T.Real turbina de vapor SNP (desglose subsistemas, granularidad 10')
#ID:1755 Generación T.Real cogeneración SNP (desglose subsistemas, granularidad 10')
#ID:1754 Generación T.Real generación auxiliar SNP (desglose subsistemas, granularidad 10')
#ID:1753 Generación T.Real residuos SNP (desglose subsistemas, granularidad 10')
#ID:1752 Generación T.Real otras renovables SNP (desglose subsistemas, granularidad 10')
#ID:1745 Generación T.Real eólica SNP (desglose subsistemas, granularidad 10')
#ID:1751 Generación T.Real enlace balear SNP (desglose subsistemas, granularidad 10')
#ID:1746 Generación T.Real ciclo combinado SNP (desglose subsistemas, granularidad 10')
#ID:1744 Generación T.Real turbina de gas SNP (desglose subsistemas, granularidad 10')
#ID:1743 Generación T.Real motores diésel SNP (desglose subsistemas, granularidad 10')
#ID:1750 Generación T.Real carbón SNP (desglose subsistemas, granularidad 10')
#ID:1740 Demanda Real SNP (desglose subsistemas, granularidad 10')
#ID:1741 Demanda programada SNP (desglose subsistemas, granularidad 10')

#ID:10248 Generación en los SNP (desglose subsistemas, granularidad horaria)
#ID:10246 Generación en Canarias (desglose subsistemas, granularidad horaria)
#ID:10245 Demanda en los SNP (desglose subsistemas, granularidad horaria)
#ID:10243 Demanda en Canarias (desglose subsistemas, granularidad horaria)
#ID:1337 Precio medio de la generación en los SNP por subsistema (desglose subsistemas, granularidad horaria)
#ID:1336 Precio medio de la demanda en los SNP por subsistema (desglose subsistemas, granularidad horaria)

#ID:10252 Volumen neto de energía utilizada de regulación secundaria (Energía peninsular, granularidad horaria)
#ID:811 Precio medio horario componente banda secundaria (precio peninsular, granularidad horaria)
#   Habría que añadir una nueva columna al dataset con el coste repercutido de la banda secundaria en las islas canarias.
#   Hasta que punto afecta la gestión activa de la demanda en las islas canarias sobre el coste total de la banda de regulación secundaria del sistema eléctrico español... es lo que hay que analizar.

datos_id = ["10354","10353","10350"]
df_parcial=[]

#geo_id = str(8797)         # GEO_IDS 8797-Tenerife

#Valores de generación a tiempo real en los Sistemas No Peninsulares

# You can get it by putting the mouse over the indicator name on the webpage. 
# webpage: https://www.esios.ree.es/es/analisis/10354

print ("Recorrer lista por Indices")
for x in range(0,len(datos_id)):
    website = 'https://api.esios.ree.es/indicators/'+datos_id[x]+'?start_date='+startdate+'&end_date='+enddate
    
    URL = website # host website
    GET = '/archives_json' # API link
    HEADERS = {
                'Accept': "application/json; application/vnd.esios-api-v1+json",
                'Host': 'api.esios.ree.es',
                'Authorization': "Token token=\"3627f9a1b46617055cb615ed161382e551ec7baa18466965dfd2cda3ebfc7307",#"a6f2f926dea90ade64acc97b3b4fff73af5bdc5d7bce554a1adfa16d554ede81"',
                'Content-Type': 'application/json'}
    
    # Runs the request to get the total URL with access token
    response = requests.get(url = URL+GET, headers = HEADERS)#, params = PARAMS) 
    matriz=[]
       
    for stuff in response.json()["indicator"]['values']:
        #print(stuff) ## show more stuff that can be gathered
        if stuff['geo_id'] == 8797: ## choose Tenerife id=8797 
            #print(stuff['value'])
            matriz.append([stuff['datetime'],stuff['value']])
            encabezado = ["time_series",response.json()["indicator"]['name']]
            
    df_parcial.append(pd.DataFrame(data=matriz,columns=encabezado))
    
dataset = pd.concat(df_parcial, axis=1)                    

print('Checking dates: ' , startdate , "to" , enddate) # printing the date 


# Read the status code
status = response.status_code

print(dataset)
# Out:
# Recorrer lista por Indices
# Checking dates:  2019-12-31T00:00:00.00 to 2019-12-31T23:50:00.00
#                        time_series  Generación T.Real no renovable SNP  \
# 0    2019-12-31T00:00:00.000+01:00                               312.2
# 1    2019-12-31T00:10:00.000+01:00                               307.0
# 2    2019-12-31T00:20:00.000+01:00                               304.7
# 3    2019-12-31T00:30:00.000+01:00                               302.7
# 4    2019-12-31T00:40:00.000+01:00                               297.9
# ..                             ...                                 ...
# 139  2019-12-31T23:10:00.000+01:00                               371.4
# 140  2019-12-31T23:20:00.000+01:00                               368.0
# 141  2019-12-31T23:30:00.000+01:00                               362.6
# 142  2019-12-31T23:40:00.000+01:00                               355.2
# 143  2019-12-31T23:50:00.000+01:00                               349.6
#
# ...

# %%
website = 'https://api.esios.ree.es/indicators/10354?start_date=2019-12-31T00:00:00.00&end_date=2019-12-31T23:50:00.00'
    
URL = website # host website
GET = '/archives_json' # API link
HEADERS = {
           'Accept': "application/json; application/vnd.esios-api-v1+json",
           'Host': 'api.esios.ree.es',
           'Authorization': "Token token=\"3627f9a1b46617055cb615ed161382e551ec7baa18466965dfd2cda3ebfc7307",#"a6f2f926dea90ade64acc97b3b4fff73af5bdc5d7bce554a1adfa16d554ede81"',
           'Content-Type': 'application/json'}
response = requests.get(url = URL+GET, headers = HEADERS)
response.json()
# Out:
# {'indicator': {'name': 'Generación T.Real no renovable SNP',
#   'short_name': 'No renovable SNP',
#   'id': 10354,
#   'composited': True,
#   'step_type': 'linear',
#   'disaggregated': False,
#   'magnitud': [{'name': 'Potencia', 'id': 20}],
#   'tiempo': [{'name': 'Diez minutos', 'id': 154}],
#   'geos': [{'geo_id': 8795, 'geo_name': 'Gran Canaria'},
#    {'geo_id': 8796, 'geo_name': 'Lanzarote y Fuerteventura'},
#    {'geo_id': 8797, 'geo_name': 'Tenerife'},
#    {'geo_id': 8798, 'geo_name': 'La Palma'},
#    {'geo_id': 8799, 'geo_name': 'La Gomera'},
#    {'geo_id': 8800, 'geo_name': 'El Hierro'},
#    {'geo_id': 8823, 'geo_name': 'Baleares'}],
#   'values_updated_at': '2020-01-01T01:19:01.000+01:00',
#   'values': [{'value': 332.8,
#     'datetime': '2019-12-31T00:00:00.000+01:00',
#     'datetime_utc': '2019-12-30T23:00:00Z',
#     'tz_time': '2019-12-30T23:00:00.000Z',
#     'geo_id': 8795,
#     'geo_name': 'Gran Canaria'},
#    {'value': 147.7,
# ...

# %% [markdown]
# ### Indicador Day-Ahead Market Clearing Price

# %%
#date_today = datetime.date.today()                # use todays prices
#date = date_today + datetime.timedelta(days=2)    # open to use tomorrows prices
#dateend = datetime.date.today()            # use to specify a date
#dateend = date                              # to use only one day

### Tomorrows prices can only be requested after 20:15 the day before. ###

#startdate = str(date_today) + "T00:00:00.00" # can specify more if desired
#enddate = str(dateend) + "T23:50:00.00"
indicator = str(600)    # market clearing (DAM) price. Imbalance is 687

# You can get it by putting the mouse over the indicator name on the webpage. 
# webpage: https://www.esios.ree.es/es/analisis/600
website = 'https://api.esios.ree.es/indicators/'+indicator+'?start_date='+'2020-06-12T00:00:00.00'+'&end_date='+'2020-06-13T00:00:00.00'

     
     
#print('Checking dates: ' , startdate , "to" , enddate) # printing the date 

URL = website # host website
GET = '/archives_json' # API link
HEADERS = {
            'Accept': "application/json; application/vnd.esios-api-v1+json",
            'Host': 'api.esios.ree.es',
            'Authorization': "Token token=\"3627f9a1b46617055cb615ed161382e551ec7baa18466965dfd2cda3ebfc7307",#"a6f2f926dea90ade64acc97b3b4fff73af5bdc5d7bce554a1adfa16d554ede81"',
            'Content-Type': 'application/json'}
#PARAMS = {'date':date}

# Runs the request to get the total URL with access token
response = requests.get(url = URL+GET, headers = HEADERS)#, params = PARAMS)

# Read the status code
status = response.status_code

# %%
status
# Out:
# 200

# %%
response.json()
# Out:
# {'indicator': {'name': 'Precio mercado SPOT Diario',
#   'short_name': 'Mercado SPOT',
#   'id': 600,
#   'composited': False,
#   'step_type': 'linear',
#   'disaggregated': True,
#   'magnitud': [{'name': 'Precio', 'id': 23}],
#   'tiempo': [{'name': 'Hora', 'id': 4}],
#   'geos': [{'geo_id': 1, 'geo_name': 'Portugal'},
#    {'geo_id': 2, 'geo_name': 'Francia'},
#    {'geo_id': 3, 'geo_name': 'España'},
#    {'geo_id': 8824, 'geo_name': 'Reino Unido'},
#    {'geo_id': 8825, 'geo_name': 'Italia'},
#    {'geo_id': 8826, 'geo_name': 'Alemania'},
#    {'geo_id': 8827, 'geo_name': 'Bélgica'},
#    {'geo_id': 8828, 'geo_name': 'Países Bajos'},
#    {'geo_id': 8830, 'geo_name': 'Nord Pool'}],
#   'values_updated_at': '2020-08-27T12:56:11.000+02:00',
#   'values': [{'value': 20.7,
#     'datetime': '2020-06-12T00:00:00.000+02:00',
#     'datetime_utc': '2020-06-11T22:00:00Z',
#     'tz_time': '2020-06-11T22:00:00.000Z',
#     'geo_id': 1,
#     'geo_name': 'Portugal'},
# ...

# %%
# Diving into the data:
marketlist = []
for stuff in response.json()["indicator"]['values']:
    #print(stuff) ## show more stuff that can be gathered
    if stuff['geo_id'] == 3: ## choose Espana. 1 = Portugal, 2 = Francia
    #print(stuff['value'])
        marketlist.append(stuff['value'])

        
print('\n')
print(f"List of market prices for day 2020-06-12 in €/MWh:")        
print(marketlist)

plt.style.use('ggplot')
plt.figure(figsize=(20,10))
plt.plot(marketlist,'r',linewidth=3, color='cornflowerblue')
plt.title(f"Day-Ahead Market prices for 2020-06-12")
plt.xlim(0,24)
plt.ylim(0,50)
plt.xlabel('Hour')
plt.ylabel('Price [€/MWh]')
plt.show()
# Out:
# List of market prices for day 2020-06-12 in €/MWh:
# [20.7, 17.96, 17.09, 16.01, 16.0, 16.64, 19.14, 22.68, 26.01, 23.23, 21.07, 20.5, 19.45, 19.0, 17.71, 16.25, 17.4, 19.6, 20.6, 20.8, 26.01, 24.7, 25.46, 23.0, 20.98]

# %%
date_today = datetime.date.today()                # use todays prices
date = date_today + datetime.timedelta(days=1)    # open to use tomorrows prices
#dateend = datetime.date.today()            # use to specify a date
dateend = date                              # to use only one day

### Tomorrows prices can only be requested after 20:15 the day before. ###

startdate = str(date_today) + "T00:00:00.00" # can specify more if desired
enddate = str(dateend) + "T23:50:00.00"
indicator = str(600)    # market clearing (DAM) price. Imbalance is 687

# You can get it by putting the mouse over the indicator name on the webpage. 
# webpage: https://www.esios.ree.es/es/analisis/600
website = 'https://api.esios.ree.es/indicators/'+indicator+'?start_date='+startdate+'&end_date='+enddate
     
     
print('Checking dates: ' , startdate , "to" , enddate) # printing the date 

URL = website # host website
GET = '/archives_json' # API link
HEADERS = {
            'Accept': "application/json; application/vnd.esios-api-v1+json",
            'Host': 'api.esios.ree.es',
            'Authorization': "Token token=\"3627f9a1b46617055cb615ed161382e551ec7baa18466965dfd2cda3ebfc7307",#"a6f2f926dea90ade64acc97b3b4fff73af5bdc5d7bce554a1adfa16d554ede81"',
            'Content-Type': 'application/json'}
#PARAMS = {'date':date}

# Runs the request to get the total URL with access token
response = requests.get(url = URL+GET, headers = HEADERS)#, params = PARAMS)

# Read the status code
status = response.status_code
# Out:
# Checking dates:  2020-10-01T00:00:00.00 to 2020-10-02T23:50:00.00

# %%
response.json()
# Out:
# {'indicator': {'name': 'Precio mercado SPOT Diario',
#   'short_name': 'Mercado SPOT',
#   'id': 600,
#   'composited': False,
#   'step_type': 'linear',
#   'disaggregated': True,
#   'magnitud': [{'name': 'Precio', 'id': 23}],
#   'tiempo': [{'name': 'Hora', 'id': 4}],
#   'geos': [{'geo_id': 1, 'geo_name': 'Portugal'},
#    {'geo_id': 2, 'geo_name': 'Francia'},
#    {'geo_id': 3, 'geo_name': 'España'},
#    {'geo_id': 8824, 'geo_name': 'Reino Unido'},
#    {'geo_id': 8825, 'geo_name': 'Italia'},
#    {'geo_id': 8826, 'geo_name': 'Alemania'},
#    {'geo_id': 8827, 'geo_name': 'Bélgica'},
#    {'geo_id': 8828, 'geo_name': 'Países Bajos'},
#    {'geo_id': 8830, 'geo_name': 'Nord Pool'}],
#   'values_updated_at': '2020-09-30T14:32:36.000+02:00',
#   'values': [{'value': 38.7,
#     'datetime': '2020-10-01T00:00:00.000+02:00',
#     'datetime_utc': '2020-09-30T22:00:00Z',
#     'tz_time': '2020-09-30T22:00:00.000Z',
#     'geo_id': 1,
#     'geo_name': 'Portugal'},
# ...

# %%
# Diving into the data:
marketlist = []
for stuff in response.json()["indicator"]['values']:
    #print(stuff) ## show more stuff that can be gathered
    if stuff['geo_id'] == 3: ## choose Espana. 1 = Portugal, 2 = Francia
    #print(stuff['value'])
        marketlist.append(stuff['value'])

        
print('\n')
print(f"List of market prices for day {date} in €/MWh:")        
print(marketlist)

plt.style.use('ggplot')
plt.figure(figsize=(20,10))
plt.plot(marketlist,'r',linewidth=3, color='cornflowerblue')
plt.title(f"Day-Ahead Market prices for {date}")
plt.xlabel('Hour')
plt.ylabel('Price [€/MWh]')
plt.show()
# Out:
# List of market prices for day 2020-10-02 in €/MWh:
# [38.7, 34.07, 31.18, 29.75, 30.82, 34.04, 43.53, 52.35, 54.83, 54.0, 51.73, 48.99, 45.65, 44.36, 41.93, 38.33, 36.2, 37.95, 40.0, 40.07, 50.81, 46.08, 40.07, 30.0]

# %%
len(marketlist)
# Out:
# 24
