# %% [markdown]
# # PFM: Data Collection SNP - API Esio REE
#
# En este documento se muestra el desarrollo del modelo de aprendizaje para la predicción de los costes de generación en las islas canarias. Se utiliza lenguaje Python por su versatilidad y gran cantidad de librerías.
#
# En primer lugar importamos las librerías que nos serán de utilidad:

# %%
# import requests library
import requests 
import json
# import pandas library
import pandas as pd 
# import csv library
import csv
# import datetime library
import datetime

# %% [markdown]
# As we have seen before, when we work with APIs, we have to write the endpoint we want to access.
# We need to write also the folder/section we want to access. We can have the same endpoint and different sections from where to get information.
#
# Most of the times, we need to add some headers to our requests that are required to get the information. The most important one is the **Authorization**, which corresponds to our ID to access that API.
#
# ## Listado de indicadores
#
# Podemos llamar a objetos a traves de la API. Esto lo hacemos mediante la librería requests que nos permite hacer solicitudes HTTP a un servidor mediante el método GET de entre otros.
#
# A continuación hacemos una solicitud del listado de indicadores existentes a través de la API, comprobamos su estado y imprimimos en pantalla los valores para su comprensión.

# %%
endpoint = 'https://api.esios.ree.es'
get_indicators = '/indicators?text=SNP'
headers = {'Accept': 'application/json;application/vnd.esios-api-v1+json',
           'Host': 'api.esios.ree.es',
           'Authorization': 'Token token=\"3627f9a1b46617055cb615ed161382e551ec7baa18466965dfd2cda3ebfc7307"',
          }

request = requests.get(endpoint+get_indicators, headers=headers) #, params=params)
status = request.status_code

#Check the status code
if status < 200:
    print('informational')
    # If the status code is 200, treat the information.
elif status >= 200 and status < 300:
    print('Connection is established')
    #okBehavior(response) # runs the function to get list of archives
elif status >= 300 and status < 400:
    print('redirection')
elif status >= 400 and status < 500:
    print('client error')
else:
    print('server error')

request.json()
# Out:
# Connection is established
# {'indicators': [{'name': 'Generación T.Real enlace Ibiza-Formentera SNP',
#    'description': '<p>Generaci&oacute;n medida en tiempo real en el enlace Ibiza-Formentera&nbsp;en el sistema Balear.</p>\n\n<p><b>Publicaci&oacute;n:</b>&nbsp;cada 10 minutos con la informaci&oacute;n de las tres &uacute;ltimas horas del d&iacute;a D-1 hasta la hora actual del d&iacute;a D.</p>\n',
#    'short_name': 'Enlace Ibiza-Formentera SNP',
#    'id': 1820},
#   {'name': 'Generación T.Real enlace Mallorca-Ibiza SNP',
#    'description': '<p>Generaci&oacute;n medida en tiempo real en el enlace Mallorca-Ibiza&nbsp;en el sistema Balear.</p>\n\n<p><b>Publicaci&oacute;n:</b>&nbsp;cada 10 minutos con la informaci&oacute;n de las tres &uacute;ltimas horas del d&iacute;a D-1 hasta la hora actual del d&iacute;a D.</p>\n',
#    'short_name': 'Enlace Mallorca-Ibiza SNP',
#    'id': 1822},
#   {'name': 'Generación T.Real enlace Mallorca-Menorca SNP',
#    'description': '<p>Generaci&oacute;n medida en tiempo real en el enlace Mallorca-Menorca en el sistema Balear.</p>\n\n<p><b>Publicaci&oacute;n:</b>&nbsp;cada 10 minutos con la informaci&oacute;n de las tres &uacute;ltimas horas del d&iacute;a D-1 hasta la hora actual del d&iacute;a D.</p>\n',
#    'short_name': 'Enlace Mallorca-Menorca SNP',
#    'id': 1821},
#   {'name': 'CO2 Asociado Generación T.Real SNP',
#    'description': '<p>CO2 asociado a la generaci&oacute;n medida en tiempo real&nbsp;en los sistemas no peninsulares.</p>\r\n\r\n<p><b>Publicaci&oacute;n:</b>&nbsp;cada 10 minutos con la informaci&oacute;n de las tres &uacute;ltimas horas del d&iacute;a D-1 hasta la hora actual del d&iacute;a D.</p>\r\n',
#    'short_name': 'CO2 T.Real SNP',
#    'id': 10356},
#   {'name': 'Generación T.Real no renovable SNP',
#    'description': '<p>Generaci&oacute;n medida en tiempo real del tipo de producci&oacute;n no renovable en los sistemas no peninsulares.</p>\r\n\r\n<p><b>Publicaci&oacute;n:</b>&nbsp;cada 10 minutos con la informaci&oacute;n de las tres &uacute;ltimas horas del d&iacute;a D-1 hasta la hora actual del d&iacute;a D.</p>\r\n',
#    'short_name': 'No renovable SNP',
#    'id': 10354},
#   {'name': 'Generación T.Real renovable SNP',
#    'description': '<p>Generaci&oacute;n medida en tiempo real del tipo de producci&oacute;n renovable en los sistemas no peninsulares.</p>\r\n\r\n<p><b>Publicaci&oacute;n:</b>&nbsp;cada 10 minutos con la informaci&oacute;n de las tres &uacute;ltimas horas del d&iacute;a D-1 hasta la hora actual del d&iacute;a D.</p>\r\n',
#    'short_name': 'Renovable SNP',
#    'id': 10353},
#   {'name': 'Demanda real suma de generación SNP',
#    'description': '<p>Es el sumatorio de la medida en tiempo real para los distintos tipos de producci&oacute;n en los sistemas no peninsulares.</p>\r\n\r\n<p>El desglose de este indicador proporciona los MW generados por cada tipo de producci&oacute;n medidos en tiempo real.</p>\r\n\r\n<p><b>Publicaci&oacute;n:</b> cada 10 minutos con la informaci&oacute;n de los 10 minutos anteriores.</p>\r\n',
#    'short_name': 'Demanda real SNP',
#    'id': 10350},
#   {'name': 'Generación T.Real eólica SNP',
#    'description': '<p>Generación medida en tiempo real del tipo de producción eólica en los sistemas no peninsulares.</p>\n<p><b>Publicación:</b> cada 10 minutos con la información de las tres últimas horas del día D-1 hasta la hora actual del día D.</p>',
#    'short_name': 'Eólica SNP',
#    'id': 1745},
#   {'name': 'Generación T.Real cogeneración SNP',
#    'description': '<p>Generación medida en tiempo real del tipo de producción cogeneración en los sistemas no peninsulares.</p>\n<p><b>Publicación:</b> cada 10 minutos con la información de las tres últimas horas del día D-1 hasta la hora actual del día D.</p>',
#    'short_name': 'Cogeneración SNP',
#    'id': 1755},
#   {'name': 'Generación T.Real generación auxiliar SNP',
#    'description': '<p>Generación medida en tiempo real del tipo de producción generación auxiliar en los sistemas no peninsulares.</p>\n<p><b>Publicación:</b> cada 10 minutos con la información de las tres últimas horas del día D-1 hasta la hora actual del día D.</p>',
#    'short_name': 'Generación auxiliar SNP',
#    'id': 1754},
#   {'name': 'Generación T.Real residuos SNP',
#    'description': '<p>Generación medida en tiempo real del tipo de producción residuos en los sistemas no peninsulares.</p>\n<p><b>Publicación:</b> cada 10 minutos con la información de las tres últimas horas del día D-1 hasta la hora actual del día D.</p>',
#    'short_name': 'Residuos SNP',
#    'id': 1753},
#   {'name': 'Generación T.Real otras renovables SNP',
#    'description': '<p>Generación medida en tiempo real del tipo de producción otras renovables en los sistemas no peninsulares.</p>\n<p><b>Publicación:</b> cada 10 minutos con la información de las tres últimas horas del día D-1 hasta la hora actual del día D.</p>',
#    'short_name': 'Otras renovables SNP',
#    'id': 1752},
#   {'name': 'Generación T.Real hidráulica SNP',
#    'description': '<p>Generación medida en tiempo real del tipo de producción hidráulica en los sistemas no peninsulares.</p>\n<p><b>Publicación:</b> cada 10 minutos con la información de las tres últimas horas del día D-1 hasta la hora actual del día D.</p>',
#    'short_name': 'Hidráulica SNP',
#    'id': 1749},
#   {'name': 'Generación T.Real solar fotovoltaica SNP',
#    'description': '<p>Generación medida en tiempo real del tipo de producción solar fotovoltaica en los sistemas no peninsulares.</p>\n<p><b>Publicación:</b> cada 10 minutos con la información de las tres últimas horas del día D-1 hasta la hora actual del día D.</p>',
#    'short_name': 'Solar fotovoltaica SNP',
#    'id': 1748},
#   {'name': 'Generación T.Real turbina de vapor SNP',
#    'description': '<p>Generación medida en tiempo real del tipo de producción turbina de vapor en los sistemas no peninsulares.</p>\n<p><b>Publicación:</b> cada 10 minutos con la información de las tres últimas horas del día D-1 hasta la hora actual del día D.</p>',
#    'short_name': 'Turbina de vapor SNP',
#    'id': 1747},
#   {'name': 'Demanda Real SNP',
#    'description': '<p>Es el valor real de la demanda de energ&iacute;a el&eacute;ctrica medida en tiempo real de los sistemas no peninsulares.</p>\r\n\r\n<p><b>Publicaci&oacute;n:</b> cada 10 minutos con la informaci&oacute;n de los 10 minutos anteriores.</p>\r\n',
#    'short_name': 'Demanda Real SNP',
#    'id': 1740},
#   {'name': 'Generación T.Real enlace balear SNP',
#    'description': '<p>Generación medida en tiempo real en el enlace Península-Baleares en el sistema Balear.</p>\n<p><b>Publicación:</b> cada 10 minutos con la información de las tres últimas horas del día D-1 hasta la hora actual del día D.</p>',
#    'short_name': 'Enlace balear SNP',
#    'id': 1751},
#   {'name': 'Generación T.Real carbón SNP',
#    'description': '<p>Generación medida en tiempo real del tipo de producción carbón en los sistemas no peninsulares.</p>\n<p><b>Publicación:</b> cada 10 minutos con la información de las tres últimas horas del día D-1 hasta la hora actual del día D.</p>',
#    'short_name': 'Carbón SNP',
#    'id': 1750},
#   {'name': 'Generación T.Real ciclo combinado SNP',
#    'description': '<p>Generación medida en tiempo real del tipo de producción ciclo combinado en los sistemas no peninsulares.</p>\n<p><b>Publicación:</b> cada 10 minutos con la información de las tres últimas horas del día D-1 hasta la hora actual del día D.</p>',
#    'short_name': 'Ciclo combinado SNP',
#    'id': 1746},
#   {'name': 'Generación T.Real turbina de gas SNP',
#    'description': '<p>Generación medida en tiempo real del tipo de producción turbina gas en los sistemas no peninsulares.</p>\n<p><b>Publicación:</b> cada 10 minutos con la información de las tres últimas horas del día D-1 hasta la hora actual del día D.</p>',
#    'short_name': 'Turbina de gas SNP',
#    'id': 1744},
#   {'name': 'Generación T.Real motores diésel SNP',
#    'description': '<p>Generación medida en tiempo real del tipo de producción motores diesel en los sistemas no peninsulares.</p>\n<p><b>Publicación:</b> cada 10 minutos con la información de las tres últimas horas del día D-1 hasta la hora actual del día D.</p>',
#    'short_name': 'Motores diésel SNP',
#    'id': 1743},
#   {'name': 'Demanda prevista SNP',
#    'description': '<p>Es la previsión de consumo de los sistemas no peninsulares que REE elabora teniendo en cuenta los valores de consumo registrados en periodos precedentes similares, así como otros factores con influencia en el consumo eléctrico como la laboralidad, la climatológica y la actividad económica. Los valores diezminutales son representandos en forma de curva aplicando unos parámetros que parabolizan el valor constante horario.</p>\n<p><b>Publicación:</b> diariamente a las 0:00 horas con la información del día D y a las 13:30 horas con las tres primeras horas del día D+1. Un valor cada diez minutos.</p>',
#    'short_name': 'Demanda prevista SNP',
#    'id': 1742},
#   {'name': 'Demanda programada SNP',
#    'description': '<p>Es la demanda de energía programada en los sistemas no peninsulares calculada con los programas de los grupos de generación a los que se les haya asignado suministro.</p>\n<p><b>Publicación:</b> diariamente a las 0:00 horas con la información del día D y a las 13:30 horas con las tres primeras horas del día D+1. Un valor por hora.</p>',
#    'short_name': 'Demanda programada SNP',
#    'id': 1741},
#   {'name': 'Demanda en los SNP',
#    'description': '<p>Energía de adquisición de los sistemas no peninsulares.</p><p>El desglose de este indicador proporciona el detalle de la demanda en cada uno de los subsistemas no peninsulares.</p><p><b>Publicación:</b> diariamente a las 7:45 con los datos del día D-2.</p>',
#    'short_name': 'Demanda',
#    'id': 10245},
#   {'name': 'Generación en los SNP',
#    'description': '<p>Energía generada en los sistemas no peninsulares.</p><p>Este indicador por defecto proporciona el detalle de la generación en cada uno de los subsistemas no peninsulares.</p><p><b>Publicación:</b> diariamente a las 7:45 con los datos del día D-2.</p>',
#    'short_name': 'Generación',
#    'id': 10248},
#   {'name': 'Precio medio de la generación en los SNP por subsistema',
#    'description': '<p>Precio medio ponderado de la generación de energía de los subsistemas no peninsulares.</p><p>Este indicador por defecto proporciona el detalle del precio de la generación en cada uno de los subsistemas no peninsulares.</p><p><b>Publicación:</b> diariamente a las 7:45 con los datos del día D-2.</p>',
#    'short_name': 'Precio medio generación subsistema',
#    'id': 1337},
#   {'name': 'Precio medio de la demanda en los SNP por subsistema',
#    'description': '<p>Precio medio ponderado de adquisición de energía de los subsistemas no peninsulares.</p><p>Este indicador por defecto proporciona el detalle del precio de la demanda en cada uno de los subsistemas no peninsulares.</p><p><b>Publicación:</b> diariamente a las 7:45 con los datos del día D-2.</p>',
#    'short_name': 'Precio medio demanda subsistema',
#    'id': 1336},
#   {'name': 'Precio medio de la demanda en los SNP por sistema',
#    'description': '<p>Precio medio ponderado de adquisición de energía de los sistemas no peninsulares.</p><p>Este indicador por defecto proporciona el detalle del precio de la demanda en cada uno de los sistemas no peninsulares.</p><p><b>Publicación:</b> diariamente a las 7:45 con los datos del día D-2.</p>',
#    'short_name': 'Precio medio demanda sistema',
#    'id': 573},
#   {'name': 'Precio medio de la generación en los SNP por sistema',
#    'description': '<p>Precio medio ponderado de la generación de energía de los sistemas no peninsulares.</p><p>Este indicador por defecto proporciona el detalle del precio de la generación en cada uno de los sistemas no peninsulares.</p><p><b>Publicación:</b> diariamente a las 7:45 con los datos del día D-2.</p>',
#    'short_name': 'Precio medio generación sistema',
#    'id': 574}],
#  'meta': {'size': 29}}

# %% [markdown]
# #### Indicadores de interés:
#
# ID:10354 Generación T.Real no renovable SNP (desglose subsistemas, granularidad 10')
# ID:10353 Generación T.Real renovable SNP (desglose subsistemas, granularidad 10')
# ID:10350 Demanda real suma de generación SNP (desglose subsistemas, granularidad 10')
# ID:1755 Generación T.Real cogeneración SNP (desglose subsistemas, granularidad 10')
# ID:1754 Generación T.Real generación auxiliar SNP (desglose subsistemas, granularidad 10')
# ID:1753 Generación T.Real residuos SNP (desglose subsistemas, granularidad 10')
# ID:1752 Generación T.Real otras renovables SNP (desglose subsistemas, granularidad 10')
# ID:1750 Generación T.Real carbón SNP (desglose subsistemas, granularidad 10')
# ID:1749 Generación T.Real hidráulica SNP (desglose subsistemas, granularidad 10')
# ID:1748 Generación T.Real solar fotovoltaica SNP (desglose subsistemas, granularidad 10')
# ID:1747 Generación T.Real turbina de vapor SNP (desglose subsistemas, granularidad 10')
# ID:1746 Generación T.Real ciclo combinado SNP (desglose subsistemas, granularidad 10')
# ID:1745 Generación T.Real eólica SNP (desglose subsistemas, granularidad 10')
# ID:1744 Generación T.Real turbina de gas SNP (desglose subsistemas, granularidad 10')
# ID:1743 Generación T.Real motores diésel SNP (desglose subsistemas, granularidad 10')
# ID:1751 Generación T.Real enlace balear SNP (desglose subsistemas, granularidad 10')
# ID:1742 Demanda prevista SNP (desglose subsistemas, granularidad 10')
# ID:1741 Demanda programada SNP (desglose subsistemas, granularidad 10')
# ID:1740 Demanda Real SNP (desglose subsistemas, granularidad 10')
#
#
# ID:10248 Generación en los SNP (desglose subsistemas, granularidad horaria)
# ID:10246 Generación en Canarias (desglose subsistemas, granularidad horaria)
# ID:10245 Demanda en los SNP (desglose subsistemas, granularidad horaria)
# ID:10243 Demanda en Canarias (desglose subsistemas, granularidad horaria)
# ID:1337 Precio medio de la generación en los SNP por subsistema (desglose subsistemas, granularidad horaria)
# ID:1336 Precio medio de la demanda en los SNP por subsistema (desglose subsistemas, granularidad horaria)
#
#
# ID:573 Precio medio de la demanda en los SNP por sistema (desglose sistemas, granularidad horaria)
# ID:574 Precio medio de la generación en los SNP por sistema (desglose sistemas, granularidad horaria)

# %% [markdown]
# ## Indicador X (pruebas)

# %%
date_start = "2020-04-01"                # start date
date_end = "2020-04-30"                  # end date

startdate = date_start + "T00:00:00.00" # can specify more if desired
enddate = date_end + "T23:50:00.00"
indicator = str(10354)    # INDICADOR

#Energía correspondiente al programa operativo que el OS establece en cada período hasta el final del horizonte de programación diario

# You can get it by putting the mouse over the indicator name on the webpage. 
# webpage: https://www.esios.ree.es/es/analisis/10024
website = 'https://api.esios.ree.es/indicators/'+indicator+'?start_date='+startdate+'&end_date='+enddate#+'&geo_id[]='+geo_ids
     
     
print('Checking dates: ' , startdate , "to" , enddate) # printing the date 

URL = website # host website
GET = '/archives_json' # API link
HEADERS = {
            'Accept': "application/json; application/vnd.esios-api-v1+json",
            'Host': 'api.esios.ree.es',
            'Authorization': "Token token=\"3627f9a1b46617055cb615ed161382e551ec7baa18466965dfd2cda3ebfc7307",#"a6f2f926dea90ade64acc97b3b4fff73af5bdc5d7bce554a1adfa16d554ede81"',
            'Content-Type': 'application/json'}
#PARAMS = {'date':date}

# Runs the request to get the total URL with access token
response = requests.get(url = URL+GET, headers = HEADERS)#, params = PARAMS)

# Read the status code
status = response.status_code  

#print the json()
response.json()
# Out:
# Checking dates:  2020-04-01T00:00:00.00 to 2020-04-30T23:50:00.00
# {'indicator': {'name': 'Generación T.Real no renovable SNP',
#   'short_name': 'No renovable SNP',
#   'id': 10354,
#   'composited': True,
#   'step_type': 'linear',
#   'disaggregated': False,
#   'magnitud': [{'name': 'Potencia', 'id': 20}],
#   'tiempo': [{'name': 'Diez minutos', 'id': 154}],
#   'geos': [{'geo_id': 8795, 'geo_name': 'Gran Canaria'},
#    {'geo_id': 8796, 'geo_name': 'Lanzarote y Fuerteventura'},
#    {'geo_id': 8797, 'geo_name': 'Tenerife'},
#    {'geo_id': 8798, 'geo_name': 'La Palma'},
#    {'geo_id': 8799, 'geo_name': 'La Gomera'},
#    {'geo_id': 8800, 'geo_name': 'El Hierro'},
#    {'geo_id': 8823, 'geo_name': 'Baleares'}],
#   'values_updated_at': '2020-05-01T01:19:01.000+02:00',
#   'values': [{'value': 304.2,
#     'datetime': '2020-04-01T00:00:00.000+02:00',
#     'datetime_utc': '2020-03-31T22:00:00Z',
#     'tz_time': '2020-03-31T22:00:00.000Z',
#     'geo_id': 8795,
#     'geo_name': 'Gran Canaria'},
#    {'value': 110.8,
#     'datetime': '2020-04-01T00:00:00.000+02:00',
#     'datetime_utc': '2020-03-31T22:00:00Z',
#     'tz_time': '2020-03-31T22:00:00.000Z',
#     'geo_id': 8796,
#     'geo_name': 'Lanzarote y Fuerteventura'},
#    {'value': 282.0,
#     'datetime': '2020-04-01T00:00:00.000+02:00',
#     'datetime_utc': '2020-03-31T22:00:00Z',
#     'tz_time': '2020-03-31T22:00:00.000Z',
#     'geo_id': 8797,
#     'geo_name': 'Tenerife'},
#    {'value': 24.2,
#     'datetime': '2020-04-01T00:00:00.000+02:00',
#     'datetime_utc': '2020-03-31T22:00:00Z',
#     'tz_time': '2020-03-31T22:00:00.000Z',
#     'geo_id': 8798,
#     'geo_name': 'La Palma'},
#    {'value': 6.9,
#     'datetime': '2020-04-01T00:00:00.000+02:00',
#     'datetime_utc': '2020-03-31T22:00:00Z',
#     'tz_time': '2020-03-31T22:00:00.000Z',
#     'geo_id': 8799,
#     'geo_name': 'La Gomera'},
#    {'value': 4.5,
#     'datetime': '2020-04-01T00:00:00.000+02:00',
#     'datetime_utc': '2020-03-31T22:00:00Z',
#     'tz_time': '2020-03-31T22:00:00.000Z',
#     'geo_id': 8800,
#     'geo_name': 'El Hierro'},
#    {'value': 465.7,
#     'datetime': '2020-04-01T00:00:00.000+02:00',
#     'datetime_utc': '2020-03-31T22:00:00Z',
#     'tz_time': '2020-03-31T22:00:00.000Z',
#     'geo_id': 8823,
#     'geo_name': 'Baleares'},
#    {'value': 301.2,
#     'datetime': '2020-04-01T00:10:00.000+02:00',
#     'datetime_utc': '2020-03-31T22:10:00Z',
#     'tz_time': '2020-03-31T22:10:00.000Z',
#     'geo_id': 8795,
#     'geo_name': 'Gran Canaria'},
#    {'value': 109.7,
#     'datetime': '2020-04-01T00:10:00.000+02:00',
#     'datetime_utc': '2020-03-31T22:10:00Z',
#     'tz_time': '2020-03-31T22:10:00.000Z',
#     'geo_id': 8796,
#     'geo_name': 'Lanzarote y Fuerteventura'},
#    {'value': 276.7,
#     'datetime': '2020-04-01T00:10:00.000+02:00',
#     'datetime_utc': '2020-03-31T22:10:00Z',
#     'tz_time': '2020-03-31T22:10:00.000Z',
#     'geo_id': 8797,
#     'geo_name': 'Tenerife'},
#    {'value': 24.1,
#     'datetime': '2020-04-01T00:10:00.000+02:00',
#     'datetime_utc': '2020-03-31T22:10:00Z',
#     'tz_time': '2020-03-31T22:10:00.000Z',
#     'geo_id': 8798,
#     'geo_name': 'La Palma'},
#    {'value': 7.2,
#     'datetime': '2020-04-01T00:10:00.000+02:00',
#     'datetime_utc': '2020-03-31T22:10:00Z',
#     'tz_time': '2020-03-31T22:10:00.000Z',
#     'geo_id': 8799,
#     'geo_name': 'La Gomera'},
#    {'value': 4.3,
#     'datetime': '2020-04-01T00:10:00.000+02:00',
#     'datetime_utc': '2020-03-31T22:10:00Z',
#     'tz_time': '2020-03-31T22:10:00.000Z',
#     'geo_id': 8800,
#     'geo_name': 'El Hierro'},
#    {'value': 453.2,
#     'datetime': '2020-04-01T00:10:00.000+02:00',
#     'datetime_utc': '2020-03-31T22:10:00Z',
#     'tz_time': '2020-03-31T22:10:00.000Z',
#     'geo_id': 8823,
#     'geo_name': 'Baleares'},
#    {'value': 296.7,
#     'datetime': '2020-04-01T00:20:00.000+02:00',
#     'datetime_utc': '2020-03-31T22:20:00Z',
#     'tz_time': '2020-03-31T22:20:00.000Z',
#     'geo_id': 8795,
#     'geo_name': 'Gran Canaria'},
#    {'value': 106.6,
#     'datetime': '2020-04-01T00:20:00.000+02:00',
#     'datetime_utc': '2020-03-31T22:20:00Z',
#     'tz_time': '2020-03-31T22:20:00.000Z',
#     'geo_id': 8796,
#     'geo_name': 'Lanzarote y Fuerteventura'},
#    {'value': 272.7,
#     'datetime': '2020-04-01T00:20:00.000+02:00',
#     'datetime_utc': '2020-03-31T22:20:00Z',
#     'tz_time': '2020-03-31T22:20:00.000Z',
#     'geo_id': 8797,
#     'geo_name': 'Tenerife'},
#    {'value': 23.7,
#     'datetime': '2020-04-01T00:20:00.000+02:00',
#     'datetime_utc': '2020-03-31T22:20:00Z',
#     'tz_time': '2020-03-31T22:20:00.000Z',
#     'geo_id': 8798,
#     'geo_name': 'La Palma'},
#    {'value': 7.3,
#     'datetime': '2020-04-01T00:20:00.000+02:00',
#     'datetime_utc': '2020-03-31T22:20:00Z',
#     'tz_time': '2020-03-31T22:20:00.000Z',
#     'geo_id': 8799,
#     'geo_name': 'La Gomera'},
#    {'value': 4.1,
#     'datetime': '2020-04-01T00:20:00.000+02:00',
#     'datetime_utc': '2020-03-31T22:20:00Z',
#     'tz_time': '2020-03-31T22:20:00.000Z',
#     'geo_id': 8800,
#     'geo_name': 'El Hierro'},
#    {'value': 444.4,
#     'datetime': '2020-04-01T00:20:00.000+02:00',
#     'datetime_utc': '2020-03-31T22:20:00Z',
#     'tz_time': '2020-03-31T22:20:00.000Z',
#     'geo_id': 8823,
#     'geo_name': 'Baleares'},
#    {'value': 291.6,
#     'datetime': '2020-04-01T00:30:00.000+02:00',
#     'datetime_utc': '2020-03-31T22:30:00Z',
#     'tz_time': '2020-03-31T22:30:00.000Z',
#     'geo_id': 8795,
#     'geo_name': 'Gran Canaria'},
#    {'value': 106.4,
#     'datetime': '2020-04-01T00:30:00.000+02:00',
#     'datetime_utc': '2020-03-31T22:30:00Z',
#     'tz_time': '2020-03-31T22:30:00.000Z',
#     'geo_id': 8796,
#     'geo_name': 'Lanzarote y Fuerteventura'},
#    {'value': 268.2,
#     'datetime': '2020-04-01T00:30:00.000+02:00',
#     'datetime_utc': '2020-03-31T22:30:00Z',
#     'tz_time': '2020-03-31T22:30:00.000Z',
#     'geo_id': 8797,
#     'geo_name': 'Tenerife'},
#    {'value': 23.5,
#     'datetime': '2020-04-01T00:30:00.000+02:00',
#     'datetime_utc': '2020-03-31T22:30:00Z',
#     'tz_time': '2020-03-31T22:30:00.000Z',
#     'geo_id': 8798,
#     'geo_name': 'La Palma'},
#    {'value': 7.2,
#     'datetime': '2020-04-01T00:30:00.000+02:00',
#     'datetime_utc': '2020-03-31T22:30:00Z',
#     'tz_time': '2020-03-31T22:30:00.000Z',
#     'geo_id': 8799,
#     'geo_name': 'La Gomera'},
#    {'value': 3.8,
#     'datetime': '2020-04-01T00:30:00.000+02:00',
#     'datetime_utc': '2020-03-31T22:30:00Z',
#     'tz_time': '2020-03-31T22:30:00.000Z',
#     'geo_id': 8800,
#     'geo_name': 'El Hierro'},
#    {'value': 435.1,
#     'datetime': '2020-04-01T00:30:00.000+02:00',
#     'datetime_utc': '2020-03-31T22:30:00Z',
#     'tz_time': '2020-03-31T22:30:00.000Z',
#     'geo_id': 8823,
#     'geo_name': 'Baleares'},
#    {'value': 287.3,
#     'datetime': '2020-04-01T00:40:00.000+02:00',
#     'datetime_utc': '2020-03-31T22:40:00Z',
#     'tz_time': '2020-03-31T22:40:00.000Z',
#     'geo_id': 8795,
#     'geo_name': 'Gran Canaria'},
#    {'value': 104.3,
#     'datetime': '2020-04-01T00:40:00.000+02:00',
#     'datetime_utc': '2020-03-31T22:40:00Z',
#     'tz_time': '2020-03-31T22:40:00.000Z',
#     'geo_id': 8796,
#     'geo_name': 'Lanzarote y Fuerteventura'},
#    {'value': 265.4,
#     'datetime': '2020-04-01T00:40:00.000+02:00',
#     'datetime_utc': '2020-03-31T22:40:00Z',
#     'tz_time': '2020-03-31T22:40:00.000Z',
#     'geo_id': 8797,
#     'geo_name': 'Tenerife'},
#    {'value': 22.9,
#     'datetime': '2020-04-01T00:40:00.000+02:00',
#     'datetime_utc': '2020-03-31T22:40:00Z',
#     'tz_time': '2020-03-31T22:40:00.000Z',
#     'geo_id': 8798,
#     'geo_name': 'La Palma'},
#    {'value': 7.1,
#     'datetime': '2020-04-01T00:40:00.000+02:00',
#     'datetime_utc': '2020-03-31T22:40:00Z',
#     'tz_time': '2020-03-31T22:40:00.000Z',
#     'geo_id': 8799,
#     'geo_name': 'La Gomera'},
#    {'value': 4.1,
#     'datetime': '2020-04-01T00:40:00.000+02:00',
#     'datetime_utc': '2020-03-31T22:40:00Z',
#     'tz_time': '2020-03-31T22:40:00.000Z',
#     'geo_id': 8800,
#     'geo_name': 'El Hierro'},
#    {'value': 425.1,
#     'datetime': '2020-04-01T00:40:00.000+02:00',
#     'datetime_utc': '2020-03-31T22:40:00Z',
#     'tz_time': '2020-03-31T22:40:00.000Z',
#     'geo_id': 8823,
#     'geo_name': 'Baleares'},
#    {'value': 282.8,
#     'datetime': '2020-04-01T00:50:00.000+02:00',
#     'datetime_utc': '2020-03-31T22:50:00Z',
#     'tz_time': '2020-03-31T22:50:00.000Z',
#     'geo_id': 8795,
#     'geo_name': 'Gran Canaria'},
#    {'value': 104.0,
#     'datetime': '2020-04-01T00:50:00.000+02:00',
#     'datetime_utc': '2020-03-31T22:50:00Z',
#     'tz_time': '2020-03-31T22:50:00.000Z',
#     'geo_id': 8796,
#     'geo_name': 'Lanzarote y Fuerteventura'},
#    {'value': 262.7,
#     'datetime': '2020-04-01T00:50:00.000+02:00',
#     'datetime_utc': '2020-03-31T22:50:00Z',
#     'tz_time': '2020-03-31T22:50:00.000Z',
#     'geo_id': 8797,
#     'geo_name': 'Tenerife'},
#    {'value': 22.2,
#     'datetime': '2020-04-01T00:50:00.000+02:00',
#     'datetime_utc': '2020-03-31T22:50:00Z',
#     'tz_time': '2020-03-31T22:50:00.000Z',
#     'geo_id': 8798,
#     'geo_name': 'La Palma'},
#    {'value': 7.1,
#     'datetime': '2020-04-01T00:50:00.000+02:00',
#     'datetime_utc': '2020-03-31T22:50:00Z',
#     'tz_time': '2020-03-31T22:50:00.000Z',
#     'geo_id': 8799,
#     'geo_name': 'La Gomera'},
#    {'value': 4.0,
#     'datetime': '2020-04-01T00:50:00.000+02:00',
#     'datetime_utc': '2020-03-31T22:50:00Z',
#     'tz_time': '2020-03-31T22:50:00.000Z',
#     'geo_id': 8800,
#     'geo_name': 'El Hierro'},
#    {'value': 414.6,
#     'datetime': '2020-04-01T00:50:00.000+02:00',
#     'datetime_utc': '2020-03-31T22:50:00Z',
#     'tz_time': '2020-03-31T22:50:00.000Z',
#     'geo_id': 8823,
#     'geo_name': 'Baleares'},
#    {'value': 278.1,
#     'datetime': '2020-04-01T01:00:00.000+02:00',
#     'datetime_utc': '2020-03-31T23:00:00Z',
#     'tz_time': '2020-03-31T23:00:00.000Z',
#     'geo_id': 8795,
#     'geo_name': 'Gran Canaria'},
#    {'value': 102.7,
#     'datetime': '2020-04-01T01:00:00.000+02:00',
#     'datetime_utc': '2020-03-31T23:00:00Z',
#     'tz_time': '2020-03-31T23:00:00.000Z',
#     'geo_id': 8796,
#     'geo_name': 'Lanzarote y Fuerteventura'},
#    {'value': 260.0,
#     'datetime': '2020-04-01T01:00:00.000+02:00',
#     'datetime_utc': '2020-03-31T23:00:00Z',
#     'tz_time': '2020-03-31T23:00:00.000Z',
#     'geo_id': 8797,
#     'geo_name': 'Tenerife'},
#    {'value': 22.4,
#     'datetime': '2020-04-01T01:00:00.000+02:00',
#     'datetime_utc': '2020-03-31T23:00:00Z',
#     'tz_time': '2020-03-31T23:00:00.000Z',
#     'geo_id': 8798,
#     'geo_name': 'La Palma'},
#    {'value': 6.9,
#     'datetime': '2020-04-01T01:00:00.000+02:00',
#     'datetime_utc': '2020-03-31T23:00:00Z',
#     'tz_time': '2020-03-31T23:00:00.000Z',
#     'geo_id': 8799,
#     'geo_name': 'La Gomera'},
#    {'value': 4.1,
#     'datetime': '2020-04-01T01:00:00.000+02:00',
#     'datetime_utc': '2020-03-31T23:00:00Z',
#     'tz_time': '2020-03-31T23:00:00.000Z',
#     'geo_id': 8800,
#     'geo_name': 'El Hierro'},
#    {'value': 407.6,
#     'datetime': '2020-04-01T01:00:00.000+02:00',
#     'datetime_utc': '2020-03-31T23:00:00Z',
#     'tz_time': '2020-03-31T23:00:00.000Z',
#     'geo_id': 8823,
#     'geo_name': 'Baleares'},
#    {'value': 272.9,
#     'datetime': '2020-04-01T01:10:00.000+02:00',
#     'datetime_utc': '2020-03-31T23:10:00Z',
#     'tz_time': '2020-03-31T23:10:00.000Z',
#     'geo_id': 8795,
#     'geo_name': 'Gran Canaria'},
#    {'value': 102.4,
#     'datetime': '2020-04-01T01:10:00.000+02:00',
#     'datetime_utc': '2020-03-31T23:10:00Z',
#     'tz_time': '2020-03-31T23:10:00.000Z',
#     'geo_id': 8796,
#     'geo_name': 'Lanzarote y Fuerteventura'},
#    {'value': 255.5,
#     'datetime': '2020-04-01T01:10:00.000+02:00',
#     'datetime_utc': '2020-03-31T23:10:00Z',
#     'tz_time': '2020-03-31T23:10:00.000Z',
#     'geo_id': 8797,
#     'geo_name': 'Tenerife'},
#    {'value': 21.9,
#     'datetime': '2020-04-01T01:10:00.000+02:00',
#     'datetime_utc': '2020-03-31T23:10:00Z',
#     'tz_time': '2020-03-31T23:10:00.000Z',
#     'geo_id': 8798,
#     'geo_name': 'La Palma'},
#    {'value': 7.0,
#     'datetime': '2020-04-01T01:10:00.000+02:00',
#     'datetime_utc': '2020-03-31T23:10:00Z',
#     'tz_time': '2020-03-31T23:10:00.000Z',
#     'geo_id': 8799,
#     'geo_name': 'La Gomera'},
#    {'value': 4.1,
#     'datetime': '2020-04-01T01:10:00.000+02:00',
#     'datetime_utc': '2020-03-31T23:10:00Z',
#     'tz_time': '2020-03-31T23:10:00.000Z',
#     'geo_id': 8800,
#     'geo_name': 'El Hierro'},
#    {'value': 400.2,
#     'datetime': '2020-04-01T01:10:00.000+02:00',
#     'datetime_utc': '2020-03-31T23:10:00Z',
#     'tz_time': '2020-03-31T23:10:00.000Z',
#     'geo_id': 8823,
#     'geo_name': 'Baleares'},
#    {'value': 268.4,
#     'datetime': '2020-04-01T01:20:00.000+02:00',
#     'datetime_utc': '2020-03-31T23:20:00Z',
#     'tz_time': '2020-03-31T23:20:00.000Z',
#     'geo_id': 8795,
#     'geo_name': 'Gran Canaria'},
#    {'value': 100.4,
#     'datetime': '2020-04-01T01:20:00.000+02:00',
#     'datetime_utc': '2020-03-31T23:20:00Z',
#     'tz_time': '2020-03-31T23:20:00.000Z',
#     'geo_id': 8796,
#     'geo_name': 'Lanzarote y Fuerteventura'},
#    {'value': 251.1,
#     'datetime': '2020-04-01T01:20:00.000+02:00',
#     'datetime_utc': '2020-03-31T23:20:00Z',
#     'tz_time': '2020-03-31T23:20:00.000Z',
#     'geo_id': 8797,
#     'geo_name': 'Tenerife'},
#    {'value': 21.7,
#     'datetime': '2020-04-01T01:20:00.000+02:00',
#     'datetime_utc': '2020-03-31T23:20:00Z',
#     'tz_time': '2020-03-31T23:20:00.000Z',
#     'geo_id': 8798,
#     'geo_name': 'La Palma'},
#    {'value': 6.9,
#     'datetime': '2020-04-01T01:20:00.000+02:00',
#     'datetime_utc': '2020-03-31T23:20:00Z',
#     'tz_time': '2020-03-31T23:20:00.000Z',
#     'geo_id': 8799,
#     'geo_name': 'La Gomera'},
#    {'value': 4.0,
#     'datetime': '2020-04-01T01:20:00.000+02:00',
#     'datetime_utc': '2020-03-31T23:20:00Z',
#     'tz_time': '2020-03-31T23:20:00.000Z',
#     'geo_id': 8800,
#     'geo_name': 'El Hierro'},
#    {'value': 391.9,
#     'datetime': '2020-04-01T01:20:00.000+02:00',
#     'datetime_utc': '2020-03-31T23:20:00Z',
#     'tz_time': '2020-03-31T23:20:00.000Z',
#     'geo_id': 8823,
#     'geo_name': 'Baleares'},
#    {'value': 266.0,
#     'datetime': '2020-04-01T01:30:00.000+02:00',
#     'datetime_utc': '2020-03-31T23:30:00Z',
#     'tz_time': '2020-03-31T23:30:00.000Z',
#     'geo_id': 8795,
#     'geo_name': 'Gran Canaria'},
#    {'value': 99.5,
#     'datetime': '2020-04-01T01:30:00.000+02:00',
#     'datetime_utc': '2020-03-31T23:30:00Z',
#     'tz_time': '2020-03-31T23:30:00.000Z',
#     'geo_id': 8796,
#     'geo_name': 'Lanzarote y Fuerteventura'},
#    {'value': 248.6,
#     'datetime': '2020-04-01T01:30:00.000+02:00',
#     'datetime_utc': '2020-03-31T23:30:00Z',
#     'tz_time': '2020-03-31T23:30:00.000Z',
#     'geo_id': 8797,
#     'geo_name': 'Tenerife'},
#    {'value': 21.3,
#     'datetime': '2020-04-01T01:30:00.000+02:00',
#     'datetime_utc': '2020-03-31T23:30:00Z',
#     'tz_time': '2020-03-31T23:30:00.000Z',
#     'geo_id': 8798,
#     'geo_name': 'La Palma'},
#    {'value': 6.9,
#     'datetime': '2020-04-01T01:30:00.000+02:00',
#     'datetime_utc': '2020-03-31T23:30:00Z',
#     'tz_time': '2020-03-31T23:30:00.000Z',
#     'geo_id': 8799,
#     'geo_name': 'La Gomera'},
#    {'value': 3.9,
#     'datetime': '2020-04-01T01:30:00.000+02:00',
#     'datetime_utc': '2020-03-31T23:30:00Z',
#     'tz_time': '2020-03-31T23:30:00.000Z',
#     'geo_id': 8800,
#     'geo_name': 'El Hierro'},
#    {'value': 384.2,
#     'datetime': '2020-04-01T01:30:00.000+02:00',
#     'datetime_utc': '2020-03-31T23:30:00Z',
#     'tz_time': '2020-03-31T23:30:00.000Z',
#     'geo_id': 8823,
#     'geo_name': 'Baleares'},
#    {'value': 262.9,
#     'datetime': '2020-04-01T01:40:00.000+02:00',
#     'datetime_utc': '2020-03-31T23:40:00Z',
#     'tz_time': '2020-03-31T23:40:00.000Z',
#     'geo_id': 8795,
#     'geo_name': 'Gran Canaria'},
#    {'value': 99.1,
#     'datetime': '2020-04-01T01:40:00.000+02:00',
#     'datetime_utc': '2020-03-31T23:40:00Z',
#     'tz_time': '2020-03-31T23:40:00.000Z',
#     'geo_id': 8796,
#     'geo_name': 'Lanzarote y Fuerteventura'},
#    {'value': 246.8,
#     'datetime': '2020-04-01T01:40:00.000+02:00',
#     'datetime_utc': '2020-03-31T23:40:00Z',
#     'tz_time': '2020-03-31T23:40:00.000Z',
#     'geo_id': 8797,
#     'geo_name': 'Tenerife'},
#    {'value': 21.2,
#     'datetime': '2020-04-01T01:40:00.000+02:00',
#     'datetime_utc': '2020-03-31T23:40:00Z',
#     'tz_time': '2020-03-31T23:40:00.000Z',
#     'geo_id': 8798,
#     'geo_name': 'La Palma'},
#    {'value': 6.8,
#     'datetime': '2020-04-01T01:40:00.000+02:00',
#     'datetime_utc': '2020-03-31T23:40:00Z',
#     'tz_time': '2020-03-31T23:40:00.000Z',
#     'geo_id': 8799,
#     'geo_name': 'La Gomera'},
#    {'value': 4.0,
#     'datetime': '2020-04-01T01:40:00.000+02:00',
#     'datetime_utc': '2020-03-31T23:40:00Z',
#     'tz_time': '2020-03-31T23:40:00.000Z',
#     'geo_id': 8800,
#     'geo_name': 'El Hierro'},
#    {'value': 378.4,
#     'datetime': '2020-04-01T01:40:00.000+02:00',
#     'datetime_utc': '2020-03-31T23:40:00Z',
#     'tz_time': '2020-03-31T23:40:00.000Z',
#     'geo_id': 8823,
#     'geo_name': 'Baleares'},
#    {'value': 258.1,
#     'datetime': '2020-04-01T01:50:00.000+02:00',
#     'datetime_utc': '2020-03-31T23:50:00Z',
#     'tz_time': '2020-03-31T23:50:00.000Z',
#     'geo_id': 8795,
#     'geo_name': 'Gran Canaria'},
#    {'value': 97.5,
#     'datetime': '2020-04-01T01:50:00.000+02:00',
#     'datetime_utc': '2020-03-31T23:50:00Z',
#     'tz_time': '2020-03-31T23:50:00.000Z',
#     'geo_id': 8796,
#     'geo_name': 'Lanzarote y Fuerteventura'},
#    {'value': 242.5,
#     'datetime': '2020-04-01T01:50:00.000+02:00',
#     'datetime_utc': '2020-03-31T23:50:00Z',
#     'tz_time': '2020-03-31T23:50:00.000Z',
#     'geo_id': 8797,
#     'geo_name': 'Tenerife'},
#    {'value': 21.0,
#     'datetime': '2020-04-01T01:50:00.000+02:00',
#     'datetime_utc': '2020-03-31T23:50:00Z',
#     'tz_time': '2020-03-31T23:50:00.000Z',
#     'geo_id': 8798,
#     'geo_name': 'La Palma'},
#    {'value': 6.8,
#     'datetime': '2020-04-01T01:50:00.000+02:00',
#     'datetime_utc': '2020-03-31T23:50:00Z',
#     'tz_time': '2020-03-31T23:50:00.000Z',
#     'geo_id': 8799,
#     'geo_name': 'La Gomera'},
#    {'value': 4.3,
#     'datetime': '2020-04-01T01:50:00.000+02:00',
#     'datetime_utc': '2020-03-31T23:50:00Z',
#     'tz_time': '2020-03-31T23:50:00.000Z',
#     'geo_id': 8800,
#     'geo_name': 'El Hierro'},
#    {'value': 372.7,
#     'datetime': '2020-04-01T01:50:00.000+02:00',
#     'datetime_utc': '2020-03-31T23:50:00Z',
#     'tz_time': '2020-03-31T23:50:00.000Z',
#     'geo_id': 8823,
#     'geo_name': 'Baleares'},
#    {'value': 254.6,
#     'datetime': '2020-04-01T02:00:00.000+02:00',
#     'datetime_utc': '2020-04-01T00:00:00Z',
#     'tz_time': '2020-04-01T00:00:00.000Z',
#     'geo_id': 8795,
#     'geo_name': 'Gran Canaria'},
#    {'value': 97.2,
#     'datetime': '2020-04-01T02:00:00.000+02:00',
#     'datetime_utc': '2020-04-01T00:00:00Z',
#     'tz_time': '2020-04-01T00:00:00.000Z',
#     'geo_id': 8796,
#     'geo_name': 'Lanzarote y Fuerteventura'},
#    {'value': 241.0,
#     'datetime': '2020-04-01T02:00:00.000+02:00',
#     'datetime_utc': '2020-04-01T00:00:00Z',
#     'tz_time': '2020-04-01T00:00:00.000Z',
#     'geo_id': 8797,
#     'geo_name': 'Tenerife'},
#    {'value': 20.7,
#     'datetime': '2020-04-01T02:00:00.000+02:00',
#     'datetime_utc': '2020-04-01T00:00:00Z',
#     'tz_time': '2020-04-01T00:00:00.000Z',
#     'geo_id': 8798,
#     'geo_name': 'La Palma'},
#    {'value': 6.7,
#     'datetime': '2020-04-01T02:00:00.000+02:00',
#     'datetime_utc': '2020-04-01T00:00:00Z',
#     'tz_time': '2020-04-01T00:00:00.000Z',
#     'geo_id': 8799,
#     'geo_name': 'La Gomera'},
#    {'value': 4.6,
#     'datetime': '2020-04-01T02:00:00.000+02:00',
#     'datetime_utc': '2020-04-01T00:00:00Z',
#     'tz_time': '2020-04-01T00:00:00.000Z',
#     'geo_id': 8800,
#     'geo_name': 'El Hierro'},
#    {'value': 370.7,
#     'datetime': '2020-04-01T02:00:00.000+02:00',
#     'datetime_utc': '2020-04-01T00:00:00Z',
#     'tz_time': '2020-04-01T00:00:00.000Z',
#     'geo_id': 8823,
#     'geo_name': 'Baleares'},
#    {'value': 250.1,
#     'datetime': '2020-04-01T02:10:00.000+02:00',
#     'datetime_utc': '2020-04-01T00:10:00Z',
#     'tz_time': '2020-04-01T00:10:00.000Z',
#     'geo_id': 8795,
#     'geo_name': 'Gran Canaria'},
#    {'value': 96.1,
#     'datetime': '2020-04-01T02:10:00.000+02:00',
#     'datetime_utc': '2020-04-01T00:10:00Z',
#     'tz_time': '2020-04-01T00:10:00.000Z',
#     'geo_id': 8796,
#     'geo_name': 'Lanzarote y Fuerteventura'},
#    {'value': 239.3,
#     'datetime': '2020-04-01T02:10:00.000+02:00',
#     'datetime_utc': '2020-04-01T00:10:00Z',
#     'tz_time': '2020-04-01T00:10:00.000Z',
#     'geo_id': 8797,
#     'geo_name': 'Tenerife'},
#    {'value': 20.3,
#     'datetime': '2020-04-01T02:10:00.000+02:00',
#     'datetime_utc': '2020-04-01T00:10:00Z',
#     'tz_time': '2020-04-01T00:10:00.000Z',
#     'geo_id': 8798,
#     'geo_name': 'La Palma'},
#    {'value': 6.8,
#     'datetime': '2020-04-01T02:10:00.000+02:00',
#     'datetime_utc': '2020-04-01T00:10:00Z',
#     'tz_time': '2020-04-01T00:10:00.000Z',
#     'geo_id': 8799,
#     'geo_name': 'La Gomera'},
#    {'value': 4.5,
#     'datetime': '2020-04-01T02:10:00.000+02:00',
#     'datetime_utc': '2020-04-01T00:10:00Z',
#     'tz_time': '2020-04-01T00:10:00.000Z',
#     'geo_id': 8800,
#     'geo_name': 'El Hierro'},
#    {'value': 365.0,
#     'datetime': '2020-04-01T02:10:00.000+02:00',
#     'datetime_utc': '2020-04-01T00:10:00Z',
#     'tz_time': '2020-04-01T00:10:00.000Z',
#     'geo_id': 8823,
#     'geo_name': 'Baleares'},
#    {'value': 248.5,
#     'datetime': '2020-04-01T02:20:00.000+02:00',
#     'datetime_utc': '2020-04-01T00:20:00Z',
#     'tz_time': '2020-04-01T00:20:00.000Z',
#     'geo_id': 8795,
#     'geo_name': 'Gran Canaria'},
#    {'value': 95.5,
#     'datetime': '2020-04-01T02:20:00.000+02:00',
#     'datetime_utc': '2020-04-01T00:20:00Z',
#     'tz_time': '2020-04-01T00:20:00.000Z',
#     'geo_id': 8796,
#     'geo_name': 'Lanzarote y Fuerteventura'},
#    {'value': 236.6,
#     'datetime': '2020-04-01T02:20:00.000+02:00',
#     'datetime_utc': '2020-04-01T00:20:00Z',
#     'tz_time': '2020-04-01T00:20:00.000Z',
#     'geo_id': 8797,
#     'geo_name': 'Tenerife'},
#    {'value': 20.3,
#     'datetime': '2020-04-01T02:20:00.000+02:00',
#     'datetime_utc': '2020-04-01T00:20:00Z',
#     'tz_time': '2020-04-01T00:20:00.000Z',
#     'geo_id': 8798,
#     'geo_name': 'La Palma'},
#    {'value': 6.8,
#     'datetime': '2020-04-01T02:20:00.000+02:00',
#     'datetime_utc': '2020-04-01T00:20:00Z',
#     'tz_time': '2020-04-01T00:20:00.000Z',
#     'geo_id': 8799,
#     'geo_name': 'La Gomera'},
#    {'value': 4.2,
#     'datetime': '2020-04-01T02:20:00.000+02:00',
#     'datetime_utc': '2020-04-01T00:20:00Z',
#     'tz_time': '2020-04-01T00:20:00.000Z',
#     'geo_id': 8800,
#     'geo_name': 'El Hierro'},
#    {'value': 360.4,
#     'datetime': '2020-04-01T02:20:00.000+02:00',
#     'datetime_utc': '2020-04-01T00:20:00Z',
#     'tz_time': '2020-04-01T00:20:00.000Z',
#     'geo_id': 8823,
#     'geo_name': 'Baleares'},
#    {'value': 245.9,
#     'datetime': '2020-04-01T02:30:00.000+02:00',
#     'datetime_utc': '2020-04-01T00:30:00Z',
#     'tz_time': '2020-04-01T00:30:00.000Z',
#     'geo_id': 8795,
#     'geo_name': 'Gran Canaria'},
#    {'value': 94.8,
#     'datetime': '2020-04-01T02:30:00.000+02:00',
#     'datetime_utc': '2020-04-01T00:30:00Z',
#     'tz_time': '2020-04-01T00:30:00.000Z',
#     'geo_id': 8796,
#     'geo_name': 'Lanzarote y Fuerteventura'},
#    {'value': 234.0,
#     'datetime': '2020-04-01T02:30:00.000+02:00',
#     'datetime_utc': '2020-04-01T00:30:00Z',
#     'tz_time': '2020-04-01T00:30:00.000Z',
#     'geo_id': 8797,
#     'geo_name': 'Tenerife'},
#    {'value': 20.3,
#     'datetime': '2020-04-01T02:30:00.000+02:00',
#     'datetime_utc': '2020-04-01T00:30:00Z',
#     'tz_time': '2020-04-01T00:30:00.000Z',
#     'geo_id': 8798,
#     'geo_name': 'La Palma'},
#    {'value': 6.8,
#     'datetime': '2020-04-01T02:30:00.000+02:00',
#     'datetime_utc': '2020-04-01T00:30:00Z',
#     'tz_time': '2020-04-01T00:30:00.000Z',
#     'geo_id': 8799,
#     'geo_name': 'La Gomera'},
#    {'value': 3.8,
#     'datetime': '2020-04-01T02:30:00.000+02:00',
#     'datetime_utc': '2020-04-01T00:30:00Z',
#     'tz_time': '2020-04-01T00:30:00.000Z',
#     'geo_id': 8800,
#     'geo_name': 'El Hierro'},
#    {'value': 357.0,
#     'datetime': '2020-04-01T02:30:00.000+02:00',
#     'datetime_utc': '2020-04-01T00:30:00Z',
#     'tz_time': '2020-04-01T00:30:00.000Z',
#     'geo_id': 8823,
#     'geo_name': 'Baleares'},
#    {'value': 241.2,
#     'datetime': '2020-04-01T02:40:00.000+02:00',
#     'datetime_utc': '2020-04-01T00:40:00Z',
#     'tz_time': '2020-04-01T00:40:00.000Z',
#     'geo_id': 8795,
#     'geo_name': 'Gran Canaria'},
#    {'value': 94.0,
#     'datetime': '2020-04-01T02:40:00.000+02:00',
#     'datetime_utc': '2020-04-01T00:40:00Z',
#     'tz_time': '2020-04-01T00:40:00.000Z',
#     'geo_id': 8796,
#     'geo_name': 'Lanzarote y Fuerteventura'},
#    {'value': 233.4,
#     'datetime': '2020-04-01T02:40:00.000+02:00',
#     'datetime_utc': '2020-04-01T00:40:00Z',
#     'tz_time': '2020-04-01T00:40:00.000Z',
#     'geo_id': 8797,
#     'geo_name': 'Tenerife'},
#    {'value': 20.5,
#     'datetime': '2020-04-01T02:40:00.000+02:00',
#     'datetime_utc': '2020-04-01T00:40:00Z',
#     'tz_time': '2020-04-01T00:40:00.000Z',
#     'geo_id': 8798,
#     'geo_name': 'La Palma'},
#    {'value': 6.9,
#     'datetime': '2020-04-01T02:40:00.000+02:00',
#     'datetime_utc': '2020-04-01T00:40:00Z',
#     'tz_time': '2020-04-01T00:40:00.000Z',
#     'geo_id': 8799,
#     'geo_name': 'La Gomera'},
#    {'value': 3.6,
#     'datetime': '2020-04-01T02:40:00.000+02:00',
#     'datetime_utc': '2020-04-01T00:40:00Z',
#     'tz_time': '2020-04-01T00:40:00.000Z',
#     'geo_id': 8800,
#     'geo_name': 'El Hierro'},
#    {'value': 352.2,
#     'datetime': '2020-04-01T02:40:00.000+02:00',
#     'datetime_utc': '2020-04-01T00:40:00Z',
#     'tz_time': '2020-04-01T00:40:00.000Z',
#     'geo_id': 8823,
#     'geo_name': 'Baleares'},
#    {'value': 235.9,
#     'datetime': '2020-04-01T02:50:00.000+02:00',
#     'datetime_utc': '2020-04-01T00:50:00Z',
#     'tz_time': '2020-04-01T00:50:00.000Z',
#     'geo_id': 8795,
#     'geo_name': 'Gran Canaria'},
#    {'value': 93.9,
#     'datetime': '2020-04-01T02:50:00.000+02:00',
#     'datetime_utc': '2020-04-01T00:50:00Z',
#     'tz_time': '2020-04-01T00:50:00.000Z',
#     'geo_id': 8796,
#     'geo_name': 'Lanzarote y Fuerteventura'},
#    {'value': 232.0,
#     'datetime': '2020-04-01T02:50:00.000+02:00',
#     'datetime_utc': '2020-04-01T00:50:00Z',
#     'tz_time': '2020-04-01T00:50:00.000Z',
#     'geo_id': 8797,
#     'geo_name': 'Tenerife'},
#    {'value': 20.5,
#     'datetime': '2020-04-01T02:50:00.000+02:00',
#     'datetime_utc': '2020-04-01T00:50:00Z',
#     'tz_time': '2020-04-01T00:50:00.000Z',
#     'geo_id': 8798,
#     'geo_name': 'La Palma'},
#    {'value': 6.8,
#     'datetime': '2020-04-01T02:50:00.000+02:00',
#     'datetime_utc': '2020-04-01T00:50:00Z',
#     'tz_time': '2020-04-01T00:50:00.000Z',
#     'geo_id': 8799,
#     'geo_name': 'La Gomera'},
#    {'value': 3.7,
#     'datetime': '2020-04-01T02:50:00.000+02:00',
#     'datetime_utc': '2020-04-01T00:50:00Z',
#     'tz_time': '2020-04-01T00:50:00.000Z',
#     'geo_id': 8800,
#     'geo_name': 'El Hierro'},
#    {'value': 348.5,
#     'datetime': '2020-04-01T02:50:00.000+02:00',
#     'datetime_utc': '2020-04-01T00:50:00Z',
#     'tz_time': '2020-04-01T00:50:00.000Z',
#     'geo_id': 8823,
#     'geo_name': 'Baleares'},
#    {'value': 235.3,
#     'datetime': '2020-04-01T03:00:00.000+02:00',
#     'datetime_utc': '2020-04-01T01:00:00Z',
#     'tz_time': '2020-04-01T01:00:00.000Z',
#     'geo_id': 8795,
#     'geo_name': 'Gran Canaria'},
#    {'value': 93.4,
#     'datetime': '2020-04-01T03:00:00.000+02:00',
#     'datetime_utc': '2020-04-01T01:00:00Z',
#     'tz_time': '2020-04-01T01:00:00.000Z',
#     'geo_id': 8796,
#     'geo_name': 'Lanzarote y Fuerteventura'},
#    {'value': 231.3,
#     'datetime': '2020-04-01T03:00:00.000+02:00',
#     'datetime_utc': '2020-04-01T01:00:00Z',
#     'tz_time': '2020-04-01T01:00:00.000Z',
#     'geo_id': 8797,
#     'geo_name': 'Tenerife'},
#    {'value': 20.3,
#     'datetime': '2020-04-01T03:00:00.000+02:00',
#     'datetime_utc': '2020-04-01T01:00:00Z',
#     'tz_time': '2020-04-01T01:00:00.000Z',
#     'geo_id': 8798,
#     'geo_name': 'La Palma'},
#    {'value': 6.8,
#     'datetime': '2020-04-01T03:00:00.000+02:00',
#     'datetime_utc': '2020-04-01T01:00:00Z',
#     'tz_time': '2020-04-01T01:00:00.000Z',
#     'geo_id': 8799,
#     'geo_name': 'La Gomera'},
#    {'value': 3.4,
#     'datetime': '2020-04-01T03:00:00.000+02:00',
#     'datetime_utc': '2020-04-01T01:00:00Z',
#     'tz_time': '2020-04-01T01:00:00.000Z',
#     'geo_id': 8800,
#     'geo_name': 'El Hierro'},
#    {'value': 345.5,
#     'datetime': '2020-04-01T03:00:00.000+02:00',
#     'datetime_utc': '2020-04-01T01:00:00Z',
#     'tz_time': '2020-04-01T01:00:00.000Z',
#     'geo_id': 8823,
#     'geo_name': 'Baleares'},
#    {'value': 236.3,
#     'datetime': '2020-04-01T03:10:00.000+02:00',
#     'datetime_utc': '2020-04-01T01:10:00Z',
#     'tz_time': '2020-04-01T01:10:00.000Z',
#     'geo_id': 8795,
#     'geo_name': 'Gran Canaria'},
#    {'value': 92.5,
#     'datetime': '2020-04-01T03:10:00.000+02:00',
#     'datetime_utc': '2020-04-01T01:10:00Z',
#     'tz_time': '2020-04-01T01:10:00.000Z',
#     'geo_id': 8796,
#     'geo_name': 'Lanzarote y Fuerteventura'},
#    {'value': 230.9,
#     'datetime': '2020-04-01T03:10:00.000+02:00',
#     'datetime_utc': '2020-04-01T01:10:00Z',
#     'tz_time': '2020-04-01T01:10:00.000Z',
#     'geo_id': 8797,
#     'geo_name': 'Tenerife'},
#    {'value': 20.4,
#     'datetime': '2020-04-01T03:10:00.000+02:00',
#     'datetime_utc': '2020-04-01T01:10:00Z',
#     'tz_time': '2020-04-01T01:10:00.000Z',
#     'geo_id': 8798,
#     'geo_name': 'La Palma'},
#    {'value': 6.7,
#     'datetime': '2020-04-01T03:10:00.000+02:00',
#     'datetime_utc': '2020-04-01T01:10:00Z',
#     'tz_time': '2020-04-01T01:10:00.000Z',
#     'geo_id': 8799,
#     'geo_name': 'La Gomera'},
#    {'value': 3.1,
#     'datetime': '2020-04-01T03:10:00.000+02:00',
#     'datetime_utc': '2020-04-01T01:10:00Z',
#     'tz_time': '2020-04-01T01:10:00.000Z',
#     'geo_id': 8800,
#     'geo_name': 'El Hierro'},
#    {'value': 343.9,
#     'datetime': '2020-04-01T03:10:00.000+02:00',
#     'datetime_utc': '2020-04-01T01:10:00Z',
#     'tz_time': '2020-04-01T01:10:00.000Z',
#     'geo_id': 8823,
#     'geo_name': 'Baleares'},
#    {'value': 232.7,
#     'datetime': '2020-04-01T03:20:00.000+02:00',
#     'datetime_utc': '2020-04-01T01:20:00Z',
#     'tz_time': '2020-04-01T01:20:00.000Z',
#     'geo_id': 8795,
#     'geo_name': 'Gran Canaria'},
#    {'value': 92.0,
#     'datetime': '2020-04-01T03:20:00.000+02:00',
#     'datetime_utc': '2020-04-01T01:20:00Z',
#     'tz_time': '2020-04-01T01:20:00.000Z',
#     'geo_id': 8796,
#     'geo_name': 'Lanzarote y Fuerteventura'},
#    {'value': 228.6,
#     'datetime': '2020-04-01T03:20:00.000+02:00',
#     'datetime_utc': '2020-04-01T01:20:00Z',
#     'tz_time': '2020-04-01T01:20:00.000Z',
#     'geo_id': 8797,
#     'geo_name': 'Tenerife'},
#    {'value': 20.0,
#     'datetime': '2020-04-01T03:20:00.000+02:00',
#     'datetime_utc': '2020-04-01T01:20:00Z',
#     'tz_time': '2020-04-01T01:20:00.000Z',
#     'geo_id': 8798,
#     'geo_name': 'La Palma'},
#    {'value': 6.7,
#     'datetime': '2020-04-01T03:20:00.000+02:00',
#     'datetime_utc': '2020-04-01T01:20:00Z',
#     'tz_time': '2020-04-01T01:20:00.000Z',
#     'geo_id': 8799,
#     'geo_name': 'La Gomera'},
#    {'value': 3.5,
#     'datetime': '2020-04-01T03:20:00.000+02:00',
#     'datetime_utc': '2020-04-01T01:20:00Z',
#     'tz_time': '2020-04-01T01:20:00.000Z',
#     'geo_id': 8800,
#     'geo_name': 'El Hierro'},
#    {'value': 342.4,
#     'datetime': '2020-04-01T03:20:00.000+02:00',
#     'datetime_utc': '2020-04-01T01:20:00Z',
#     'tz_time': '2020-04-01T01:20:00.000Z',
#     'geo_id': 8823,
#     'geo_name': 'Baleares'},
#    {'value': 228.0,
#     'datetime': '2020-04-01T03:30:00.000+02:00',
#     'datetime_utc': '2020-04-01T01:30:00Z',
#     'tz_time': '2020-04-01T01:30:00.000Z',
#     'geo_id': 8795,
#     'geo_name': 'Gran Canaria'},
#    {'value': 91.0,
#     'datetime': '2020-04-01T03:30:00.000+02:00',
#     'datetime_utc': '2020-04-01T01:30:00Z',
#     'tz_time': '2020-04-01T01:30:00.000Z',
#     'geo_id': 8796,
#     'geo_name': 'Lanzarote y Fuerteventura'},
#    {'value': 229.2,
#     'datetime': '2020-04-01T03:30:00.000+02:00',
#     'datetime_utc': '2020-04-01T01:30:00Z',
#     'tz_time': '2020-04-01T01:30:00.000Z',
#     'geo_id': 8797,
#     'geo_name': 'Tenerife'},
#    {'value': 20.2,
#     'datetime': '2020-04-01T03:30:00.000+02:00',
#     'datetime_utc': '2020-04-01T01:30:00Z',
#     'tz_time': '2020-04-01T01:30:00.000Z',
#     'geo_id': 8798,
#     'geo_name': 'La Palma'},
#    {'value': 6.6,
#     'datetime': '2020-04-01T03:30:00.000+02:00',
#     'datetime_utc': '2020-04-01T01:30:00Z',
#     'tz_time': '2020-04-01T01:30:00.000Z',
#     'geo_id': 8799,
#     'geo_name': 'La Gomera'},
#    {'value': 3.5,
#     'datetime': '2020-04-01T03:30:00.000+02:00',
#     'datetime_utc': '2020-04-01T01:30:00Z',
#     'tz_time': '2020-04-01T01:30:00.000Z',
#     'geo_id': 8800,
#     'geo_name': 'El Hierro'},
#    {'value': 341.2,
#     'datetime': '2020-04-01T03:30:00.000+02:00',
#     'datetime_utc': '2020-04-01T01:30:00Z',
#     'tz_time': '2020-04-01T01:30:00.000Z',
#     'geo_id': 8823,
#     'geo_name': 'Baleares'},
#    {'value': 228.8,
#     'datetime': '2020-04-01T03:40:00.000+02:00',
#     'datetime_utc': '2020-04-01T01:40:00Z',
#     'tz_time': '2020-04-01T01:40:00.000Z',
#     'geo_id': 8795,
#     'geo_name': 'Gran Canaria'},
#    {'value': 90.7,
#     'datetime': '2020-04-01T03:40:00.000+02:00',
#     'datetime_utc': '2020-04-01T01:40:00Z',
#     'tz_time': '2020-04-01T01:40:00.000Z',
#     'geo_id': 8796,
#     'geo_name': 'Lanzarote y Fuerteventura'},
#    {'value': 227.7,
#     'datetime': '2020-04-01T03:40:00.000+02:00',
#     'datetime_utc': '2020-04-01T01:40:00Z',
#     'tz_time': '2020-04-01T01:40:00.000Z',
#     'geo_id': 8797,
#     'geo_name': 'Tenerife'},
#    {'value': 19.6,
#     'datetime': '2020-04-01T03:40:00.000+02:00',
#     'datetime_utc': '2020-04-01T01:40:00Z',
#     'tz_time': '2020-04-01T01:40:00.000Z',
#     'geo_id': 8798,
#     'geo_name': 'La Palma'},
#    {'value': 6.5,
#     'datetime': '2020-04-01T03:40:00.000+02:00',
#     'datetime_utc': '2020-04-01T01:40:00Z',
#     'tz_time': '2020-04-01T01:40:00.000Z',
#     'geo_id': 8799,
#     'geo_name': 'La Gomera'},
#    {'value': 3.0,
#     'datetime': '2020-04-01T03:40:00.000+02:00',
#     'datetime_utc': '2020-04-01T01:40:00Z',
#     'tz_time': '2020-04-01T01:40:00.000Z',
#     'geo_id': 8800,
#     'geo_name': 'El Hierro'},
#    {'value': 338.6,
#     'datetime': '2020-04-01T03:40:00.000+02:00',
#     'datetime_utc': '2020-04-01T01:40:00Z',
#     'tz_time': '2020-04-01T01:40:00.000Z',
#     'geo_id': 8823,
#     'geo_name': 'Baleares'},
#    {'value': 229.6,
#     'datetime': '2020-04-01T03:50:00.000+02:00',
#     'datetime_utc': '2020-04-01T01:50:00Z',
#     'tz_time': '2020-04-01T01:50:00.000Z',
#     'geo_id': 8795,
#     'geo_name': 'Gran Canaria'},
#    {'value': 91.2,
#     'datetime': '2020-04-01T03:50:00.000+02:00',
#     'datetime_utc': '2020-04-01T01:50:00Z',
#     'tz_time': '2020-04-01T01:50:00.000Z',
#     'geo_id': 8796,
#     'geo_name': 'Lanzarote y Fuerteventura'},
#    {'value': 226.2,
#     'datetime': '2020-04-01T03:50:00.000+02:00',
#     'datetime_utc': '2020-04-01T01:50:00Z',
#     'tz_time': '2020-04-01T01:50:00.000Z',
#     'geo_id': 8797,
#     'geo_name': 'Tenerife'},
#    {'value': 19.8,
#     'datetime': '2020-04-01T03:50:00.000+02:00',
#     'datetime_utc': '2020-04-01T01:50:00Z',
#     'tz_time': '2020-04-01T01:50:00.000Z',
#     'geo_id': 8798,
#     'geo_name': 'La Palma'},
#    {'value': 6.5,
#     'datetime': '2020-04-01T03:50:00.000+02:00',
#     'datetime_utc': '2020-04-01T01:50:00Z',
#     'tz_time': '2020-04-01T01:50:00.000Z',
#     'geo_id': 8799,
#     'geo_name': 'La Gomera'},
#    {'value': 3.2,
#     'datetime': '2020-04-01T03:50:00.000+02:00',
#     'datetime_utc': '2020-04-01T01:50:00Z',
#     'tz_time': '2020-04-01T01:50:00.000Z',
#     'geo_id': 8800,
#     'geo_name': 'El Hierro'},
#    {'value': 335.3,
#     'datetime': '2020-04-01T03:50:00.000+02:00',
#     'datetime_utc': '2020-04-01T01:50:00Z',
#     'tz_time': '2020-04-01T01:50:00.000Z',
#     'geo_id': 8823,
#     'geo_name': 'Baleares'},
#    {'value': 228.3,
#     'datetime': '2020-04-01T04:00:00.000+02:00',
#     'datetime_utc': '2020-04-01T02:00:00Z',
#     'tz_time': '2020-04-01T02:00:00.000Z',
#     'geo_id': 8795,
#     'geo_name': 'Gran Canaria'},
#    {'value': 90.9,
#     'datetime': '2020-04-01T04:00:00.000+02:00',
#     'datetime_utc': '2020-04-01T02:00:00Z',
#     'tz_time': '2020-04-01T02:00:00.000Z',
#     'geo_id': 8796,
#     'geo_name': 'Lanzarote y Fuerteventura'},
#    {'value': 226.6,
#     'datetime': '2020-04-01T04:00:00.000+02:00',
#     'datetime_utc': '2020-04-01T02:00:00Z',
#     'tz_time': '2020-04-01T02:00:00.000Z',
#     'geo_id': 8797,
#     'geo_name': 'Tenerife'},
#    {'value': 19.9,
#     'datetime': '2020-04-01T04:00:00.000+02:00',
#     'datetime_utc': '2020-04-01T02:00:00Z',
#     'tz_time': '2020-04-01T02:00:00.000Z',
#     'geo_id': 8798,
#     'geo_name': 'La Palma'},
#    {'value': 6.5,
#     'datetime': '2020-04-01T04:00:00.000+02:00',
#     'datetime_utc': '2020-04-01T02:00:00Z',
#     'tz_time': '2020-04-01T02:00:00.000Z',
#     'geo_id': 8799,
#     'geo_name': 'La Gomera'},
#    {'value': 3.2,
#     'datetime': '2020-04-01T04:00:00.000+02:00',
#     'datetime_utc': '2020-04-01T02:00:00Z',
#     'tz_time': '2020-04-01T02:00:00.000Z',
#     'geo_id': 8800,
#     'geo_name': 'El Hierro'},
#    {'value': 334.6,
#     'datetime': '2020-04-01T04:00:00.000+02:00',
#     'datetime_utc': '2020-04-01T02:00:00Z',
#     'tz_time': '2020-04-01T02:00:00.000Z',
#     'geo_id': 8823,
#     'geo_name': 'Baleares'},
#    {'value': 226.8,
#     'datetime': '2020-04-01T04:10:00.000+02:00',
#     'datetime_utc': '2020-04-01T02:10:00Z',
#     'tz_time': '2020-04-01T02:10:00.000Z',
#     'geo_id': 8795,
#     'geo_name': 'Gran Canaria'},
#    {'value': 91.4,
#     'datetime': '2020-04-01T04:10:00.000+02:00',
#     'datetime_utc': '2020-04-01T02:10:00Z',
#     'tz_time': '2020-04-01T02:10:00.000Z',
#     'geo_id': 8796,
#     'geo_name': 'Lanzarote y Fuerteventura'},
#    {'value': 226.3,
#     'datetime': '2020-04-01T04:10:00.000+02:00',
#     'datetime_utc': '2020-04-01T02:10:00Z',
#     'tz_time': '2020-04-01T02:10:00.000Z',
#     'geo_id': 8797,
#     'geo_name': 'Tenerife'},
#    {'value': 19.6,
#     'datetime': '2020-04-01T04:10:00.000+02:00',
#     'datetime_utc': '2020-04-01T02:10:00Z',
#     'tz_time': '2020-04-01T02:10:00.000Z',
#     'geo_id': 8798,
#     'geo_name': 'La Palma'},
#    {'value': 6.3,
#     'datetime': '2020-04-01T04:10:00.000+02:00',
#     'datetime_utc': '2020-04-01T02:10:00Z',
#     'tz_time': '2020-04-01T02:10:00.000Z',
#     'geo_id': 8799,
#     'geo_name': 'La Gomera'},
#    {'value': 3.8,
#     'datetime': '2020-04-01T04:10:00.000+02:00',
#     'datetime_utc': '2020-04-01T02:10:00Z',
#     'tz_time': '2020-04-01T02:10:00.000Z',
#     'geo_id': 8800,
#     'geo_name': 'El Hierro'},
#    {'value': 334.5,
#     'datetime': '2020-04-01T04:10:00.000+02:00',
#     'datetime_utc': '2020-04-01T02:10:00Z',
#     'tz_time': '2020-04-01T02:10:00.000Z',
#     'geo_id': 8823,
#     'geo_name': 'Baleares'},
#    {'value': 224.0,
#     'datetime': '2020-04-01T04:20:00.000+02:00',
#     'datetime_utc': '2020-04-01T02:20:00Z',
#     'tz_time': '2020-04-01T02:20:00.000Z',
#     'geo_id': 8795,
#     'geo_name': 'Gran Canaria'},
#    {'value': 91.3,
#     'datetime': '2020-04-01T04:20:00.000+02:00',
#     'datetime_utc': '2020-04-01T02:20:00Z',
#     'tz_time': '2020-04-01T02:20:00.000Z',
#     'geo_id': 8796,
#     'geo_name': 'Lanzarote y Fuerteventura'},
#    {'value': 225.2,
#     'datetime': '2020-04-01T04:20:00.000+02:00',
#     'datetime_utc': '2020-04-01T02:20:00Z',
#     'tz_time': '2020-04-01T02:20:00.000Z',
#     'geo_id': 8797,
#     'geo_name': 'Tenerife'},
#    {'value': 19.8,
#     'datetime': '2020-04-01T04:20:00.000+02:00',
#     'datetime_utc': '2020-04-01T02:20:00Z',
#     'tz_time': '2020-04-01T02:20:00.000Z',
#     'geo_id': 8798,
#     'geo_name': 'La Palma'},
#    {'value': 6.4,
#     'datetime': '2020-04-01T04:20:00.000+02:00',
#     'datetime_utc': '2020-04-01T02:20:00Z',
#     'tz_time': '2020-04-01T02:20:00.000Z',
#     'geo_id': 8799,
#     'geo_name': 'La Gomera'},
#    {'value': 3.8,
#     'datetime': '2020-04-01T04:20:00.000+02:00',
#     'datetime_utc': '2020-04-01T02:20:00Z',
#     'tz_time': '2020-04-01T02:20:00.000Z',
#     'geo_id': 8800,
#     'geo_name': 'El Hierro'},
#    {'value': 332.7,
#     'datetime': '2020-04-01T04:20:00.000+02:00',
#     'datetime_utc': '2020-04-01T02:20:00Z',
#     'tz_time': '2020-04-01T02:20:00.000Z',
#     'geo_id': 8823,
#     'geo_name': 'Baleares'},
#    {'value': 223.4,
#     'datetime': '2020-04-01T04:30:00.000+02:00',
#     'datetime_utc': '2020-04-01T02:30:00Z',
#     'tz_time': '2020-04-01T02:30:00.000Z',
#     'geo_id': 8795,
#     'geo_name': 'Gran Canaria'},
#    {'value': 90.1,
#     'datetime': '2020-04-01T04:30:00.000+02:00',
#     'datetime_utc': '2020-04-01T02:30:00Z',
#     'tz_time': '2020-04-01T02:30:00.000Z',
#     'geo_id': 8796,
#     'geo_name': 'Lanzarote y Fuerteventura'},
#    {'value': 223.2,
#     'datetime': '2020-04-01T04:30:00.000+02:00',
#     'datetime_utc': '2020-04-01T02:30:00Z',
#     'tz_time': '2020-04-01T02:30:00.000Z',
#     'geo_id': 8797,
#     'geo_name': 'Tenerife'},
#    {'value': 19.8,
#     'datetime': '2020-04-01T04:30:00.000+02:00',
#     'datetime_utc': '2020-04-01T02:30:00Z',
#     'tz_time': '2020-04-01T02:30:00.000Z',
#     'geo_id': 8798,
#     'geo_name': 'La Palma'},
#    {'value': 6.4,
#     'datetime': '2020-04-01T04:30:00.000+02:00',
#     'datetime_utc': '2020-04-01T02:30:00Z',
#     'tz_time': '2020-04-01T02:30:00.000Z',
#     'geo_id': 8799,
#     'geo_name': 'La Gomera'},
#    {'value': 3.3,
#     'datetime': '2020-04-01T04:30:00.000+02:00',
#     'datetime_utc': '2020-04-01T02:30:00Z',
#     'tz_time': '2020-04-01T02:30:00.000Z',
#     'geo_id': 8800,
#     'geo_name': 'El Hierro'},
#    {'value': 332.7,
#     'datetime': '2020-04-01T04:30:00.000+02:00',
#     'datetime_utc': '2020-04-01T02:30:00Z',
#     'tz_time': '2020-04-01T02:30:00.000Z',
#     'geo_id': 8823,
#     'geo_name': 'Baleares'},
#    {'value': 229.9,
#     'datetime': '2020-04-01T04:40:00.000+02:00',
#     'datetime_utc': '2020-04-01T02:40:00Z',
#     'tz_time': '2020-04-01T02:40:00.000Z',
#     'geo_id': 8795,
#     'geo_name': 'Gran Canaria'},
#    {'value': 89.8,
#     'datetime': '2020-04-01T04:40:00.000+02:00',
#     'datetime_utc': '2020-04-01T02:40:00Z',
#     'tz_time': '2020-04-01T02:40:00.000Z',
#     'geo_id': 8796,
#     'geo_name': 'Lanzarote y Fuerteventura'},
#    {'value': 222.1,
#     'datetime': '2020-04-01T04:40:00.000+02:00',
#     'datetime_utc': '2020-04-01T02:40:00Z',
#     'tz_time': '2020-04-01T02:40:00.000Z',
#     'geo_id': 8797,
#     'geo_name': 'Tenerife'},
#    {'value': 19.7,
#     'datetime': '2020-04-01T04:40:00.000+02:00',
#     'datetime_utc': '2020-04-01T02:40:00Z',
#     'tz_time': '2020-04-01T02:40:00.000Z',
#     'geo_id': 8798,
#     'geo_name': 'La Palma'},
#    {'value': 6.3,
#     'datetime': '2020-04-01T04:40:00.000+02:00',
#     'datetime_utc': '2020-04-01T02:40:00Z',
#     'tz_time': '2020-04-01T02:40:00.000Z',
#     'geo_id': 8799,
#     'geo_name': 'La Gomera'},
#    {'value': 3.8,
#     'datetime': '2020-04-01T04:40:00.000+02:00',
#     'datetime_utc': '2020-04-01T02:40:00Z',
#     'tz_time': '2020-04-01T02:40:00.000Z',
#     'geo_id': 8800,
#     'geo_name': 'El Hierro'},
#    {'value': 333.1,
#     'datetime': '2020-04-01T04:40:00.000+02:00',
#     'datetime_utc': '2020-04-01T02:40:00Z',
#     'tz_time': '2020-04-01T02:40:00.000Z',
#     'geo_id': 8823,
#     'geo_name': 'Baleares'},
#    {'value': 232.2,
#     'datetime': '2020-04-01T04:50:00.000+02:00',
#     'datetime_utc': '2020-04-01T02:50:00Z',
#     'tz_time': '2020-04-01T02:50:00.000Z',
#     'geo_id': 8795,
#     'geo_name': 'Gran Canaria'},
#    {'value': 89.4,
#     'datetime': '2020-04-01T04:50:00.000+02:00',
#     'datetime_utc': '2020-04-01T02:50:00Z',
#     'tz_time': '2020-04-01T02:50:00.000Z',
#     'geo_id': 8796,
#     'geo_name': 'Lanzarote y Fuerteventura'},
#    {'value': 221.8,
#     'datetime': '2020-04-01T04:50:00.000+02:00',
#     'datetime_utc': '2020-04-01T02:50:00Z',
#     'tz_time': '2020-04-01T02:50:00.000Z',
#     'geo_id': 8797,
#     'geo_name': 'Tenerife'},
#    {'value': 19.6,
#     'datetime': '2020-04-01T04:50:00.000+02:00',
#     'datetime_utc': '2020-04-01T02:50:00Z',
#     'tz_time': '2020-04-01T02:50:00.000Z',
#     'geo_id': 8798,
#     'geo_name': 'La Palma'},
#    {'value': 6.5,
#     'datetime': '2020-04-01T04:50:00.000+02:00',
#     'datetime_utc': '2020-04-01T02:50:00Z',
#     'tz_time': '2020-04-01T02:50:00.000Z',
#     'geo_id': 8799,
#     'geo_name': 'La Gomera'},
#    {'value': 4.0,
#     'datetime': '2020-04-01T04:50:00.000+02:00',
#     'datetime_utc': '2020-04-01T02:50:00Z',
#     'tz_time': '2020-04-01T02:50:00.000Z',
#     'geo_id': 8800,
#     'geo_name': 'El Hierro'},
#    {'value': 332.0,
#     'datetime': '2020-04-01T04:50:00.000+02:00',
#     'datetime_utc': '2020-04-01T02:50:00Z',
#     'tz_time': '2020-04-01T02:50:00.000Z',
#     'geo_id': 8823,
#     'geo_name': 'Baleares'},
#    {'value': 233.9,
#     'datetime': '2020-04-01T05:00:00.000+02:00',
#     'datetime_utc': '2020-04-01T03:00:00Z',
#     'tz_time': '2020-04-01T03:00:00.000Z',
#     'geo_id': 8795,
#     'geo_name': 'Gran Canaria'},
#    {'value': 89.1,
#     'datetime': '2020-04-01T05:00:00.000+02:00',
#     'datetime_utc': '2020-04-01T03:00:00Z',
#     'tz_time': '2020-04-01T03:00:00.000Z',
#     'geo_id': 8796,
#     'geo_name': 'Lanzarote y Fuerteventura'},
#    {'value': 222.4,
#     'datetime': '2020-04-01T05:00:00.000+02:00',
#     'datetime_utc': '2020-04-01T03:00:00Z',
#     'tz_time': '2020-04-01T03:00:00.000Z',
#     'geo_id': 8797,
#     'geo_name': 'Tenerife'},
#    {'value': 19.7,
#     'datetime': '2020-04-01T05:00:00.000+02:00',
#     'datetime_utc': '2020-04-01T03:00:00Z',
#     'tz_time': '2020-04-01T03:00:00.000Z',
#     'geo_id': 8798,
#     'geo_name': 'La Palma'},
#    {'value': 6.3,
#     'datetime': '2020-04-01T05:00:00.000+02:00',
#     'datetime_utc': '2020-04-01T03:00:00Z',
#     'tz_time': '2020-04-01T03:00:00.000Z',
#     'geo_id': 8799,
#     'geo_name': 'La Gomera'},
#    {'value': 3.9,
#     'datetime': '2020-04-01T05:00:00.000+02:00',
#     'datetime_utc': '2020-04-01T03:00:00Z',
#     'tz_time': '2020-04-01T03:00:00.000Z',
#     'geo_id': 8800,
#     'geo_name': 'El Hierro'},
#    {'value': 333.5,
#     'datetime': '2020-04-01T05:00:00.000+02:00',
#     'datetime_utc': '2020-04-01T03:00:00Z',
#     'tz_time': '2020-04-01T03:00:00.000Z',
#     'geo_id': 8823,
#     'geo_name': 'Baleares'},
#    {'value': 235.1,
#     'datetime': '2020-04-01T05:10:00.000+02:00',
#     'datetime_utc': '2020-04-01T03:10:00Z',
#     'tz_time': '2020-04-01T03:10:00.000Z',
#     'geo_id': 8795,
#     'geo_name': 'Gran Canaria'},
#    {'value': 90.0,
#     'datetime': '2020-04-01T05:10:00.000+02:00',
#     'datetime_utc': '2020-04-01T03:10:00Z',
#     'tz_time': '2020-04-01T03:10:00.000Z',
#     'geo_id': 8796,
#     'geo_name': 'Lanzarote y Fuerteventura'},
#    {'value': 224.2,
#     'datetime': '2020-04-01T05:10:00.000+02:00',
#     'datetime_utc': '2020-04-01T03:10:00Z',
#     'tz_time': '2020-04-01T03:10:00.000Z',
#     'geo_id': 8797,
#     'geo_name': 'Tenerife'},
#    {'value': 19.6,
#     'datetime': '2020-04-01T05:10:00.000+02:00',
#     'datetime_utc': '2020-04-01T03:10:00Z',
#     'tz_time': '2020-04-01T03:10:00.000Z',
#     'geo_id': 8798,
#     'geo_name': 'La Palma'},
#    {'value': 6.4,
#     'datetime': '2020-04-01T05:10:00.000+02:00',
#     'datetime_utc': '2020-04-01T03:10:00Z',
#     'tz_time': '2020-04-01T03:10:00.000Z',
#     'geo_id': 8799,
#     'geo_name': 'La Gomera'},
#    {'value': 3.9,
#     'datetime': '2020-04-01T05:10:00.000+02:00',
#     'datetime_utc': '2020-04-01T03:10:00Z',
#     'tz_time': '2020-04-01T03:10:00.000Z',
#     'geo_id': 8800,
#     'geo_name': 'El Hierro'},
#    {'value': 335.1,
#     'datetime': '2020-04-01T05:10:00.000+02:00',
#     'datetime_utc': '2020-04-01T03:10:00Z',
#     'tz_time': '2020-04-01T03:10:00.000Z',
#     'geo_id': 8823,
#     'geo_name': 'Baleares'},
#    {'value': 236.7,
#     'datetime': '2020-04-01T05:20:00.000+02:00',
#     'datetime_utc': '2020-04-01T03:20:00Z',
#     'tz_time': '2020-04-01T03:20:00.000Z',
#     'geo_id': 8795,
#     'geo_name': 'Gran Canaria'},
#    {'value': 90.1,
#     'datetime': '2020-04-01T05:20:00.000+02:00',
#     'datetime_utc': '2020-04-01T03:20:00Z',
#     'tz_time': '2020-04-01T03:20:00.000Z',
#     'geo_id': 8796,
#     'geo_name': 'Lanzarote y Fuerteventura'},
#    {'value': 219.2,
#     'datetime': '2020-04-01T05:20:00.000+02:00',
#     'datetime_utc': '2020-04-01T03:20:00Z',
#     'tz_time': '2020-04-01T03:20:00.000Z',
#     'geo_id': 8797,
#     'geo_name': 'Tenerife'},
#    {'value': 19.5,
#     'datetime': '2020-04-01T05:20:00.000+02:00',
#     'datetime_utc': '2020-04-01T03:20:00Z',
# ...
#    {'value': 618.0,
#     'datetime': '2020-04-01T21:50:00.000+02:00',
#     'datetime_utc': '2020-04-01T19:50:00Z',
#     'tz_time': '2020-04-01T19:50:00.000Z',
#     'geo_id': 8823,
#     'geo_name': 'Baleares'},
#    {'value': 363.4,
#     'datetime': '2020-04-01T22:00:00.000+02:00',
#     'datetime_utc': '2020-04-01T20:00:00Z',
#     'tz_time': '2020-04-01T20:00:00.000Z',
#     'geo_id': 8795,
#     'geo_name': 'Gran Canaria'},
#    {'value': 132.7,
#     'datetime': '2020-04-01T22:00:00.000+02:00',
#     'datetime_utc': '2020-04-01T20:00:00Z',
#     'tz_time': '2020-04-01T20:00:00.000Z',
#     'geo_id': 8796,
#     'geo_name': 'Lanzarote y Fuerteventura'},
#    {'value': 368.2,
#     'datetime': '2020-04-01T22:00:00.000+02:00',
#     'datetime_utc': '2020-04-01T20:00:00Z',
#     'tz_time': '2020-04-01T20:00:00.000Z',
#     'geo_id': 8797,
#     'geo_name': 'Tenerife'},
#    {'value': 33.7,
#     'datetime': '2020-04-01T22:00:00.000+02:00',
#     'datetime_utc': '2020-04-01T20:00:00Z',
#     'tz_time': '2020-04-01T20:00:00.000Z',
#     'geo_id': 8798,
#     'geo_name': 'La Palma'},
#    {'value': 7.7,
#     'datetime': '2020-04-01T22:00:00.000+02:00',
#     'datetime_utc': '2020-04-01T20:00:00Z',
#     'tz_time': '2020-04-01T20:00:00.000Z',
#     'geo_id': 8799,
#     'geo_name': 'La Gomera'},
#    {'value': 5.6,
#     'datetime': '2020-04-01T22:00:00.000+02:00',
#     'datetime_utc': '2020-04-01T20:00:00Z',
#     'tz_time': '2020-04-01T20:00:00.000Z',
#     'geo_id': 8800,
#     'geo_name': 'El Hierro'},
#    {'value': 603.6,
#     'datetime': '2020-04-01T22:00:00.000+02:00',
#     'datetime_utc': '2020-04-01T20:00:00Z',
#     'tz_time': '2020-04-01T20:00:00.000Z',
#     'geo_id': 8823,
#     'geo_name': 'Baleares'},
#    {'value': 350.7,
#     'datetime': '2020-04-01T22:10:00.000+02:00',
#     'datetime_utc': '2020-04-01T20:10:00Z',
#     'tz_time': '2020-04-01T20:10:00.000Z',
#     'geo_id': 8795,
#     'geo_name': 'Gran Canaria'},
#    {'value': 128.9,
#     'datetime': '2020-04-01T22:10:00.000+02:00',
#     'datetime_utc': '2020-04-01T20:10:00Z',
#     'tz_time': '2020-04-01T20:10:00.000Z',
#     'geo_id': 8796,
#     'geo_name': 'Lanzarote y Fuerteventura'},
#    {'value': 361.5,
#     'datetime': '2020-04-01T22:10:00.000+02:00',
#     'datetime_utc': '2020-04-01T20:10:00Z',
#     'tz_time': '2020-04-01T20:10:00.000Z',
#     'geo_id': 8797,
#     'geo_name': 'Tenerife'},
#    {'value': 32.9,
#     'datetime': '2020-04-01T22:10:00.000+02:00',
#     'datetime_utc': '2020-04-01T20:10:00Z',
#     'tz_time': '2020-04-01T20:10:00.000Z',
#     'geo_id': 8798,
#     'geo_name': 'La Palma'},
#    {'value': 7.5,
#     'datetime': '2020-04-01T22:10:00.000+02:00',
#     'datetime_utc': '2020-04-01T20:10:00Z',
#     'tz_time': '2020-04-01T20:10:00.000Z',
#     'geo_id': 8799,
#     'geo_name': 'La Gomera'},
#    {'value': 5.5,
#     'datetime': '2020-04-01T22:10:00.000+02:00',
#     'datetime_utc': '2020-04-01T20:10:00Z',
#     'tz_time': '2020-04-01T20:10:00.000Z',
#     'geo_id': 8800,
#     'geo_name': 'El Hierro'},
#    {'value': 590.5,
#     'datetime': '2020-04-01T22:10:00.000+02:00',
#     'datetime_utc': '2020-04-01T20:10:00Z',
#     'tz_time': '2020-04-01T20:10:00.000Z',
#     'geo_id': 8823,
#     'geo_name': 'Baleares'},
#    {'value': 340.7,
#     'datetime': '2020-04-01T22:20:00.000+02:00',
#     'datetime_utc': '2020-04-01T20:20:00Z',
#     'tz_time': '2020-04-01T20:20:00.000Z',
#     'geo_id': 8795,
#     'geo_name': 'Gran Canaria'},
#    {'value': 126.0,
#     'datetime': '2020-04-01T22:20:00.000+02:00',
#     'datetime_utc': '2020-04-01T20:20:00Z',
#     'tz_time': '2020-04-01T20:20:00.000Z',
#     'geo_id': 8796,
#     'geo_name': 'Lanzarote y Fuerteventura'},
#    {'value': 352.5,
#     'datetime': '2020-04-01T22:20:00.000+02:00',
#     'datetime_utc': '2020-04-01T20:20:00Z',
#     'tz_time': '2020-04-01T20:20:00.000Z',
#     'geo_id': 8797,
#     'geo_name': 'Tenerife'},
#    {'value': 32.2,
#     'datetime': '2020-04-01T22:20:00.000+02:00',
#     'datetime_utc': '2020-04-01T20:20:00Z',
#     'tz_time': '2020-04-01T20:20:00.000Z',
#     'geo_id': 8798,
#     'geo_name': 'La Palma'},
#    {'value': 7.4,
#     'datetime': '2020-04-01T22:20:00.000+02:00',
#     'datetime_utc': '2020-04-01T20:20:00Z',
#     'tz_time': '2020-04-01T20:20:00.000Z',
#     'geo_id': 8799,
#     'geo_name': 'La Gomera'},
#    {'value': 5.5,
#     'datetime': '2020-04-01T22:20:00.000+02:00',
#     'datetime_utc': '2020-04-01T20:20:00Z',
#     'tz_time': '2020-04-01T20:20:00.000Z',
#     'geo_id': 8800,
#     'geo_name': 'El Hierro'},
#    {'value': 574.9,
#     'datetime': '2020-04-01T22:20:00.000+02:00',
#     'datetime_utc': '2020-04-01T20:20:00Z',
#     'tz_time': '2020-04-01T20:20:00.000Z',
#     'geo_id': 8823,
#     'geo_name': 'Baleares'},
#    {'value': 331.0,
#     'datetime': '2020-04-01T22:30:00.000+02:00',
#     'datetime_utc': '2020-04-01T20:30:00Z',
#     'tz_time': '2020-04-01T20:30:00.000Z',
#     'geo_id': 8795,
#     'geo_name': 'Gran Canaria'},
#    {'value': 122.6,
#     'datetime': '2020-04-01T22:30:00.000+02:00',
#     'datetime_utc': '2020-04-01T20:30:00Z',
#     'tz_time': '2020-04-01T20:30:00.000Z',
#     'geo_id': 8796,
#     'geo_name': 'Lanzarote y Fuerteventura'},
#    {'value': 345.6,
#     'datetime': '2020-04-01T22:30:00.000+02:00',
#     'datetime_utc': '2020-04-01T20:30:00Z',
#     'tz_time': '2020-04-01T20:30:00.000Z',
#     'geo_id': 8797,
#     'geo_name': 'Tenerife'},
#    {'value': 31.4,
#     'datetime': '2020-04-01T22:30:00.000+02:00',
#     'datetime_utc': '2020-04-01T20:30:00Z',
#     'tz_time': '2020-04-01T20:30:00.000Z',
#     'geo_id': 8798,
#     'geo_name': 'La Palma'},
#    {'value': 7.3,
#     'datetime': '2020-04-01T22:30:00.000+02:00',
#     'datetime_utc': '2020-04-01T20:30:00Z',
#     'tz_time': '2020-04-01T20:30:00.000Z',
#     'geo_id': 8799,
#     'geo_name': 'La Gomera'},
#    {'value': 5.4,
#     'datetime': '2020-04-01T22:30:00.000+02:00',
#     'datetime_utc': '2020-04-01T20:30:00Z',
#     'tz_time': '2020-04-01T20:30:00.000Z',
#     'geo_id': 8800,
#     'geo_name': 'El Hierro'},
#    {'value': 560.9,
#     'datetime': '2020-04-01T22:30:00.000+02:00',
#     'datetime_utc': '2020-04-01T20:30:00Z',
#     'tz_time': '2020-04-01T20:30:00.000Z',
#     'geo_id': 8823,
#     'geo_name': 'Baleares'},
#    {'value': 328.4,
#     'datetime': '2020-04-01T22:40:00.000+02:00',
#     'datetime_utc': '2020-04-01T20:40:00Z',
#     'tz_time': '2020-04-01T20:40:00.000Z',
#     'geo_id': 8795,
#     'geo_name': 'Gran Canaria'},
#    {'value': 120.8,
#     'datetime': '2020-04-01T22:40:00.000+02:00',
#     'datetime_utc': '2020-04-01T20:40:00Z',
#     'tz_time': '2020-04-01T20:40:00.000Z',
#     'geo_id': 8796,
#     'geo_name': 'Lanzarote y Fuerteventura'},
#    {'value': 334.3,
#     'datetime': '2020-04-01T22:40:00.000+02:00',
#     'datetime_utc': '2020-04-01T20:40:00Z',
#     'tz_time': '2020-04-01T20:40:00.000Z',
#     'geo_id': 8797,
#     'geo_name': 'Tenerife'},
#    {'value': 30.9,
#     'datetime': '2020-04-01T22:40:00.000+02:00',
#     'datetime_utc': '2020-04-01T20:40:00Z',
#     'tz_time': '2020-04-01T20:40:00.000Z',
#     'geo_id': 8798,
#     'geo_name': 'La Palma'},
#    {'value': 7.2,
#     'datetime': '2020-04-01T22:40:00.000+02:00',
#     'datetime_utc': '2020-04-01T20:40:00Z',
#     'tz_time': '2020-04-01T20:40:00.000Z',
#     'geo_id': 8799,
#     'geo_name': 'La Gomera'},
#    {'value': 5.4,
#     'datetime': '2020-04-01T22:40:00.000+02:00',
#     'datetime_utc': '2020-04-01T20:40:00Z',
#     'tz_time': '2020-04-01T20:40:00.000Z',
#     'geo_id': 8800,
#     'geo_name': 'El Hierro'},
#    {'value': 548.5,
#     'datetime': '2020-04-01T22:40:00.000+02:00',
#     'datetime_utc': '2020-04-01T20:40:00Z',
#     'tz_time': '2020-04-01T20:40:00.000Z',
#     'geo_id': 8823,
#     'geo_name': 'Baleares'},
#    {'value': 316.4,
#     'datetime': '2020-04-01T22:50:00.000+02:00',
#     'datetime_utc': '2020-04-01T20:50:00Z',
#     'tz_time': '2020-04-01T20:50:00.000Z',
#     'geo_id': 8795,
#     'geo_name': 'Gran Canaria'},
#    {'value': 120.1,
#     'datetime': '2020-04-01T22:50:00.000+02:00',
#     'datetime_utc': '2020-04-01T20:50:00Z',
#     'tz_time': '2020-04-01T20:50:00.000Z',
#     'geo_id': 8796,
#     'geo_name': 'Lanzarote y Fuerteventura'},
#    {'value': 329.1,
#     'datetime': '2020-04-01T22:50:00.000+02:00',
#     'datetime_utc': '2020-04-01T20:50:00Z',
#     'tz_time': '2020-04-01T20:50:00.000Z',
#     'geo_id': 8797,
#     'geo_name': 'Tenerife'},
#    {'value': 29.6,
#     'datetime': '2020-04-01T22:50:00.000+02:00',
#     'datetime_utc': '2020-04-01T20:50:00Z',
#     'tz_time': '2020-04-01T20:50:00.000Z',
#     'geo_id': 8798,
#     'geo_name': 'La Palma'},
#    {'value': 7.1,
#     'datetime': '2020-04-01T22:50:00.000+02:00',
#     'datetime_utc': '2020-04-01T20:50:00Z',
#     'tz_time': '2020-04-01T20:50:00.000Z',
#     'geo_id': 8799,
#     'geo_name': 'La Gomera'},
#    {'value': 5.3,
#     'datetime': '2020-04-01T22:50:00.000+02:00',
#     'datetime_utc': '2020-04-01T20:50:00Z',
#     'tz_time': '2020-04-01T20:50:00.000Z',
#     'geo_id': 8800,
#     'geo_name': 'El Hierro'},
#    {'value': 536.0,
#     'datetime': '2020-04-01T22:50:00.000+02:00',
#     'datetime_utc': '2020-04-01T20:50:00Z',
#     'tz_time': '2020-04-01T20:50:00.000Z',
#     'geo_id': 8823,
#     'geo_name': 'Baleares'},
#    {'value': 305.0,
#     'datetime': '2020-04-01T23:00:00.000+02:00',
#     'datetime_utc': '2020-04-01T21:00:00Z',
#     'tz_time': '2020-04-01T21:00:00.000Z',
#     'geo_id': 8795,
#     'geo_name': 'Gran Canaria'},
#    {'value': 118.9,
#     'datetime': '2020-04-01T23:00:00.000+02:00',
#     'datetime_utc': '2020-04-01T21:00:00Z',
#     'tz_time': '2020-04-01T21:00:00.000Z',
#     'geo_id': 8796,
#     'geo_name': 'Lanzarote y Fuerteventura'},
#    {'value': 320.1,
#     'datetime': '2020-04-01T23:00:00.000+02:00',
#     'datetime_utc': '2020-04-01T21:00:00Z',
#     'tz_time': '2020-04-01T21:00:00.000Z',
#     'geo_id': 8797,
#     'geo_name': 'Tenerife'},
#    {'value': 29.0,
#     'datetime': '2020-04-01T23:00:00.000+02:00',
#     'datetime_utc': '2020-04-01T21:00:00Z',
#     'tz_time': '2020-04-01T21:00:00.000Z',
#     'geo_id': 8798,
#     'geo_name': 'La Palma'},
#    {'value': 6.9,
#     'datetime': '2020-04-01T23:00:00.000+02:00',
#     'datetime_utc': '2020-04-01T21:00:00Z',
#     'tz_time': '2020-04-01T21:00:00.000Z',
#     'geo_id': 8799,
#     'geo_name': 'La Gomera'},
#    {'value': 5.4,
#     'datetime': '2020-04-01T23:00:00.000+02:00',
#     'datetime_utc': '2020-04-01T21:00:00Z',
#     'tz_time': '2020-04-01T21:00:00.000Z',
#     'geo_id': 8800,
#     'geo_name': 'El Hierro'},
#    {'value': 521.3,
#     'datetime': '2020-04-01T23:00:00.000+02:00',
#     'datetime_utc': '2020-04-01T21:00:00Z',
#     'tz_time': '2020-04-01T21:00:00.000Z',
#     'geo_id': 8823,
#     'geo_name': 'Baleares'},
#    {'value': 298.3,
#     'datetime': '2020-04-01T23:10:00.000+02:00',
#     'datetime_utc': '2020-04-01T21:10:00Z',
#     'tz_time': '2020-04-01T21:10:00.000Z',
#     'geo_id': 8795,
#     'geo_name': 'Gran Canaria'},
#    {'value': 115.7,
#     'datetime': '2020-04-01T23:10:00.000+02:00',
#     'datetime_utc': '2020-04-01T21:10:00Z',
#     'tz_time': '2020-04-01T21:10:00.000Z',
#     'geo_id': 8796,
#     'geo_name': 'Lanzarote y Fuerteventura'},
#    {'value': 311.3,
#     'datetime': '2020-04-01T23:10:00.000+02:00',
#     'datetime_utc': '2020-04-01T21:10:00Z',
#     'tz_time': '2020-04-01T21:10:00.000Z',
#     'geo_id': 8797,
#     'geo_name': 'Tenerife'},
#    {'value': 28.2,
#     'datetime': '2020-04-01T23:10:00.000+02:00',
#     'datetime_utc': '2020-04-01T21:10:00Z',
#     'tz_time': '2020-04-01T21:10:00.000Z',
#     'geo_id': 8798,
#     'geo_name': 'La Palma'},
#    {'value': 6.8,
#     'datetime': '2020-04-01T23:10:00.000+02:00',
#     'datetime_utc': '2020-04-01T21:10:00Z',
#     'tz_time': '2020-04-01T21:10:00.000Z',
#     'geo_id': 8799,
#     'geo_name': 'La Gomera'},
#    {'value': 5.2,
#     'datetime': '2020-04-01T23:10:00.000+02:00',
#     'datetime_utc': '2020-04-01T21:10:00Z',
#     'tz_time': '2020-04-01T21:10:00.000Z',
#     'geo_id': 8800,
#     'geo_name': 'El Hierro'},
#    {'value': 510.8,
#     'datetime': '2020-04-01T23:10:00.000+02:00',
#     'datetime_utc': '2020-04-01T21:10:00Z',
#     'tz_time': '2020-04-01T21:10:00.000Z',
#     'geo_id': 8823,
#     'geo_name': 'Baleares'},
#    {'value': 293.5,
#     'datetime': '2020-04-01T23:20:00.000+02:00',
#     'datetime_utc': '2020-04-01T21:20:00Z',
#     'tz_time': '2020-04-01T21:20:00.000Z',
#     'geo_id': 8795,
#     'geo_name': 'Gran Canaria'},
#    {'value': 113.5,
#     'datetime': '2020-04-01T23:20:00.000+02:00',
#     'datetime_utc': '2020-04-01T21:20:00Z',
#     'tz_time': '2020-04-01T21:20:00.000Z',
#     'geo_id': 8796,
#     'geo_name': 'Lanzarote y Fuerteventura'},
#    {'value': 304.7,
#     'datetime': '2020-04-01T23:20:00.000+02:00',
#     'datetime_utc': '2020-04-01T21:20:00Z',
#     'tz_time': '2020-04-01T21:20:00.000Z',
#     'geo_id': 8797,
#     'geo_name': 'Tenerife'},
#    {'value': 27.5,
#     'datetime': '2020-04-01T23:20:00.000+02:00',
#     'datetime_utc': '2020-04-01T21:20:00Z',
#     'tz_time': '2020-04-01T21:20:00.000Z',
#     'geo_id': 8798,
#     'geo_name': 'La Palma'},
#    {'value': 6.6,
#     'datetime': '2020-04-01T23:20:00.000+02:00',
#     'datetime_utc': '2020-04-01T21:20:00Z',
#     'tz_time': '2020-04-01T21:20:00.000Z',
#     'geo_id': 8799,
#     'geo_name': 'La Gomera'},
#    {'value': 5.0,
#     'datetime': '2020-04-01T23:20:00.000+02:00',
#     'datetime_utc': '2020-04-01T21:20:00Z',
#     'tz_time': '2020-04-01T21:20:00.000Z',
#     'geo_id': 8800,
#     'geo_name': 'El Hierro'},
#    {'value': 496.6,
#     'datetime': '2020-04-01T23:20:00.000+02:00',
#     'datetime_utc': '2020-04-01T21:20:00Z',
#     'tz_time': '2020-04-01T21:20:00.000Z',
#     'geo_id': 8823,
#     'geo_name': 'Baleares'},
#    {'value': 288.1,
#     'datetime': '2020-04-01T23:30:00.000+02:00',
#     'datetime_utc': '2020-04-01T21:30:00Z',
#     'tz_time': '2020-04-01T21:30:00.000Z',
#     'geo_id': 8795,
#     'geo_name': 'Gran Canaria'},
#    {'value': 112.6,
#     'datetime': '2020-04-01T23:30:00.000+02:00',
#     'datetime_utc': '2020-04-01T21:30:00Z',
#     'tz_time': '2020-04-01T21:30:00.000Z',
#     'geo_id': 8796,
#     'geo_name': 'Lanzarote y Fuerteventura'},
#    {'value': 298.0,
#     'datetime': '2020-04-01T23:30:00.000+02:00',
#     'datetime_utc': '2020-04-01T21:30:00Z',
#     'tz_time': '2020-04-01T21:30:00.000Z',
#     'geo_id': 8797,
#     'geo_name': 'Tenerife'},
#    {'value': 26.6,
#     'datetime': '2020-04-01T23:30:00.000+02:00',
#     'datetime_utc': '2020-04-01T21:30:00Z',
#     'tz_time': '2020-04-01T21:30:00.000Z',
#     'geo_id': 8798,
#     'geo_name': 'La Palma'},
#    {'value': 6.6,
#     'datetime': '2020-04-01T23:30:00.000+02:00',
#     'datetime_utc': '2020-04-01T21:30:00Z',
#     'tz_time': '2020-04-01T21:30:00.000Z',
#     'geo_id': 8799,
#     'geo_name': 'La Gomera'},
#    {'value': 4.7,
#     'datetime': '2020-04-01T23:30:00.000+02:00',
#     'datetime_utc': '2020-04-01T21:30:00Z',
#     'tz_time': '2020-04-01T21:30:00.000Z',
#     'geo_id': 8800,
#     'geo_name': 'El Hierro'},
#    {'value': 485.9,
#     'datetime': '2020-04-01T23:30:00.000+02:00',
#     'datetime_utc': '2020-04-01T21:30:00Z',
#     'tz_time': '2020-04-01T21:30:00.000Z',
#     'geo_id': 8823,
#     'geo_name': 'Baleares'},
#    {'value': 280.7,
#     'datetime': '2020-04-01T23:40:00.000+02:00',
#     'datetime_utc': '2020-04-01T21:40:00Z',
#     'tz_time': '2020-04-01T21:40:00.000Z',
#     'geo_id': 8795,
#     'geo_name': 'Gran Canaria'},
#    {'value': 110.3,
#     'datetime': '2020-04-01T23:40:00.000+02:00',
#     'datetime_utc': '2020-04-01T21:40:00Z',
#     'tz_time': '2020-04-01T21:40:00.000Z',
#     'geo_id': 8796,
#     'geo_name': 'Lanzarote y Fuerteventura'},
#    {'value': 291.1,
#     'datetime': '2020-04-01T23:40:00.000+02:00',
#     'datetime_utc': '2020-04-01T21:40:00Z',
#     'tz_time': '2020-04-01T21:40:00.000Z',
#     'geo_id': 8797,
#     'geo_name': 'Tenerife'},
#    {'value': 26.2,
#     'datetime': '2020-04-01T23:40:00.000+02:00',
#     'datetime_utc': '2020-04-01T21:40:00Z',
#     'tz_time': '2020-04-01T21:40:00.000Z',
#     'geo_id': 8798,
#     'geo_name': 'La Palma'},
#    {'value': 6.5,
#     'datetime': '2020-04-01T23:40:00.000+02:00',
#     'datetime_utc': '2020-04-01T21:40:00Z',
#     'tz_time': '2020-04-01T21:40:00.000Z',
#     'geo_id': 8799,
#     'geo_name': 'La Gomera'},
#    {'value': 4.7,
#     'datetime': '2020-04-01T23:40:00.000+02:00',
#     'datetime_utc': '2020-04-01T21:40:00Z',
#     'tz_time': '2020-04-01T21:40:00.000Z',
#     'geo_id': 8800,
#     'geo_name': 'El Hierro'},
#    ...]}}

# %%
date_start = "2020-04-01"                # start date
date_end = "2020-04-30"                  # end date

startdate = date_start + "T00:00:00.00" # can specify more if desired
enddate = date_end + "T23:50:00.00"

#LISTADO DE INDICADORES:

#ID:10354 Generación T.Real no renovable SNP (desglose subsistemas, granularidad 10')
#ID:10353 Generación T.Real renovable SNP (desglose subsistemas, granularidad 10')
#ID:10350 Demanda real suma de generación SNP (desglose subsistemas, granularidad 10')
#ID:1749 Generación T.Real hidráulica SNP (desglose subsistemas, granularidad 10')
#ID:1748 Generación T.Real solar fotovoltaica SNP (desglose subsistemas, granularidad 10')
#ID:1747 Generación T.Real turbina de vapor SNP (desglose subsistemas, granularidad 10')
#ID:1746 Generación T.Real ciclo combinado SNP (desglose subsistemas, granularidad 10')
#ID:1745 Generación T.Real eólica SNP (desglose subsistemas, granularidad 10')
#ID:1744 Generación T.Real turbina de gas SNP (desglose subsistemas, granularidad 10')
#ID:1743 Generación T.Real motores diésel SNP (desglose subsistemas, granularidad 10')
#ID:1742 Demanda prevista SNP (desglose subsistemas, granularidad 10')
#ID:1741 Demanda programada SNP (desglose subsistemas, granularidad 10')
#ID:1740 Demanda Real SNP (desglose subsistemas, granularidad 10')

#ID:10248 Generación en los SNP (desglose subsistemas, granularidad horaria)
#ID:10246 Generación en Canarias (desglose subsistemas, granularidad horaria) IGUAL QUE EL DE ARRIBA
#ID:10245 Demanda en los SNP (desglose subsistemas, granularidad horaria)
#ID:10243 Demanda en Canarias (desglose subsistemas, granularidad horaria) IGUAL QUE EL DE ARRIBA
# Generación = Demanda al ser un sistema eléctric aislado sin interconexiones ni intercambios de energía.

#ID:1337 Precio medio de la generación en los SNP por subsistema (desglose subsistemas, granularidad horaria)
#ID:1336 Precio medio de la demanda en los SNP por subsistema (desglose subsistemas, granularidad horaria)

#ID:573 Precio medio de la demanda en los SNP por sistema (desglose sistemas, granularidad horaria)
#ID:574 Precio medio de la generación en los SNP por sistema (desglose sistemas, granularidad horaria)

datos_id = ["10354","10353","10350","1748","1747","1745","1337"] #"1749","1746","1744","1743","1742","1741","1740",,"1336"
dataset=pd.DataFrame(columns=('ini','time_series'))

#LISTADO DE IDENTIFICADORES GEOGRÁFICOS:

#ID:8795 Gran Canaria
#ID:8796 Lanzarota y Fuerteventura
#ID:8797 Tenerife
#ID:8798 La Palma
#ID:8799 La Gomera
#ID:8800 El Hierro

#ID:8742 Islas Canarias


# You can get it by putting the mouse over the indicator name on the webpage. 
# webpage: https://www.esios.ree.es/es/analisis/10354

print ("Recorrer lista por Indices")
for x in range(0,len(datos_id)):
    website = 'https://api.esios.ree.es/indicators/'+datos_id[x]+'?start_date='+startdate+'&end_date='+enddate
    
    URL = website # host website
    GET = '/archives_json' # API link
    HEADERS = {
                'Accept': "application/json; application/vnd.esios-api-v1+json",
                'Host': 'api.esios.ree.es',
                'Authorization': "Token token=\"3627f9a1b46617055cb615ed161382e551ec7baa18466965dfd2cda3ebfc7307",#"a6f2f926dea90ade64acc97b3b4fff73af5bdc5d7bce554a1adfa16d554ede81"',
                'Content-Type': 'application/json'}
    
    # Runs the request to get the total URL with access token
    response = requests.get(url = URL+GET, headers = HEADERS)#, params = PARAMS) 
    matriz=[]
       
    for stuff in response.json()["indicator"]['values']:
        #print(stuff) ## show more stuff that can be gathered
        if stuff['geo_id'] == 8797: ## choose Tenerife id=8797 
            #print(stuff['value'])
            matriz.append([pd.to_datetime(stuff['datetime'],format='%Y-%m-%dT%H:%M:%S.%f%z'),stuff['value']])
            encabezado = ["time_series",response.json()["indicator"]['name']]
         
    df_parcial=pd.DataFrame(data=matriz,columns=encabezado)
    dataset=pd.merge(dataset,df_parcial, how='outer', on='time_series')
    
                 
dataset = dataset.set_index('time_series')
#dataset = dataset.resample('60T').mean()

#x=dataset.groupby(dataset.index.hour)['Precio medio de la demanda en los SNP por subsistema'].mean()
#print(x)
print('Checking dates: ' , startdate , "to" , enddate) # printing the date 


# Read the status code
status = response.status_code

print(dataset)

dataset.to_csv('df_Tenerife_Electricity_20_04.csv', index=True)
# Out:
# Recorrer lista por Indices
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# <ipython-input-3-4b48160c5f9d> in <module>
#      72             #print(stuff['value'])
#      73             matriz.append([pd.to_datetime(stuff['datetime'],format='%Y-%m-%dT%H:%M:%S.%f%z'),stuff['value']])
# ---> 74             encabezado = ["time_series",response.json()["indicator"]['name']]
#      75
#      76     df_parcial=pd.DataFrame(data=matriz,columns=encabezado)
#
# ~\anaconda3\lib\site-packages\requests\models.py in json(self, **kwargs)
#     896                     # used.
#     897                     pass
# --> 898         return complexjson.loads(self.text, **kwargs)
#     899
#     900     @property
#
# ~\anaconda3\lib\json\__init__.py in loads(s, cls, object_hook, parse_float, parse_int, parse_constant, object_pairs_hook, **kw)
#     355             parse_int is None and parse_float is None and
#     356             parse_constant is None and object_pairs_hook is None and not kw):
# --> 357         return _default_decoder.decode(s)
#     358     if cls is None:
#     359         cls = JSONDecoder
#
# ~\anaconda3\lib\json\decoder.py in decode(self, s, _w)
#     335
#     336         """
# --> 337         obj, end = self.raw_decode(s, idx=_w(s, 0).end())
#     338         end = _w(s, end).end()
#     339         if end != len(s):
#
# ~\anaconda3\lib\json\decoder.py in raw_decode(self, s, idx)
#     351         """
#     352         try:
# --> 353             obj, end = self.scan_once(s, idx)
#     354         except StopIteration as err:
#     355             raise JSONDecodeError("Expecting value", s, err.value) from None
#
# KeyboardInterrupt:
